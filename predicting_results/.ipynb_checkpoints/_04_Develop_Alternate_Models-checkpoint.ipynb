# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Set-up" data-toc-modified-id="Set-up-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Set up</a></span><ul class="toc-item"><li><span><a href="#Import-custom-functions" data-toc-modified-id="Import-custom-functions-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Import custom functions</a></span></li><li><span><a href="#Read-in-Files" data-toc-modified-id="Read-in-Files-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Read in Files</a></span></li><li><span><a href="#Create-single-line-df" data-toc-modified-id="Create-single-line-df-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Create single line df</a></span></li><li><span><a href="#Feature-labelling" data-toc-modified-id="Feature-labelling-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Feature labelling</a></span><ul class="toc-item"><li><span><a href="#Split-out-seasons" data-toc-modified-id="Split-out-seasons-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Split out seasons</a></span></li><li><span><a href="#Create-target-goals-dataframe" data-toc-modified-id="Create-target-goals-dataframe-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Create target goals dataframe</a></span></li></ul></li></ul></li><li><span><a href="#Compare-Multiple-Models" data-toc-modified-id="Compare-Multiple-Models-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Compare Multiple Models</a></span><ul class="toc-item"><li><span><a href="#Variable-lists" data-toc-modified-id="Variable-lists-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Variable lists</a></span></li><li><span><a href="#Model-Lists" data-toc-modified-id="Model-Lists-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Model Lists</a></span></li><li><span><a href="#Create-X-an-y" data-toc-modified-id="Create-X-an-y-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Create X an y</a></span></li><li><span><a href="#Retry-on-all-variables" data-toc-modified-id="Retry-on-all-variables-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Retry on all variables</a></span></li></ul></li><li><span><a href="#Scaling" data-toc-modified-id="Scaling-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Scaling</a></span><ul class="toc-item"><li><span><a href="#Standard-Scaling" data-toc-modified-id="Standard-Scaling-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Standard Scaling</a></span></li><li><span><a href="#MinMax" data-toc-modified-id="MinMax-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>MinMax</a></span></li><li><span><a href="#Compare-Results" data-toc-modified-id="Compare-Results-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Compare Results</a></span></li></ul></li><li><span><a href="#Keep-contender-Models" data-toc-modified-id="Keep-contender-Models-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Keep contender Models</a></span></li><li><span><a href="#Optimising-Span" data-toc-modified-id="Optimising-Span-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Optimising Span</a></span><ul class="toc-item"><li><span><a href="#Run-on-calculated-variables" data-toc-modified-id="Run-on-calculated-variables-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Run on calculated variables</a></span><ul class="toc-item"><li><span><a href="#Plot-Results" data-toc-modified-id="Plot-Results-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Plot Results</a></span></li></ul></li><li><span><a href="#Run-on-scaled-all-values" data-toc-modified-id="Run-on-scaled-all-values-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Run on scaled all values</a></span></li><li><span><a href="#Test-span-for-individual-model" data-toc-modified-id="Test-span-for-individual-model-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Test span for individual model</a></span></li></ul></li><li><span><a href="#New-Model-List" data-toc-modified-id="New-Model-List-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>New Model List</a></span></li><li><span><a href="#Feature-Selection" data-toc-modified-id="Feature-Selection-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Feature Selection</a></span><ul class="toc-item"><li><span><a href="#RFECV-wtih-RF-depth-2" data-toc-modified-id="RFECV-wtih-RF-depth-2-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>RFECV wtih RF depth 2</a></span></li><li><span><a href="#Test-features-on-Simple-logistic-regression" data-toc-modified-id="Test-features-on-Simple-logistic-regression-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Test features on Simple logistic regression</a></span></li><li><span><a href="#Look-at-logistic-regression-features" data-toc-modified-id="Look-at-logistic-regression-features-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Look at logistic regression features</a></span></li><li><span><a href="#Remove-Bernoulli-Naive-Bayes" data-toc-modified-id="Remove-Bernoulli-Naive-Bayes-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Remove Bernoulli Naive Bayes</a></span></li><li><span><a href="#Correlation-Plot" data-toc-modified-id="Correlation-Plot-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Correlation Plot</a></span><ul class="toc-item"><li><span><a href="#Manualy-Select-Variables" data-toc-modified-id="Manualy-Select-Variables-7.5.1"><span class="toc-item-num">7.5.1&nbsp;&nbsp;</span>Manualy Select Variables</a></span></li></ul></li><li><span><a href="#Test-Manual-Selection" data-toc-modified-id="Test-Manual-Selection-7.6"><span class="toc-item-num">7.6&nbsp;&nbsp;</span>Test Manual Selection</a></span></li></ul></li><li><span><a href="#Compare-best-models-so-far" data-toc-modified-id="Compare-best-models-so-far-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Compare best models so far</a></span><ul class="toc-item"><li><span><a href="#Log-Reg-compared-to-bookies" data-toc-modified-id="Log-Reg-compared-to-bookies-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Log Reg compared to bookies</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Random Forest</a></span></li></ul></li><li><span><a href="#Try-Transfermarkt-variables" data-toc-modified-id="Try-Transfermarkt-variables-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Try Transfermarkt variables</a></span><ul class="toc-item"><li><span><a href="#Read-in-files" data-toc-modified-id="Read-in-files-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Read in files</a></span></li><li><span><a href="#Best-Logistic-Regression-features" data-toc-modified-id="Best-Logistic-Regression-features-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Best Logistic Regression features</a></span></li><li><span><a href="#Best-RF-Base" data-toc-modified-id="Best-RF-Base-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Best RF Base</a></span></li><li><span><a href="#RFECV" data-toc-modified-id="RFECV-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>RFECV</a></span></li><li><span><a href="#Restrict-Vars" data-toc-modified-id="Restrict-Vars-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>Restrict Vars</a></span></li><li><span><a href="#Compare-profit" data-toc-modified-id="Compare-profit-9.6"><span class="toc-item-num">9.6&nbsp;&nbsp;</span>Compare profit</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Set up

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import log_loss


from sklearn.preprocessing import LabelEncoder,StandardScaler, MinMaxScaler
from sklearn.model_selection import StratifiedKFold, cross_val_score, cross_val_predict
from sklearn import ensemble, metrics, model_selection as ms, preprocessing, tree
from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline
from sklearn import linear_model as lm
from sklearn import svm
from sklearn import neighbors
from sklearn import linear_model, tree, discriminant_analysis, naive_bayes, ensemble, gaussian_process

import statsmodels.api as sm
import statsmodels.formula.api as smf
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 70)
import datetime


from pathlib import Path
import os
from os import listdir
from os.path import isfile, join

# %% [markdown]
# ## Import custom functions

# %%
# from _00_BettingFunctions import (ema_no_reset, moving_average_no_reset, restructure_ema, create_model_base,
#                                   track_best_span,create_model_probs_df,returns,expected_returns,result_returns,
#                                   determine_bet,most_likely_result,prediction_correct,bet_index_cutoff,
#                                   full_gambling_calc)

# %% [markdown]
# ## Read in Files

# %%
results = pd.read_csv(r"C:\\Users\Byron\Documents\Football Predictions\PremierLeaguePredictions\data\ff_us_1419.csv").drop("Unnamed: 0",axis=1)
results.tail()
# Out:
#       season     gameweek            matchid  \
# 4351    2019  Gameweek 28  /matches/1059980/
# 4352    2019  Gameweek 28  /matches/1059975/
# 4353    2019  Gameweek 28  /matches/1059975/
# 4354    2019  Gameweek 28  /matches/1059979/
# 4355    2019  Gameweek 28  /matches/1059979/
#
#                                            fixture            matchdate  \
# 4351                          Watford vs Liverpool  2020-02-29 17:30:00
# 4352                  Everton vs Manchester United  2020-03-01 14:00:00
# 4353                  Everton vs Manchester United  2020-03-01 14:00:00
# 4354  Tottenham Hotspur vs Wolverhampton Wanderers  2020-03-01 14:00:00
# 4355  Tottenham Hotspur vs Wolverhampton Wanderers  2020-03-01 14:00:00
#
#                        f_Team  f_HmGame  f_Possession  \
# 4351                Liverpool         0          71.0
# 4352                  Everton         1          43.1
# 4353        Manchester United         0          56.9
# ...

# %%
odds = pd.read_csv(r"C:\\Users\Byron\Documents\Football Predictions\PremierLeaguePredictions\data\bookie_odds.csv").drop("Unnamed: 0",axis=1)
odds_clean = odds[["season","fixture","FTR","bookie","BookieHomeOdds","BookieDrawOdds"
                  ,"BookieAwayOdds","BookieHomeProb","BookieDrawProb","BookieAwayProb"]].copy()
odds_clean.tail()
# Out:
#       season                             fixture FTR  bookie  BookieHomeOdds  \
# 2183    2018        Huddersfield Town vs Arsenal   A  Bet365            5.75
# 2184    2018                   Fulham vs Arsenal   A  Bet365            5.25
# 2185    2018  Wolverhampton Wanderers vs Arsenal   H  Bet365            2.90
# 2186    2018             Cardiff City vs Arsenal   A  Bet365            6.50
# 2187    2019         Sheffield United vs Arsenal   H  Bet365            3.90
#
#       BookieDrawOdds  BookieAwayOdds  BookieHomeProb  BookieDrawProb  \
# 2183            4.40            1.60        0.173913        0.227273
# 2184            4.33            1.66        0.190476        0.230947
# 2185            3.50            2.55        0.344828        0.285714
# 2186            4.33            1.57        0.153846        0.230947
# 2187            3.75            1.90        0.256410        0.266667
#
#       BookieAwayProb
# 2183        0.625000
# 2184        0.602410
# ...

# %% [markdown]
# ## Create single line df
# We will use our results dataset to create a single line results dataset that contains the Result. This will be our target variable.

# %%
def home_teams(df,keep):
    outdf = df.copy()
    outdf = outdf.query("f_HmGame==1")
    outdf = outdf[keep]
    outdf=outdf.rename(columns={'f_Team': 'HomeTeam'})
    return outdf

def away_teams(df,keep):
    outdf = df.copy()
    outdf = outdf.query("f_HmGame==0")
    outdf = outdf[keep]
    outdf=outdf.rename(columns={'f_Team': 'AwayTeam'})
    return outdf

def fixture_scores(df,score_keep_vars):
    outdf = df.copy()
    outdf = outdf.query("f_HmGame==1")
    outdf = outdf[score_keep_vars]
    outdf=outdf.rename(columns={'f_Goals': 'HomeGoals',
                                'f_Goals Conceded': 'AwayGoals'})
    return outdf

def join_fixtures(home,away,scores,merge_vars):
    outdf= pd.merge(home,away,on=merge_vars)
    outdf = pd.merge(outdf,scores,on=merge_vars)
    return outdf
def final_outcome(fixtures,homegoals,awaygoals):
    outdf = fixtures.copy()
    outdf["Result"] = np.where(outdf[homegoals]>outdf[awaygoals],"H",
                              np.where(outdf[homegoals]<outdf[awaygoals],"A","D"))
    return outdf

# %%
keep_vars = ["season","matchid","gw_no","fixture","matchdate","f_Team"]
score_keep_vars = ["season","matchid","gw_no","fixture","matchdate","f_Goals","f_Goals Conceded"]
merge_vars = ["season","matchid","gw_no","fixture","matchdate"]
team_vars = ["HomeTeam","AwayTeam"]

# %%
hometeams = home_teams(results,keep_vars)
awayteams = away_teams(results,keep_vars)
scores = fixture_scores(results,score_keep_vars)
single_line = join_fixtures(hometeams,awayteams,scores,merge_vars)
single_line = final_outcome(single_line,"HomeGoals","AwayGoals")
single_line.tail()
# Out:
#       season            matchid  gw_no  \
# 2173    2019  /matches/1059977/     28
# 2174    2019  /matches/1059981/     28
# 2175    2019  /matches/1059980/     28
# 2176    2019  /matches/1059975/     28
# 2177    2019  /matches/1059979/     28
#
#                                            fixture            matchdate  \
# 2173                   Newcastle United vs Burnley  2020-02-29 15:00:00
# 2174                West Ham United vs Southampton  2020-02-29 15:00:00
# 2175                          Watford vs Liverpool  2020-02-29 17:30:00
# 2176                  Everton vs Manchester United  2020-03-01 14:00:00
# 2177  Tottenham Hotspur vs Wolverhampton Wanderers  2020-03-01 14:00:00
#
#                HomeTeam                 AwayTeam  HomeGoals  AwayGoals Result
# 2173   Newcastle United                  Burnley          0          0      D
# 2174    West Ham United              Southampton          3          1      H
# ...

# %% [markdown]
# ## Feature labelling

# %% [markdown]
# **List Features**

# %%
features = [i for i in results.columns if i.startswith("f_") and i !="f_Team"]
# def_features = [i for i in features if "Conceded" in i]
# att_features = [i for i in features if i not in def_features]
# calculated_features = ["f_netxg","f_xGRatio","f_ShotsRatio","f_ShOnTargetRatio"]
# print(att_features)
# print()
# print(def_features)
# print()
# print(calculated_features)

# %%
df_null = results[features].isnull().sum()/results[features].count()

# %%
##handling nulls
df_null = results[features].isnull().sum()/results[features].count()
df_null = df_null[df_null>0]
null_vars = df_null.index.tolist()
print(null_vars)

results = results.drop(null_vars,axis=1)
# Out:
# ['f_xA Expected Assists Conceded']

# %%
results[results['season']==2014].describe().loc["max"].sort_values()
# Out:
# f_xG Open Play Conceded                            0.00000
# f_xG Conceded                                      0.00000
# f_xA Expected Assists                              0.00000
# f_xG Expected Goals                                0.00000
# f_xG Open Play                                     0.00000
# f_HmGame                                           1.00000
# f_Goals From Penalties                             2.00000
# f_Points                                           3.00000
# f_US xG Conceded                                   5.35103
# f_US xG                                            5.35103
# f_Touches - Final Third log                        6.25575
# f_Goals                                            8.00000
# f_Goals Conceded                                   8.00000
# f_Big Chances Total                                8.00000
# f_Big Chances Conceded                             8.00000
# f_Shots On Target Conceded                        16.00000
# ...

# %%
#remove variables that are blank
incomplete_vars = ["f_xG Open Play Conceded","f_xG Open Play","f_xA Expected Assists",
                   "f_xG Open Play","f_xG Expected Goals"]

# %%
features = [i for i in results.columns if i.startswith("f_") and i !="f_Team" 
            and i not in incomplete_vars]
def_features = [i for i in features if "Conceded" in i]
att_features = [i for i in features if i not in def_features]
calculated_features = ["f_netxg","f_xGRatio","f_ShotsRatio","f_ShOnTargetRatio"]
print(att_features)
print()
print(def_features)
# Out:
# ['f_HmGame', 'f_Possession', 'f_Touches - Final Third', 'f_Touches - Penalty Area', 'f_Passes - Final Third - Successful', 'f_Chances Created', 'f_Goals', 'f_Goals From Penalties', 'f_Goal Attempts', 'f_Shots - Inside Box', 'f_Big Chances Total', 'f_Shots On Target', 'f_US xG', 'f_Points', 'f_Touches - Final Third log']
#
# ['f_Goal Attempts In Box Conceded', 'f_Shots Conceded', 'f_Shots On Target Conceded', 'f_Big Chances Conceded', 'f_Goals Conceded', 'f_xG Conceded', 'f_Touches - Final Third Conceded', 'f_Touches - Penalty Area Conceded', 'f_Passes - Final Third - Successful Conceded', 'f_US xG Conceded', 'f_Chances Conceded']

# %% [markdown]
# ### Split out seasons

# %%
training = results[results["season"].isin([2014,2015,2016,2017])]
test = results[results["season"]==2018]
holdout = results[results["season"]==2019]

# %% [markdown]
# ### Create target goals dataframe
# This contains target variables for a per team modelling dataset predicting goals scored or conceded

# %%
target_goals = results[['f_Team', 'matchid','f_HmGame','f_Goals', 'f_Goals Conceded',"f_US xG", "f_US xG Conceded"]].copy() 
target_goals.columns = ['f_Team', 'matchid','f_HmGameFut','t_Goals', 't_Goals Conceded',"t_US xG", "t_US xG Conceded"]
target_goals.loc[0:,"t_Goals_Scored_In"] = np.where(target_goals["t_Goals"]>0,1,0)
target_goals.loc[0:,"t_Goals_Conceded_In"] = np.where(target_goals["t_Goals Conceded"]>0,1,0)
target_goals.head()
# Out:
#               f_Team           matchid  f_HmGameFut  t_Goals  \
# 0       Swansea City  /matches/755307/            0        2
# 1  Manchester United  /matches/755307/            1        1
# 2            Everton  /matches/755305/            0        2
# 3     Leicester City  /matches/755305/            1        2
# 4          Hull City  /matches/755309/            0        1
#
#    t_Goals Conceded   t_US xG  t_US xG Conceded  t_Goals_Scored_In  \
# 0                 1  0.278076          1.166350                  1
# 1                 2  1.166350          0.278076                  1
# 2                 2  0.613273          1.278300                  1
# 3                 2  1.278300          0.613273                  1
# 4                 0  1.117570          1.900670                  1
#
#    t_Goals_Conceded_In
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    0

# %%
target_goals[target_goals["f_Team"]== "Everton"].nunique()
# Out:
# f_Team                   1
# matchid                218
# f_HmGameFut              2
# t_Goals                  7
# t_Goals Conceded         7
# t_US xG                218
# t_US xG Conceded       218
# t_Goals_Scored_In        2
# t_Goals_Conceded_In      2
# dtype: int64

# %% [markdown]
# # Compare Multiple Models

# %% [markdown]
# ## Variable lists

# %%
kfold = StratifiedKFold(n_splits=5,shuffle=True, random_state=42)

# %%
classifier_vars = [i +"_Home" for i in features] + [i + "_Away" for i in features]
classifier_att_vars = [i +"_Home" for i in att_features] + [i + "_Away" for i in att_features]
classifier_def_vars = [i +"_Home" for i in def_features] + [i + "_Away" for i in def_features]
classifier_calc_vars = [i +"_Home" for i in calculated_features] + [i + "_Away" for i in calculated_features]
print(classifier_att_vars)
# Out:
# ['f_HmGame_Home', 'f_Possession_Home', 'f_Touches - Final Third_Home', 'f_Touches - Penalty Area_Home', 'f_Passes - Final Third - Successful_Home', 'f_Chances Created_Home', 'f_Goals_Home', 'f_Goals From Penalties_Home', 'f_Goal Attempts_Home', 'f_Shots - Inside Box_Home', 'f_Big Chances Total_Home', 'f_Shots On Target_Home', 'f_US xG_Home', 'f_Points_Home', 'f_Touches - Final Third log_Home', 'f_HmGame_Away', 'f_Possession_Away', 'f_Touches - Final Third_Away', 'f_Touches - Penalty Area_Away', 'f_Passes - Final Third - Successful_Away', 'f_Chances Created_Away', 'f_Goals_Away', 'f_Goals From Penalties_Away', 'f_Goal Attempts_Away', 'f_Shots - Inside Box_Away', 'f_Big Chances Total_Away', 'f_Shots On Target_Away', 'f_US xG_Away', 'f_Points_Away', 'f_Touches - Final Third log_Away']

# %% [markdown]
# ## Model Lists

# %%
# model_list ={"Logistic Regression":lm.LogisticRegression(solver="lbfgs",max_iter=4000),
#             "Random Forrest Classifier 10":ensemble.RandomForestClassifier(n_estimators=10,random_state=42),
#              "Random Forrest 50 estimators":ensemble.RandomForestClassifier(n_estimators=50, random_state=42, max_depth = 2),
#              "Naive Bayes ":GaussianNB(),
#              "Support Vector Machine":svm.SVC(gamma="auto"),
#              "KNN":neighbors.KNeighborsClassifier(),
#              "Tree Depth 2":tree.DecisionTreeClassifier(max_depth=2, min_samples_leaf=50, random_state=42),
#              "Tree Depth 5":tree.DecisionTreeClassifier(max_depth=5, min_samples_leaf=50, random_state=42)
#             }

# %%
# Create a list of standard classifiers
classifiers = {

    #GLM
    "Logistic Regression CV": lm.LogisticRegressionCV(solver='lbfgs', multi_class='auto', max_iter=1000,cv=5),
    "Logistic Regression": lm.LogisticRegression(solver='lbfgs', multi_class='auto', max_iter=1000),
    
    #Navies Bayes
    "Bernoulli NB": naive_bayes.BernoulliNB(),
    "Guassian NB": naive_bayes.GaussianNB(),
    
    #Discriminant Analysis
    "Linear Discriminant": discriminant_analysis.LinearDiscriminantAnalysis(),
    "Quadratic Discriminant": discriminant_analysis.QuadraticDiscriminantAnalysis(),

    #Ensemble Methods
    "AdaBoost": ensemble.AdaBoostClassifier(),
    "Bagging": ensemble.BaggingClassifier(),
    "ExtraTrees 10": ensemble.ExtraTreesClassifier(n_estimators=10),
    "ExtraTrees 100": ensemble.ExtraTreesClassifier(n_estimators=100),
    "Gradient Boost": ensemble.GradientBoostingClassifier(),
    "Random Forest 10": ensemble.RandomForestClassifier(n_estimators = 10,random_state=42),
    "Random Forest 50": ensemble.RandomForestClassifier(n_estimators = 50,random_state=42),
    "Random Forest 50 Depth 2": ensemble.RandomForestClassifier(n_estimators = 50,random_state=42, max_depth=2),
    
    #Trees
     "Tree Depth 2":tree.DecisionTreeClassifier(max_depth=2, min_samples_leaf=50, random_state=42),
     "Tree Depth 5":tree.DecisionTreeClassifier(max_depth=5, min_samples_leaf=50, random_state=42),

    #Gaussian Processes
    "Gaussian Process": gaussian_process.GaussianProcessClassifier(),
    
#      "Support Vector Machine":svm.SVC(gamma="auto"),
     "KNN":neighbors.KNeighborsClassifier()
    
    #xgboost: http://xgboost.readthedocs.io/en/latest/model.html
#     xgb.XGBClassifier()    
}
print(classifiers.values())
# Out:
# dict_values([LogisticRegressionCV(Cs=10, class_weight=None, cv=5, dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=1000,
#            multi_class='auto', n_jobs=None, penalty='l2',
#            random_state=None, refit=True, scoring=None, solver='lbfgs',
#            tol=0.0001, verbose=0), LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=1000, multi_class='auto',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False), BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True), GaussianNB(priors=None, var_smoothing=1e-09), LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#               solver='svd', store_covariance=False, tol=0.0001), QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
# ...

# %% [markdown]
# ## Create X an y

# %% [markdown]
# **We'll start with the calculated ratio variables**

# %%
from _00_BettingFunctions import (ema_no_reset, moving_average_no_reset, restructure_ema, create_model_base,
                                  optimise_alpha_classifier,track_best_span,create_model_probs_df,returns,expected_returns,result_returns,
                                  determine_bet,most_likely_result,prediction_correct,bet_index_cutoff,
                                  full_gambling_calc)

# %%
# import importlib
# import imp
# import _00_BettingFunctions
# from _00_BettingFunctions import create_model_probs_df

# %%
# from importlib import reload
# from _00_BettingFunctions import create_model_probs_df
# reload(create_model_probs_df)

# %%
print(features)
print()
print(merge_vars)
print()
print(calculated_features)
# Out:
# ['f_HmGame', 'f_Possession', 'f_Touches - Final Third', 'f_Touches - Penalty Area', 'f_Passes - Final Third - Successful', 'f_Chances Created', 'f_Goals', 'f_Goals From Penalties', 'f_Goal Attempts', 'f_Shots - Inside Box', 'f_Big Chances Total', 'f_Shots On Target', 'f_Goal Attempts In Box Conceded', 'f_Shots Conceded', 'f_Shots On Target Conceded', 'f_Big Chances Conceded', 'f_Goals Conceded', 'f_xG Conceded', 'f_Touches - Final Third Conceded', 'f_Touches - Penalty Area Conceded', 'f_Passes - Final Third - Successful Conceded', 'f_US xG', 'f_US xG Conceded', 'f_Points', 'f_Chances Conceded', 'f_Touches - Final Third log']
#
# ['season', 'matchid', 'gw_no', 'fixture', 'matchdate']
#
# ['f_netxg', 'f_xGRatio', 'f_ShotsRatio', 'f_ShOnTargetRatio']

# %%
test = ema_no_reset(training,36,features)
test.head()
# Out:
#             matchid             f_Team    gameweek  season  f_HmGame  \
# 0  /matches/755307/       Swansea City  Gameweek 1    2014       NaN
# 1  /matches/755307/  Manchester United  Gameweek 1    2014       NaN
# 2  /matches/755305/            Everton  Gameweek 1    2014       NaN
# 3  /matches/755305/     Leicester City  Gameweek 1    2014       NaN
# 4  /matches/755309/          Hull City  Gameweek 1    2014       NaN
#
#                              fixture            matchdate  gw_no  f_Goals  \
# 0  Manchester United vs Swansea City  2014-08-16 12:45:00      1      NaN
# 1  Manchester United vs Swansea City  2014-08-16 12:45:00      1      NaN
# 2          Leicester City vs Everton  2014-08-16 15:00:00      1      NaN
# 3          Leicester City vs Everton  2014-08-16 15:00:00      1      NaN
# 4   Queens Park Rangers vs Hull City  2014-08-16 15:00:00      1      NaN
#
#    f_Shots On Target  f_Goals From Penalties  f_Touches - Final Third  \
# ...

# %%
model_base = create_model_base(training,ema_no_reset,36,features,target_goals,merge_vars,calculated_features,single_line)
X = model_base[classifier_calc_vars]
y = model_base["Result"]
le = LabelEncoder()
y = le.fit_transform(y)

# %%
def find_best_algorithms(classifier_list, X, y):
    # This function is adapted from https://www.kaggle.com/yassineghouzam/titanic-top-4-with-ensemble-modeling
    # Cross validate model with Kfold stratified cross validation
    kfold = StratifiedKFold(n_splits=5,random_state=42)
    
    # Grab the cross validation scores for each algorithm
    cv_results = [cross_val_score(classifier, X, y, scoring = "neg_log_loss", cv = kfold) 
                  for classifier in list(classifier_list.values())]
    cv_means = [cv_result.mean() * -1 for cv_result in cv_results]
    cv_std = [cv_result.std() for cv_result in cv_results]
    algorithm_names = [alg for alg in list(classifier_list.keys())]
    
    # Create a DataFrame of all the CV results
    cv_results = pd.DataFrame({
        "Mean Log Loss": cv_means,
        "Log Loss Std": cv_std,
        "Algorithm": algorithm_names
    }).sort_values(by='Mean Log Loss')
    return cv_results

# %%
algorithm_results = find_best_algorithms(classifiers, X, y)
algorithm_results["Vars"] = "Calculated Vars"
algorithm_results["Scaling"] = "None"

# %%
algorithm_results
# Out:
#     Mean Log Loss  Log Loss Std                 Algorithm             Vars  \
# 1        0.983676      0.035420       Logistic Regression  Calculated Vars
# 0        0.985154      0.034740    Logistic Regression CV  Calculated Vars
# 16       0.988261      0.030621          Gaussian Process  Calculated Vars
# 4        0.991450      0.029773       Linear Discriminant  Calculated Vars
# 13       0.994112      0.034111  Random Forest 50 Depth 2  Calculated Vars
# 2        1.005416      0.037802              Bernoulli NB  Calculated Vars
# 14       1.016694      0.049579              Tree Depth 2  Calculated Vars
# 15       1.034037      0.041286              Tree Depth 5  Calculated Vars
# 10       1.054051      0.031122            Gradient Boost  Calculated Vars
# 9        1.070569      0.036103            ExtraTrees 100  Calculated Vars
# 6        1.093200      0.009159                  AdaBoost  Calculated Vars
# ...

# %% [markdown]
# ## Retry on all variables

# %%
model_base = create_model_base(training,ema_no_reset,36,features,target_goals,merge_vars,calculated_features,single_line)
X = model_base[classifier_vars]
y = model_base["Result"]
le = LabelEncoder()
y = le.fit_transform(y)

# %%
from sklearn.exceptions import ConvergenceWarning
import warnings

# %%
warnings.filterwarnings("ignore", category=ConvergenceWarning,
                        module="sklearn")
algorithm_results_all_vars = find_best_algorithms(classifiers, X, y)

# %%
algorithm_results_all_vars["Vars"] = "All Vars"
algorithm_results_all_vars["Scaling"] = "None"

# %%
algorithm_results_all_vars
# Out:
#     Mean Log Loss  Log Loss Std                 Algorithm      Vars Scaling
# 13       0.989628  3.489774e-02  Random Forest 50 Depth 2  All Vars    None
# 0        0.990095  3.524452e-02    Logistic Regression CV  All Vars    None
# 9        1.004528  2.893139e-02            ExtraTrees 100  All Vars    None
# 14       1.011311  3.728584e-02              Tree Depth 2  All Vars    None
# 1        1.012375  4.251352e-02       Logistic Regression  All Vars    None
# 4        1.048475  7.429906e-02       Linear Discriminant  All Vars    None
# 2        1.068298  9.469030e-03              Bernoulli NB  All Vars    None
# 12       1.071863  1.193526e-01          Random Forest 50  All Vars    None
# 10       1.072689  8.006040e-02            Gradient Boost  All Vars    None
# 15       1.092220  8.140510e-02              Tree Depth 5  All Vars    None
# 16       1.098612  3.317284e-12          Gaussian Process  All Vars    None
# ...

# %% [markdown]
# # Scaling

# %%
standard_scaler = StandardScaler()
min_max_scaler = MinMaxScaler()

# %%
test_scaled = model_base.copy()
test_scaled[classifier_vars] = standard_scaler.fit_transform(model_base[classifier_vars])
test_scaled.head()
# Out:
#    season           matchid  gw_no                               fixture  \
# 0    2014  /matches/755324/      3          Burnley vs Manchester United
# 1    2014  /matches/755327/      3         Manchester City vs Stoke City
# 2    2014  /matches/755328/      3    Newcastle United vs Crystal Palace
# 3    2014  /matches/755329/      3     Queens Park Rangers vs Sunderland
# 4    2014  /matches/755330/      3  Swansea City vs West Bromwich Albion
#
#              matchdate             HomeTeam              AwayTeam  HomeGoals  \
# 0  2014-08-30 12:45:00              Burnley     Manchester United          0
# 1  2014-08-30 15:00:00      Manchester City            Stoke City          0
# 2  2014-08-30 15:00:00     Newcastle United        Crystal Palace          3
# 3  2014-08-30 15:00:00  Queens Park Rangers            Sunderland          1
# 4  2014-08-30 15:00:00         Swansea City  West Bromwich Albion          3
#
#    AwayGoals Result  f_HmGame_Home  f_Possession_Home  \
# ...

# %%
def create_model_base_scaled(df,avg_method, span,ema_features,scaler, target_goals
                    ,merge_vars, calc_vars,single_line):
    #import pandas as pd
    ema_vars = ema_features + calc_vars
    ema_output = avg_method(df, span,ema_features)
    ema_output[ema_features] = scaler.fit_transform(ema_output[ema_features])
    ema_target = pd.merge(ema_output, target_goals, on = ['f_Team','matchid']).dropna() ## this contains our target variable
    ema_single_line = restructure_ema(ema_target,merge_vars,ema_vars)
    ema_results = pd.merge(single_line, ema_single_line, on=merge_vars,how="inner")
    return ema_results

# %% [markdown]
# ## Standard Scaling

# %%
model_base = create_model_base_scaled(training,ema_no_reset,36,features,standard_scaler,
                                      target_goals,merge_vars,calculated_features,single_line)
X = model_base[classifier_vars] #+classifier_calc_vars
y = model_base["Result"]
le = LabelEncoder()
y = le.fit_transform(y)

# %%
algorithm_results_standard_all_vars = find_best_algorithms(classifiers, X, y)
algorithm_results_standard_all_vars["Vars"] = "All Vars"
algorithm_results_standard_all_vars["Scaling"] = "Standard"

# %%
algorithm_results_standard_all_vars
# Out:
#     Mean Log Loss  Log Loss Std                 Algorithm      Vars   Scaling
# 0        0.984381      0.029660    Logistic Regression CV  All Vars  Standard
# 13       0.989628      0.034898  Random Forest 50 Depth 2  All Vars  Standard
# 9        1.011008      0.030001            ExtraTrees 100  All Vars  Standard
# 14       1.011311      0.037286              Tree Depth 2  All Vars  Standard
# 4        1.048475      0.074299       Linear Discriminant  All Vars  Standard
# 10       1.070442      0.082717            Gradient Boost  All Vars  Standard
# 12       1.071770      0.119436          Random Forest 50  All Vars  Standard
# 1        1.076293      0.123519       Logistic Regression  All Vars  Standard
# 15       1.092220      0.081405              Tree Depth 5  All Vars  Standard
# 16       1.098315      0.000179          Gaussian Process  All Vars  Standard
# 6        1.100019      0.008988                  AdaBoost  All Vars  Standard
# ...

# %% [markdown]
# ## MinMax

# %%
model_base = create_model_base_scaled(training,ema_no_reset,36,features,min_max_scaler,
                                      target_goals,merge_vars,calculated_features,single_line)
X = model_base[classifier_vars] #+classifier_calc_vars
y = model_base["Result"]
le = LabelEncoder()
y = le.fit_transform(y)

algorithm_results_minmax_all_vars = find_best_algorithms(classifiers, X, y)
algorithm_results_minmax_all_vars["Vars"] = "All Vars"
algorithm_results_minmax_all_vars["Scaling"] = "MinMax"

# %%
algorithm_results_minmax_all_vars
# Out:
#     Mean Log Loss  Log Loss Std                 Algorithm      Vars Scaling
# 0        0.987922      0.031071    Logistic Regression CV  All Vars  MinMax
# 16       0.989369      0.036821          Gaussian Process  All Vars  MinMax
# 13       0.989628      0.034898  Random Forest 50 Depth 2  All Vars  MinMax
# 9        1.005102      0.037199            ExtraTrees 100  All Vars  MinMax
# 1        1.005956      0.042366       Logistic Regression  All Vars  MinMax
# 14       1.011311      0.037286              Tree Depth 2  All Vars  MinMax
# 4        1.048475      0.074299       Linear Discriminant  All Vars  MinMax
# 2        1.068210      0.008123              Bernoulli NB  All Vars  MinMax
# 10       1.070335      0.075675            Gradient Boost  All Vars  MinMax
# 12       1.071863      0.119353          Random Forest 50  All Vars  MinMax
# 15       1.092220      0.081405              Tree Depth 5  All Vars  MinMax
# ...

# %% [markdown]
# ## Compare Results

# %%
pd.concat([algorithm_results,algorithm_results_all_vars,algorithm_results_standard_all_vars,
          algorithm_results_minmax_all_vars],axis=0).sort_values(by="Mean Log Loss").head(20)
# Out:
#     Mean Log Loss  Log Loss Std                 Algorithm             Vars  \
# 1        0.983676      0.035420       Logistic Regression  Calculated Vars
# 0        0.984381      0.029660    Logistic Regression CV         All Vars
# 0        0.985154      0.034740    Logistic Regression CV  Calculated Vars
# 0        0.987922      0.031071    Logistic Regression CV         All Vars
# 16       0.988261      0.030621          Gaussian Process  Calculated Vars
# 16       0.989369      0.036821          Gaussian Process         All Vars
# 13       0.989628      0.034898  Random Forest 50 Depth 2         All Vars
# 13       0.989628      0.034898  Random Forest 50 Depth 2         All Vars
# 13       0.989628      0.034898  Random Forest 50 Depth 2         All Vars
# 0        0.990095      0.035245    Logistic Regression CV         All Vars
# 4        0.991450      0.029773       Linear Discriminant  Calculated Vars
# ...

# %% [markdown]
# # Keep contender Models

# %%
# Create a list of standard classifiers
trial_classifiers = {
    #GLM
    "Logistic Regression CV": lm.LogisticRegressionCV(solver='lbfgs', multi_class='auto', max_iter=1000,cv=5),
    #Navies Bayes
    "Bernoulli NB": naive_bayes.BernoulliNB(),
    #Discriminant Analysis
    #Ensemble Methods
    "Random Forest 50": ensemble.RandomForestClassifier(n_estimators = 50,random_state=42,max_depth=2),
    #Gaussian Processes
    "Gaussian Process": gaussian_process.GaussianProcessClassifier(),
}
print(trial_classifiers.values())
# Out:
# dict_values([LogisticRegressionCV(Cs=10, class_weight=None, cv=5, dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=1000,
#            multi_class='auto', n_jobs=None, penalty='l2',
#            random_state=None, refit=True, scoring=None, solver='lbfgs',
#            tol=0.0001, verbose=0), BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True), RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=2, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False), GaussianProcessClassifier(copy_X_train=True, kernel=None,
#              max_iter_predict=100, multi_class='one_vs_rest', n_jobs=None,
# ...

# %% [markdown]
# # Optimising Span

# %% [markdown]
# ## Run on calculated variables

# %%
warnings.filterwarnings("ignore", category=ConvergenceWarning,
                        module="sklearn")
all_cv_scores = []
for model in trial_classifiers.values():
    print(model)
    cv_scores = []
    lowest_span = 2
    for span in range(2, 38, 2):
        model_base = create_model_base(training,ema_no_reset,span,features,target_goals,merge_vars
                                       ,calculated_features,single_line)
        model_base = model_base.dropna()
        error = optimise_alpha_classifier(model_base,classifier_calc_vars,"Result",model,"neg_log_loss")
        cv_scores.append(error)
        if error == max(cv_scores):
            lowest_span = span
    all_cv_scores.append(cv_scores)
# Out:
# LogisticRegressionCV(Cs=10, class_weight=None, cv=5, dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=1000,
#            multi_class='auto', n_jobs=None, penalty='l2',
#            random_state=None, refit=True, scoring=None, solver='lbfgs',
#            tol=0.0001, verbose=0)
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=2, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# GaussianProcessClassifier(copy_X_train=True, kernel=None,
#              max_iter_predict=100, multi_class='one_vs_rest', n_jobs=None,
# ...

# %% [markdown]
# ### Plot Results

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,6))
for i in range(0,len(all_cv_scores)):
    plt.plot(list(range(2, 38, 2)), (pd.Series(all_cv_scores[i])*-1), label=str(list(trial_classifiers.keys())[i])) # Plot our result
    #plt.plot(list(range(2, 46, 2)), (pd.Series(ma_nr)*-1), label="Moving Average No reset") # Plot our result
plt.title("Optimising span for predicted Result")
plt.xlabel("Span of games")
plt.ylabel("Neg Log Loss")
plt.legend()

# %% [markdown]
# ## Run on scaled all values

# %%
warnings.filterwarnings("ignore", category=ConvergenceWarning,
                        module="sklearn")
all_cv_scores = []
for model in trial_classifiers.values():
    print(model)
    cv_scores = []
    lowest_span = 2
    for span in range(2, 38, 2):
        model_base = create_model_base_scaled(training,ema_no_reset,span,features,standard_scaler,
                                              target_goals,merge_vars,calculated_features,single_line)
        model_base = model_base.dropna()
        #change variables here
        error = optimise_alpha_classifier(model_base,classifier_vars + classifier_calc_vars,"Result",model,"neg_log_loss")
        cv_scores.append(error)
        if error == max(cv_scores):
            lowest_span = span
    all_cv_scores.append(cv_scores)
# Out:
# LogisticRegressionCV(Cs=10, class_weight=None, cv=5, dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=1000,
#            multi_class='auto', n_jobs=None, penalty='l2',
#            random_state=None, refit=True, scoring=None, solver='lbfgs',
#            tol=0.0001, verbose=0)
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=2, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# GaussianProcessClassifier(copy_X_train=True, kernel=None,
#              max_iter_predict=100, multi_class='one_vs_rest', n_jobs=None,
# ...

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,6))
for i in range(0,len(all_cv_scores)):
    plt.plot(list(range(2, 38, 2)), (pd.Series(all_cv_scores[i])*-1), label=str(list(trial_classifiers.keys())[i])) # Plot our result
    #plt.plot(list(range(2, 46, 2)), (pd.Series(ma_nr)*-1), label="Moving Average No reset") # Plot our result
plt.title("Optimising span for predicted Result")
plt.xlabel("Span of games")
plt.ylabel("Neg Log Loss")
plt.legend()

# %% [markdown]
# ## Test span for individual model

# %%
warnings.filterwarnings("ignore", category=ConvergenceWarning,
                        module="sklearn")

all_cv_scores = []
cv_scores = []
lowest_span = 2
model = ensemble.RandomForestClassifier(n_estimators = 50,random_state=42,max_depth=2)
for span in range(2, 38, 2):
    model_base = create_model_base_scaled(training,ema_no_reset,span,features,standard_scaler,
                                          target_goals,merge_vars,calculated_features,single_line)
    model_base = model_base.dropna()
    error = optimise_alpha_classifier(model_base,classifier_vars +classifier_calc_vars,
                                      "Result",model,"neg_log_loss")
    cv_scores.append(error)
    if error == max(cv_scores):
        lowest_span = span
all_cv_scores.append(cv_scores)

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,6))
for i in range(0,len(all_cv_scores)):
    plt.plot(list(range(2, 38, 2)), (pd.Series(all_cv_scores[i])*-1), label=str(list(trial_classifiers.keys())[i])) # Plot our result
    #plt.plot(list(range(2, 46, 2)), (pd.Series(ma_nr)*-1), label="Moving Average No reset") # Plot our result
plt.title("Optimising span for predicted Goals Scored")
plt.xlabel("Span of games")
plt.ylabel("Neg Log Loss")
plt.legend()

# %% [markdown]
# # New Model List

# %%
model_list ={"Logistic Regression":lm.LogisticRegression(solver="lbfgs",max_iter=4000),
             "Random Forrest 50 estimators":ensemble.RandomForestClassifier(n_estimators=50, random_state=42, max_depth = 2),
               "Logistic Regression CV": lm.LogisticRegressionCV(solver='lbfgs', multi_class='auto', max_iter=1000,cv=5)
            }

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## RFECV wtih RF depth 2

# %%
from sklearn.feature_selection import RFECV

# %%
model_base = create_model_base_scaled(training,ema_no_reset,36,features,standard_scaler,
                                      target_goals,merge_vars,calculated_features,single_line)
X = model_base[classifier_vars+classifier_calc_vars]
y = model_base["Result"]
le = LabelEncoder()
y = le.fit_transform(y)

model = ensemble.RandomForestClassifier(n_estimators = 50,random_state=42,max_depth =2)
rfecv = RFECV(estimator=model, step=1, cv=StratifiedKFold(n_splits=10, random_state=42), scoring='neg_log_loss')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
# Out:
# Optimal number of features: 46

# %%
plt.figure(figsize=(6, 4))
plt.title('Recursive Feature Elimination with Cross-Validation', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of features selected', fontsize=14, labelpad=20)
plt.ylabel('Mean Squared Error', fontsize=14, labelpad=20)
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_*-1, color='#303F9F', linewidth=3)

plt.show()

# %%
print(len(X.columns))
len(rfecv.estimator_.feature_importances_)
# Out:
# 60
# 46

# %%
dset = pd.DataFrame()
dset['attr'] = X.columns[rfecv.support_]
dset['importance'] = rfecv.estimator_.feature_importances_

dset = dset.sort_values(by='importance', ascending=False)


plt.figure(figsize=(8, 15))
plt.barh(y=dset['attr'], width=dset['importance'], color='#1976D2')
plt.title('RFECV - Feature Importances', fontsize=20, fontweight='bold', pad=20)
plt.xlabel('Importance', fontsize=14, labelpad=20)
plt.show()

# %% [markdown]
# ## Test features on Simple logistic regression
# Logistic Regression CV takes much longer to run

# %%
model = lm.LogisticRegression(solver='lbfgs', multi_class='auto', max_iter=200)
rfecv = RFECV(estimator=model, step=1, cv=StratifiedKFold(n_splits=10, random_state=42), scoring='neg_log_loss')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
plt.figure(figsize=(6, 4))
plt.title('Recursive Feature Elimination with Cross-Validation', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of features selected', fontsize=14, labelpad=20)
plt.ylabel('Mean Squared Error', fontsize=14, labelpad=20)
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_*-1, color='#303F9F', linewidth=3)

plt.show()
# Out:
# Optimal number of features: 5

# %%
X.columns[rfecv.support_]
# Out:
# Index(['f_Touches - Final Third_Home', 'f_Touches - Final Third log_Home',
#        'f_xGRatio_Away', 'f_ShotsRatio_Away', 'f_ShOnTargetRatio_Away'],
#       dtype='object')

# %%
list(zip(X.columns[rfecv.support_],rfecv.estimator_.coef_[0]))
# Out:
# [('f_Touches - Final Third_Home', -0.7233981597866971),
#  ('f_Touches - Final Third log_Home', 0.33908251337385514),
#  ('f_xGRatio_Away', 1.9240557233569857),
#  ('f_ShotsRatio_Away', 1.9563824222694421),
#  ('f_ShOnTargetRatio_Away', 0.1874497227469308)]

# %%
log_reg_features=list(X.columns[rfecv.support_])
print(log_reg_features)
# Out:
# ['f_Touches - Final Third_Home', 'f_Touches - Final Third log_Home', 'f_xGRatio_Away', 'f_ShotsRatio_Away', 'f_ShOnTargetRatio_Away']

# %% [markdown]
# ## Look at logistic regression features

# %%
model = lm.LogisticRegressionCV(solver='lbfgs', multi_class='auto', max_iter=1000,cv=5)

model_base = create_model_base_scaled(training,ema_no_reset,36,features,standard_scaler,
                                      target_goals,merge_vars,calculated_features,single_line)
X = model_base[classifier_vars+classifier_calc_vars]
y = model_base["Result"]
le = LabelEncoder()
y = le.fit_transform(y)
X_logreg = model_base[log_reg_features]

print(cross_val_score(model,X,y,scoring = "neg_log_loss",cv=kfold).mean())
print(cross_val_score(model,X_logreg,y,scoring = "neg_log_loss",cv=kfold).mean())
# Out:
# -0.9852730692639351
# -0.9833695135841658

# %% [markdown]
# ## Remove Bernoulli Naive Bayes

# %%
trial_classifiers.pop("Bernoulli NB")
# Out:
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
trial_classifiers
# Out:
# {'Logistic Regression CV': LogisticRegressionCV(Cs=10, class_weight=None, cv=5, dual=False,
#             fit_intercept=True, intercept_scaling=1.0, max_iter=1000,
#             multi_class='auto', n_jobs=None, penalty='l2',
#             random_state=None, refit=True, scoring=None, solver='lbfgs',
#             tol=0.0001, verbose=0),
#  'Random Forest 50': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=2, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=None,
#              oob_score=False, random_state=42, verbose=0, warm_start=False),
#  'Gaussian Process': GaussianProcessClassifier(copy_X_train=True, kernel=None,
#               max_iter_predict=100, multi_class='one_vs_rest', n_jobs=None,
# ...

# %% [markdown]
# ## Correlation Plot

# %%
hg_corr = model_base[classifier_vars + classifier_calc_vars+["HomeGoals","AwayGoals"]].corr()[["HomeGoals","AwayGoals"]]
#ag_corr = model_base[classifier_vars + classifier_calc_vars+["AwayGoals"]].corr()[["AwayGoals"]]
# corr_goals = pd.concat([hg_corr,ag_corr],axis = 1)
hg_corr.sort_values(by="AwayGoals")
# Out:
#                                                    HomeGoals  AwayGoals
# f_Touches - Penalty Area Conceded_Away              0.172566  -0.247987
# f_Touches - Final Third Conceded_Away               0.138478  -0.242382
# f_Passes - Final Third - Successful Conceded_Away   0.116799  -0.235950
# f_Shots Conceded_Away                               0.146609  -0.232633
# f_Goal Attempts In Box Conceded_Away                0.169119  -0.232298
# f_Chances Conceded_Away                             0.145521  -0.227692
# f_US xG Conceded_Away                               0.163665  -0.219354
# f_Shots On Target Conceded_Away                     0.154792  -0.203186
# f_Shots On Target_Home                              0.286467  -0.187592
# f_xGRatio_Home                                      0.281340  -0.185260
# f_netxg_Home                                        0.282943  -0.185152
# f_Goals Conceded_Away                               0.128095  -0.175900
# ...

# %% [markdown]
# ### Manualy Select Variables

# %%
home_goals_home_vars = ["f_Touches - Final Third_Home","f_Touches - Penalty Area_Home","f_US xG_Home",
                       "f_ShotsRatio_Home"]
home_goals_away_vars = ["f_Touches - Penalty Area Conceded_Away","f_US xG Conceded_Away","f_Goal Attempts In Box Conceded_Away"]
away_goals_home_vars = ["f_US xG Conceded_Home","f_Shots On Target Conceded_Home","f_xGRatio_Home"]
away_goals_away_vars = ["f_Chances Created_Away","f_Goal Attempts_Away","f_Touches - Penalty Area_Away",
                       "f_US xG_Away"]
manual_trial_features = home_goals_home_vars+home_goals_away_vars+away_goals_home_vars+away_goals_away_vars

# %% [markdown]
# ## Test Manual Selection

# %%
# warnings.filterwarnings("ignore", category=ConvergenceWarning,
#                         module="sklearn")
all_cv_scores = []
for model in trial_classifiers.values():
    print(model)
    cv_scores = []
    lowest_span = 2
    for span in range(2, 38, 2):
        model_base = create_model_base_scaled(training,ema_no_reset,span,features,standard_scaler,
                                              target_goals,merge_vars,calculated_features,single_line)
        model_base = model_base.dropna()
        error = optimise_alpha_classifier(model_base,manual_trial_features,"Result",model,"neg_log_loss")
        cv_scores.append(error)
        if error == max(cv_scores):
            lowest_span = span
    all_cv_scores.append(cv_scores)
# Out:
# LogisticRegressionCV(Cs=10, class_weight=None, cv=5, dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=1000,
#            multi_class='auto', n_jobs=None, penalty='l2',
#            random_state=None, refit=True, scoring=None, solver='lbfgs',
#            tol=0.0001, verbose=0)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=2, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# GaussianProcessClassifier(copy_X_train=True, kernel=None,
#              max_iter_predict=100, multi_class='one_vs_rest', n_jobs=None,
#              n_restarts_optimizer=0, optimizer='fmin_l_bfgs_b',
#              random_state=None, warm_start=False)

# %%
plt.style.use('ggplot')
for i in range(0,len(all_cv_scores)):
    plt.plot(list(range(2, 38, 2)), (pd.Series(all_cv_scores[i])*-1), label=str(list(trial_classifiers.keys())[i])) # Plot our result
    #plt.plot(list(range(2, 46, 2)), (pd.Series(ma_nr)*-1), label="Moving Average No reset") # Plot our result
plt.title("Optimising span for result")
plt.xlabel("Span of games")
plt.ylabel("Neg Log Loss")
plt.legend()

# %% [markdown]
# # Compare best models so far

# %%
model_base_30 = create_model_base(training,ema_no_reset,30,features,target_goals,merge_vars,
                                      calculated_features,single_line)
X_calc = model_base[classifier_calc_vars]
y = model_base["Result"]
le = LabelEncoder()
y = le.fit_transform(y)

model_base_rf =create_model_base_scaled(training,ema_no_reset,22,features,standard_scaler,
                                 target_goals,merge_vars,calculated_features,single_line)
X_rf = model_base[classifier_vars + classifier_calc_vars]

rf2 = ensemble.RandomForestClassifier(n_estimators = 50,random_state=42, max_depth=2)
lr = lm.LogisticRegression(solver='lbfgs', multi_class='auto', max_iter=1000)
kfold = StratifiedKFold(n_splits=5,shuffle=True, random_state=42)

rf2_logloss = cross_val_score(rf2, X_rf, y, scoring="neg_log_loss", cv=kfold).mean()
rf2_accuracy = cross_val_score(rf2,X_rf, y, scoring="accuracy", cv=kfold).mean()

lr_logloss = cross_val_score(lr, X_calc, y, scoring="neg_log_loss", cv=kfold).mean()
lr_accuracy = cross_val_score(lr, X_calc, y, scoring="accuracy", cv=kfold).mean()


print("RF2 " + str(rf2_logloss)+" "+ str(rf2_accuracy))
print("LR " + str(lr_logloss)+" "+ str(lr_accuracy))
# Out:
# RF2 -0.9821926984828939 0.5316046369737645
# LR -0.9813847197580687 0.5289132940139651

# %% [markdown]
# ## Log Reg compared to bookies

# %%
#from _00_v2 import bet_profit
from imp import reload 
#from src import mymodule
from _00_BettingFunctions import bet_profit
#reload(_00_BettingFunctions)
# Change in mymodule

# %%
merge_vars = ["season","matchid","gw_no","fixture","matchdate"]
team_vars = ["HomeTeam","AwayTeam"]
pred_cols = ["Model_Prob_"+col for col in list(le.classes_)]
gamble_cols = merge_vars + team_vars + pred_cols
print(gamble_cols)
# Out:
# ['season', 'matchid', 'gw_no', 'fixture', 'matchdate', 'HomeTeam', 'AwayTeam', 'Model_Prob_A', 'Model_Prob_D', 'Model_Prob_H']

# %%
bookie_home_odds = "BookieHomeOdds"
bookie_draw_odds = "BookieDrawOdds"
bookie_away_odds = "BookieAwayOdds"
bookie_home_prob = "BookieHomeProb"
bookie_draw_prob = "BookieDrawProb"
bookie_away_prob = "BookieAwayProb"

model_home = "Model_Prob_H"
model_draw = "Model_Prob_D"
model_away = "Model_Prob_A"

stake = 5

# %%
model_base = create_model_base(training,ema_no_reset,30,features,target_goals,merge_vars,
                                      calculated_features,single_line)
X_calc = model_base_lr[classifier_calc_vars]
y = model_base["Result"]
le = LabelEncoder()
y = le.fit_transform(y)

lr = lm.LogisticRegression(solver='lbfgs', multi_class='auto', max_iter=1000)

clf = lr.fit(X_calc,y)
print(metrics.log_loss(y,clf.predict_proba(X_calc)))
# Out:
# 0.977183209241293

# %%
model_ema = create_model_base(results,ema_no_reset,30,features,target_goals,merge_vars,
                                      calculated_features,single_line)
model_base = create_model_probs_df(model_ema,[2014,2015,2016,2017,2018],clf,classifier_calc_vars,
                                  list(le.classes_),gamble_cols)
odds_preds = pd.merge(model_base,odds_clean, on =["season","fixture"], how ="inner")
odds_preds = odds_preds.rename(columns={"FTR":"Result"})
gambling_df = odds_preds.copy()
gambling_output = full_gambling_calc(odds_preds,stake,bookie_home_prob,bookie_draw_prob,bookie_away_prob,model_home,model_draw,model_away)

gambling_output["ValueRequirementMet"] = gambling_output.apply(lambda row: bet_index_cutoff(1.3,row["BestValueIndex"]),axis=1)
gambling_output["ModelPredProfit"] = gambling_output.apply(lambda row: 
                                                           bet_profit(row["ModelPredCorrect"],row["ResultReturns"],1,row["Stake"])
                                                          ,axis=1)
gambling_output["ValuePredProfit"] = gambling_output.apply(lambda row: 
                                                           bet_profit(row["ValuePredCorrect"],row["ResultReturns"],1,row["Stake"])
                                                          ,axis=1)
gambling_output["ValueCutoffProfit"] = gambling_output.apply(lambda row: 
                                                           bet_profit(row["ValuePredCorrect"],row["ResultReturns"]
                                                                      ,row["ValueRequirementMet"],row["Stake"])
                                                          ,axis=1)
gambling_output.groupby(["season","bookie"]).agg(BookieAcc=("BookiePredCorrect","mean")
                                        ,ModelAcc=("ModelPredCorrect","mean")
                                        ,ModelReturns=("ModelPredProfit","sum")
                                        ,ValueAcc=("ValuePredCorrect","mean")
                                        ,ValueReturns=("ValuePredProfit","sum")
                                        ,ValueCutoffReturns=("ValueCutoffProfit","sum")
                                        #,ModelResultProb=("FinalResultProb","mean")
                                        ,Counts=("fixture","nunique")
                                        ,ValueCutoffCounts=("ValueRequirementMet","sum")).reset_index().head()
# Out:
#    season  bookie  BookieAcc  ModelAcc  ModelReturns  ValueAcc  ValueReturns  \
# 0    2014  Bet365   0.541667  0.536111          78.4  0.297222         38.50
# 1    2015  Bet365   0.478610  0.473262        -176.6  0.326203         43.10
# 2    2016  Bet365   0.613757  0.576720          37.6  0.304233         37.00
# 3    2017  Bet365   0.550532  0.534574        -132.6  0.295213        219.35
# 4    2018  Bet365   0.588235  0.588235          61.9  0.302139         35.00
#
#    ValueCutoffReturns  Counts  ValueCutoffCounts
# 0              170.25     360                117
# 1               64.65     374                 58
# 2              -57.10     378                100
# 3              165.25     376                 95
# 4               51.60     374                110

# %%
for i in [2014,2015,2016,2017,2018]:
    log_test = gambling_output[gambling_output["season"]==i].copy()
    y = log_test["Result"]
    le = LabelEncoder()
    y = le.fit_transform(y)
    print(str(i) + " Model log loss " + str(metrics.log_loss(y,log_test[["Model_Prob_A","Model_Prob_D","Model_Prob_H"]])))
    print(str(i) + " Bookie log loss " + str(metrics.log_loss(y,log_test[["BookieAwayProb","BookieDrawProb","BookieHomeProb"]])))
# Out:
# 2014 Model log loss 0.9825806590090431
# 2014 Bookie log loss 0.9715931068323761
# 2015 Model log loss 1.0395001210007555
# 2015 Bookie log loss 1.0338599362386478
# 2016 Model log loss 0.9290105761052954
# 2016 Bookie log loss 0.9051049304960634
# 2017 Model log loss 0.9584588699087883
# 2017 Bookie log loss 0.946345472351005
# 2018 Model log loss 0.9030855114583045
# 2018 Bookie log loss 0.8933418817468733

# %% [markdown]
# ## Random Forest

# %%
model_base_rf =create_model_base_scaled(training,ema_no_reset,22,features,standard_scaler,
                                 target_goals,merge_vars,calculated_features,single_line)
X_rf = model_base_rf[classifier_vars + classifier_calc_vars]

rf2 = ensemble.RandomForestClassifier(n_estimators = 50,random_state=42, max_depth=2)

y = model_base_rf["Result"]
le = LabelEncoder()
y = le.fit_transform(y)

clf_rf = rf2.fit(X_rf,y)
print(metrics.log_loss(y,clf_rf.predict_proba(X_rf)))
# Out:
# 0.9650540309123057

# %%
model_ema = create_model_base_scaled(results,ema_no_reset,22,features,standard_scaler,
                                     target_goals,merge_vars,calculated_features,single_line)
model_base = create_model_probs_df(model_ema,[2014,2015,2016,2017,2018],clf_rf,classifier_vars + classifier_calc_vars,
                                  list(le.classes_),gamble_cols)
odds_preds = pd.merge(model_base,odds_clean, on =["season","fixture"], how ="inner")
odds_preds = odds_preds.rename(columns={"FTR":"Result"})
gambling_df = odds_preds.copy()
gambling_output = full_gambling_calc(odds_preds,stake,bookie_home_prob,bookie_draw_prob,bookie_away_prob,model_home,model_draw,model_away)

gambling_output["ValueRequirementMet"] = gambling_output.apply(lambda row: bet_index_cutoff(1.3,row["BestValueIndex"]),axis=1)
gambling_output["ModelPredProfit"] = gambling_output.apply(lambda row: 
                                                           bet_profit(row["ModelPredCorrect"],row["ResultReturns"],1,row["Stake"])
                                                          ,axis=1)
gambling_output["ValuePredProfit"] = gambling_output.apply(lambda row: 
                                                           bet_profit(row["ValuePredCorrect"],row["ResultReturns"],1,row["Stake"])
                                                          ,axis=1)
gambling_output["ValueCutoffProfit"] = gambling_output.apply(lambda row: 
                                                           bet_profit(row["ValuePredCorrect"],row["ResultReturns"]
                                                                      ,row["ValueRequirementMet"],row["Stake"])
                                                          ,axis=1)
gambling_output.groupby(["season","bookie"]).agg(BookieAcc=("BookiePredCorrect","mean")
                                        ,ModelAcc=("ModelPredCorrect","mean")
                                        ,ModelReturns=("ModelPredProfit","sum")
                                        ,ValueAcc=("ValuePredCorrect","mean")
                                        ,ValueReturns=("ValuePredProfit","sum")
                                        ,ValueCutoffReturns=("ValueCutoffProfit","sum")
                                        #,ModelResultProb=("FinalResultProb","mean")
                                        ,Counts=("fixture","nunique")
                                        ,ValueCutoffCounts=("ValueRequirementMet","sum")).reset_index().head()
# Out:
#    season  bookie  BookieAcc  ModelAcc  ModelReturns  ValueAcc  ValueReturns  \
# 0    2014  Bet365   0.541667  0.522222        -11.95  0.294444        176.95
# 1    2015  Bet365   0.478610  0.470588       -172.15  0.299465        220.85
# 2    2016  Bet365   0.613757  0.608466        207.50  0.256614        -49.10
# 3    2017  Bet365   0.550532  0.542553       -100.25  0.265957         72.20
# 4    2018  Bet365   0.588235  0.585561         96.10  0.259358        142.80
#
#    ValueCutoffReturns  Counts  ValueCutoffCounts
# 0               89.80     360                144
# 1              150.15     374                115
# 2              -34.75     378                161
# 3               48.20     376                156
# 4             -149.75     374                187

# %%
for i in [2014,2015,2016,2017,2018]:
    log_test = gambling_output[gambling_output["season"]==i].copy()
    y = log_test["Result"]
    le = LabelEncoder()
    y = le.fit_transform(y)
    print(str(i) + " Model log loss " + str(metrics.log_loss(y,log_test[["Model_Prob_A","Model_Prob_D","Model_Prob_H"]])))
    print(str(i) + " Bookie log loss " + str(metrics.log_loss(y,log_test[["BookieAwayProb","BookieDrawProb","BookieHomeProb"]])))
# Out:
# 2014 Model log loss 0.9740967263566845
# 2014 Bookie log loss 0.9715931068323761
# 2015 Model log loss 1.0299383964988955
# 2015 Bookie log loss 1.0338599362386478
# 2016 Model log loss 0.9195670331557553
# 2016 Bookie log loss 0.9051049304960634
# 2017 Model log loss 0.9541627959429445
# 2017 Bookie log loss 0.946345472351005
# 2018 Model log loss 0.9391559561098677
# 2018 Bookie log loss 0.8933418817468733

# %% [markdown]
# # Try Transfermarkt variables

# %% [markdown]
# ## Read in files

# %%
transfermarkt = pd.read_csv(r"C:\\Users\Byron\Documents\Football Predictions\PremierLeaguePredictions\data\TransferMarkt.csv")
transfermarkt.tail()
# Out:
#      Season                  Club  Squad   Age  Foreigners  TotalMarket   \
# 115    2014          Swansea City     36  24.3          30         96.93
# 116    2014  West Bromwich Albion     34  25.5          22         90.54
# 117    2014        Crystal Palace     42  26.0          25         80.37
# 118    2014        Leicester City     37  25.9          18         50.27
# 119    2014            Burnley FC     30  25.5          13         33.08
#
#      AverageMarketValue
# 115                2.69
# 116                2.66
# 117                1.91
# 118                1.36
# 119                1.10

# %%
TeamNames = pd.read_csv(r"C:\\Users\Byron\Documents\Football Predictions\PremierLeaguePredictions\data\PremTeamNamesLookup.csv")
TeamNames.tail()
# Out:
#    league FootballData                Understat                  FFScout  \
# 25    EPL    Tottenham                Tottenham        Tottenham Hotspur
# 26    EPL      Watford                  Watford                  Watford
# 27    EPL    West Brom     West Bromwich Albion     West Bromwich Albion
# 28    EPL     West Ham                 West Ham          West Ham United
# 29    EPL       Wolves  Wolverhampton Wanderers  Wolverhampton Wanderers
#
#               Transfermarkt
# 25        Tottenham Hotspur
# 26               Watford FC
# 27     West Bromwich Albion
# 28          West Ham United
# 29  Wolverhampton Wanderers

# %%
def lookupclean(lkup,newFile,newFileName,keepName,joinName):
    output = lkup[[keepName,joinName]].copy()
    output = pd.merge(output,newFile,left_on=joinName,right_on=newFileName)
    output = output.drop([joinName,newFileName],axis=1)
    return output

transfermarkt_clean = lookupclean(TeamNames,transfermarkt,"Club","FFScout","Transfermarkt")
transfermarkt_clean.head()
# Out:
#    FFScout  Season  Squad   Age  Foreigners  TotalMarket   AverageMarketValue
# 0  Arsenal    2018     42  23.9          28        533.97               12.71
# 1  Arsenal    2019     27  25.6          19        521.42               19.31
# 2  Arsenal    2017     45  23.8          27        570.51               12.68
# 3  Arsenal    2016     42  23.7          26        470.48               11.20
# 4  Arsenal    2015     41  23.7          29        367.74                8.97

# %%
AMVMean =(transfermarkt_clean.groupby("Season")[["AverageMarketValue"]].mean().reset_index().rename(columns={"AverageMarketValue":"AVMMean"}))
AMVMean
# Out:
#    Season  AVMMean
# 0    2014   4.8385
# 1    2015   4.9035
# 2    2016   5.9715
# 3    2017   7.4330
# 4    2018   9.4475
# 5    2019  13.8625

# %%
tm = pd.merge(transfermarkt_clean,AMVMean)
tm["AMVIndex"]=tm["AverageMarketValue"]/tm["AVMMean"]

tm.head()
# Out:
#                     FFScout  Season  Squad   Age  Foreigners  TotalMarket   \
# 0                   Arsenal    2018     42  23.9          28        533.97
# 1               Bournemouth    2018     37  24.7          16        155.52
# 2  Brighton and Hove Albion    2018     41  24.8          29        155.39
# 3                   Burnley    2018     33  27.1          14        167.18
# 4              Cardiff City    2018     35  26.3          32         68.40
#
#    AverageMarketValue  AVMMean  AMVIndex
# 0               12.71   9.4475  1.345329
# 1                4.20   9.4475  0.444562
# 2                3.79   9.4475  0.401164
# 3                5.07   9.4475  0.536650
# 4                1.95   9.4475  0.206404

# %% [markdown]
# ## Best Logistic Regression features

# %%
model_base = create_model_base(training,ema_no_reset,30,features,target_goals,merge_vars,
                                      calculated_features,single_line)

# %%
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["HomeTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Home"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["AwayTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Away"}).drop(["FFScout","Season"],axis=1)

# %%
model_base.head()
# Out:
#    season           matchid  gw_no                                   fixture  \
# 0    2014  /matches/755324/      3              Burnley vs Manchester United
# 1    2014  /matches/755400/     10      Manchester City vs Manchester United
# 2    2014  /matches/755580/     28     Newcastle United vs Manchester United
# 3    2014  /matches/755519/     22  Queens Park Rangers vs Manchester United
# 4    2014  /matches/755561/     26         Swansea City vs Manchester United
#
#              matchdate             HomeTeam           AwayTeam  HomeGoals  \
# 0  2014-08-30 12:45:00              Burnley  Manchester United          0
# 1  2014-11-02 13:30:00      Manchester City  Manchester United          1
# 2  2015-03-04 19:45:00     Newcastle United  Manchester United          0
# 3  2015-01-17 15:00:00  Queens Park Rangers  Manchester United          0
# 4  2015-02-21 15:00:00         Swansea City  Manchester United          2
#
#    AwayGoals Result  f_HmGame_Home  f_Possession_Home  \
# ...

# %%
X = model_base[classifier_calc_vars + ["f_AMVIndex_Home","f_AMVIndex_Away"]]
y = model_base["Result"]
le = LabelEncoder()
y = le.fit_transform(y)

rf2_logloss = cross_val_score(rf2, X, y, scoring="neg_log_loss", cv=kfold).mean()
rf2_accuracy = cross_val_score(rf2, X, y, scoring="accuracy", cv=kfold).mean()

lr_logloss = cross_val_score(lr, X, y, scoring="neg_log_loss", cv=kfold).mean()
lr_accuracy = cross_val_score(lr, X, y, scoring="accuracy", cv=kfold).mean()

print("RF2 " + str(rf2_logloss)+" "+ str(rf2_accuracy))
print("LR " + str(lr_logloss)+" "+ str(lr_accuracy))
# Out:
# RF2 -0.9853453833886002 0.531595598038551
# LR -0.9777830151877559 0.5322622195105416

# %%
clf_lr = lr.fit(X,y)

# %%
model_ema = create_model_base(results,ema_no_reset,30,features,target_goals,merge_vars,
                                      calculated_features,single_line)
model_ema = pd.merge(model_ema,tm[["FFScout","Season","AMVIndex"]],left_on=["HomeTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Home"}).drop(["FFScout","Season"],axis=1)
model_ema = pd.merge(model_ema,tm[["FFScout","Season","AMVIndex"]],left_on=["AwayTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Away"}).drop(["FFScout","Season"],axis=1)

model_base = create_model_probs_df(model_ema,[2014,2015,2016,2017,2018],clf_lr,classifier_calc_vars + ["f_AMVIndex_Home","f_AMVIndex_Away"],
                                  list(le.classes_),gamble_cols)
odds_preds = pd.merge(model_base,odds_clean, on =["season","fixture"], how ="inner")
odds_preds = odds_preds.rename(columns={"FTR":"Result"})
gambling_df = odds_preds.copy()
gambling_output = full_gambling_calc(odds_preds,stake,bookie_home_prob,bookie_draw_prob,bookie_away_prob,model_home,model_draw,model_away)

gambling_output["ValueRequirementMet"] = gambling_output.apply(lambda row: bet_index_cutoff(1.1,row["BestValueIndex"]),axis=1)
gambling_output["ModelPredProfit"] = gambling_output.apply(lambda row: 
                                                           bet_profit(row["ModelPredCorrect"],row["ResultReturns"],1,row["Stake"])
                                                          ,axis=1)
gambling_output["ValuePredProfit"] = gambling_output.apply(lambda row: 
                                                           bet_profit(row["ValuePredCorrect"],row["ResultReturns"],1,row["Stake"])
                                                          ,axis=1)
gambling_output["ValueCutoffProfit"] = gambling_output.apply(lambda row: 
                                                           bet_profit(row["ValuePredCorrect"],row["ResultReturns"]
                                                                      ,row["ValueRequirementMet"],row["Stake"])
                                                          ,axis=1)
gambling_output.groupby(["season","bookie"]).agg(BookieAcc=("BookiePredCorrect","mean")
                                        ,ModelAcc=("ModelPredCorrect","mean")
                                        ,ModelReturns=("ModelPredProfit","sum")
                                        ,ValueAcc=("ValuePredCorrect","mean")
                                        ,ValueReturns=("ValuePredProfit","sum")
                                        ,ValueCutoffReturns=("ValueCutoffProfit","sum")
                                        #,ModelResultProb=("FinalResultProb","mean")
                                        ,Counts=("fixture","nunique")
                                        ,ValueCutoffCounts=("ValueRequirementMet","sum")).reset_index().head()
# Out:
#    season  bookie  BookieAcc  ModelAcc  ModelReturns  ValueAcc  ValueReturns  \
# 0    2014  Bet365   0.541667  0.541667         20.30  0.325000        193.85
# 1    2015  Bet365   0.478610  0.451872       -295.15  0.312834        -89.20
# 2    2016  Bet365   0.613757  0.603175        140.50  0.312169        158.20
# 3    2017  Bet365   0.550532  0.553191        -56.70  0.289894        159.20
# 4    2018  Bet365   0.588235  0.588235         33.05  0.294118        162.60
#
#    ValueCutoffReturns  Counts  ValueCutoffCounts
# 0              323.20     360                225
# 1             -132.60     374                196
# 2               99.60     378                226
# 3              284.45     376                197
# 4               61.85     374                223

# %% [markdown]
# ## Best RF Base

# %%
model_base = create_model_base_scaled(training,ema_no_reset,22,features,standard_scaler,
                                     target_goals,merge_vars,calculated_features,single_line)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["HomeTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Home"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["AwayTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Away"}).drop(["FFScout","Season"],axis=1)

# %%
X = model_base[classifier_vars+classifier_calc_vars + ["f_AMVIndex_Home","f_AMVIndex_Away"]]
y = model_base["Result"]
le = LabelEncoder()
y = le.fit_transform(y)

rf2_logloss = cross_val_score(rf2, X, y, scoring="neg_log_loss", cv=kfold).mean()
rf2_accuracy = cross_val_score(rf2, X, y, scoring="accuracy", cv=kfold).mean()

lr_logloss = cross_val_score(lr, X, y, scoring="neg_log_loss", cv=kfold).mean()
lr_accuracy = cross_val_score(lr, X, y, scoring="accuracy", cv=kfold).mean()

print("RF2 " + str(rf2_logloss)+" "+ str(rf2_accuracy))
print("LR " + str(lr_logloss)+" "+ str(lr_accuracy))
# Out:
# RF2 -0.9834727180262419 0.5309221973651503
# LR -1.0218833610910725 0.5020540980272523

# %% [markdown]
# ## RFECV

# %%
rfecv = RFECV(estimator=rf2, step=1, cv=StratifiedKFold(n_splits=10, random_state=42), scoring='neg_log_loss')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
# Out:
# Optimal number of features: 41

# %%
plt.figure(figsize=(6, 4))
plt.title('Recursive Feature Elimination with Cross-Validation', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of features selected', fontsize=14, labelpad=20)
plt.ylabel('Mean Squared Error', fontsize=14, labelpad=20)
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_*-1, color='#303F9F', linewidth=3)

plt.show()

# %%
dset = pd.DataFrame()
dset['attr'] = X.columns[rfecv.support_]
dset['importance'] = rfecv.estimator_.feature_importances_

dset = dset.sort_values(by='importance', ascending=False)


plt.figure(figsize=(8, 15))
plt.barh(y=dset['attr'], width=dset['importance'], color='#1976D2')
plt.title('RFECV - Feature Importances', fontsize=20, fontweight='bold', pad=20)
plt.xlabel('Importance', fontsize=14, labelpad=20)
plt.show()

# %% [markdown]
# ## Restrict Vars

# %%
rf_simple_vars = dset.reset_index().iloc[:15]["attr"].tolist()
print(rf_simple_vars)
# Out:
# ['f_AMVIndex_Away', 'f_Shots On Target_Home', 'f_Touches - Final Third_Home', 'f_Passes - Final Third - Successful_Home', 'f_AMVIndex_Home', 'f_xGRatio_Away', 'f_Goal Attempts In Box Conceded_Away', 'f_Touches - Penalty Area_Away', 'f_netxg_Home', 'f_netxg_Away', 'f_US xG_Away', 'f_Touches - Final Third log_Home', 'f_Chances Created_Home', 'f_Shots - Inside Box_Home', 'f_xGRatio_Home']

# %%
X = model_base[rf_simple_vars]
y = model_base["Result"]
le = LabelEncoder()
y = le.fit_transform(y)

rf2_logloss = cross_val_score(rf2, X, y, scoring="neg_log_loss", cv=kfold).mean()
rf2_accuracy = cross_val_score(rf2, X, y, scoring="accuracy", cv=kfold).mean()

lr_logloss = cross_val_score(lr, X, y, scoring="neg_log_loss", cv=kfold).mean()
lr_accuracy = cross_val_score(lr, X, y, scoring="accuracy", cv=kfold).mean()

print("RF2 " + str(rf2_logloss)+" "+ str(rf2_accuracy))
print("LR " + str(lr_logloss)+" "+ str(lr_accuracy))
# Out:
# RF2 -0.9819781955888022 0.533609020857343
# LR -0.9835464823033746 0.5342733825955303

# %%
clf_rf = rf2.fit(X,y)

# %% [markdown]
# ## Compare profit

# %%
model_ema = create_model_base_scaled(results,ema_no_reset,22,features,standard_scaler,
                                     target_goals,merge_vars,calculated_features,single_line)
model_ema = pd.merge(model_ema,tm[["FFScout","Season","AMVIndex"]],left_on=["HomeTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Home"}).drop(["FFScout","Season"],axis=1)
model_ema = pd.merge(model_ema,tm[["FFScout","Season","AMVIndex"]],left_on=["AwayTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Away"}).drop(["FFScout","Season"],axis=1)

model_base = create_model_probs_df(model_ema,[2014,2015,2016,2017,2018],clf_rf,rf_simple_vars,
                                  list(le.classes_),gamble_cols)
odds_preds = pd.merge(model_base,odds_clean, on =["season","fixture"], how ="inner")
odds_preds = odds_preds.rename(columns={"FTR":"Result"})
gambling_df = odds_preds.copy()
gambling_output = full_gambling_calc(odds_preds,stake,bookie_home_prob,bookie_draw_prob,bookie_away_prob,model_home,model_draw,model_away)

gambling_output["ValueRequirementMet"] = gambling_output.apply(lambda row: bet_index_cutoff(1.1,row["BestValueIndex"]),axis=1)
gambling_output["ModelPredProfit"] = gambling_output.apply(lambda row: 
                                                           bet_profit(row["ModelPredCorrect"],row["ResultReturns"],1,row["Stake"])
                                                          ,axis=1)
gambling_output["ValuePredProfit"] = gambling_output.apply(lambda row: 
                                                           bet_profit(row["ValuePredCorrect"],row["ResultReturns"],1,row["Stake"])
                                                          ,axis=1)
gambling_output["ValueCutoffProfit"] = gambling_output.apply(lambda row: 
                                                           bet_profit(row["ValuePredCorrect"],row["ResultReturns"]
                                                                      ,row["ValueRequirementMet"],row["Stake"])
                                                          ,axis=1)
gambling_output.groupby(["season","bookie"]).agg(BookieAcc=("BookiePredCorrect","mean")
                                        ,ModelAcc=("ModelPredCorrect","mean")
                                        ,ModelReturns=("ModelPredProfit","sum")
                                        ,ValueAcc=("ValuePredCorrect","mean")
                                        ,ValueReturns=("ValuePredProfit","sum")
                                        ,ValueCutoffReturns=("ValueCutoffProfit","sum")
                                        #,ModelResultProb=("FinalResultProb","mean")
                                        ,Counts=("fixture","nunique")
                                        ,ValueCutoffCounts=("ValueRequirementMet","sum")).reset_index().head()
# Out:
#    season  bookie  BookieAcc  ModelAcc  ModelReturns  ValueAcc  ValueReturns  \
# 0    2014  Bet365   0.541667  0.516667        -60.60  0.280556         83.25
# 1    2015  Bet365   0.478610  0.486631       -110.00  0.299465        176.50
# 2    2016  Bet365   0.613757  0.608466        206.50  0.264550         -0.75
# 3    2017  Bet365   0.550532  0.545213        -65.25  0.265957        127.00
# 4    2018  Bet365   0.588235  0.588235         89.05  0.270053        201.55
#
#    ValueCutoffReturns  Counts  ValueCutoffCounts
# 0              119.15     360                267
# 1              215.15     374                242
# 2              138.35     378                261
# 3              239.65     376                273
# 4              123.70     374                282

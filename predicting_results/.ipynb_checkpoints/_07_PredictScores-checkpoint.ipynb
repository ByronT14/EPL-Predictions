# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Read-In" data-toc-modified-id="Read-In-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Read In</a></span><ul class="toc-item"><li><span><a href="#Import-custom-functions" data-toc-modified-id="Import-custom-functions-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Import custom functions</a></span></li><li><span><a href="#Read-in-Files" data-toc-modified-id="Read-in-Files-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Read in Files</a></span><ul class="toc-item"><li><span><a href="#Results-and-model-data" data-toc-modified-id="Results-and-model-data-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Results and model data</a></span></li><li><span><a href="#Bookie-Data" data-toc-modified-id="Bookie-Data-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Bookie Data</a></span></li><li><span><a href="#Teamnames-Lookup" data-toc-modified-id="Teamnames-Lookup-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Teamnames Lookup</a></span></li><li><span><a href="#Transfermarkt" data-toc-modified-id="Transfermarkt-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Transfermarkt</a></span></li><li><span><a href="#XG-Predictions-file" data-toc-modified-id="XG-Predictions-file-1.2.5"><span class="toc-item-num">1.2.5&nbsp;&nbsp;</span>XG Predictions file</a></span></li></ul></li><li><span><a href="#Create-single-line-df" data-toc-modified-id="Create-single-line-df-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Create single line df</a></span></li><li><span><a href="#Feature-labelling" data-toc-modified-id="Feature-labelling-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Feature labelling</a></span><ul class="toc-item"><li><span><a href="#Split-out-seasons" data-toc-modified-id="Split-out-seasons-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Split out seasons</a></span></li><li><span><a href="#Create-target-goals-dataframe" data-toc-modified-id="Create-target-goals-dataframe-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Create target goals dataframe</a></span></li><li><span><a href="#Variable-lists" data-toc-modified-id="Variable-lists-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Variable lists</a></span></li><li><span><a href="#Scaling" data-toc-modified-id="Scaling-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>Scaling</a></span></li></ul></li></ul></li><li><span><a href="#Predict-HomeGoals" data-toc-modified-id="Predict-HomeGoals-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Predict HomeGoals</a></span><ul class="toc-item"><li><span><a href="#Linear-Regression-to-predict-Home-Goals" data-toc-modified-id="Linear-Regression-to-predict-Home-Goals-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Linear Regression to predict Home Goals</a></span><ul class="toc-item"><li><span><a href="#RFECV-to-identify-variables" data-toc-modified-id="RFECV-to-identify-variables-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>RFECV to identify variables</a></span></li><li><span><a href="#Compare-Mean-squared-error-for-linear-regression" data-toc-modified-id="Compare-Mean-squared-error-for-linear-regression-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Compare Mean squared error for linear regression</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Summary</a></span></li></ul></li><li><span><a href="#Statsmodels-Regression" data-toc-modified-id="Statsmodels-Regression-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Statsmodels Regression</a></span></li><li><span><a href="#Linear-Regression-to-predict-Home-Goals-with-XG-Cols" data-toc-modified-id="Linear-Regression-to-predict-Home-Goals-with-XG-Cols-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Linear Regression to predict Home Goals with XG Cols</a></span><ul class="toc-item"><li><span><a href="#RFECV-to-identify-variables" data-toc-modified-id="RFECV-to-identify-variables-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>RFECV to identify variables</a></span></li><li><span><a href="#Compare-Mean-squared-error-for-linear-regression" data-toc-modified-id="Compare-Mean-squared-error-for-linear-regression-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Compare Mean squared error for linear regression</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Summary</a></span></li></ul></li><li><span><a href="#Predict-Using-XG-Cols-and-Random-Forest" data-toc-modified-id="Predict-Using-XG-Cols-and-Random-Forest-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Predict Using XG Cols and Random Forest</a></span><ul class="toc-item"><li><span><a href="#Summary" data-toc-modified-id="Summary-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Summary</a></span></li></ul></li></ul></li><li><span><a href="#Predict-Away-Goals" data-toc-modified-id="Predict-Away-Goals-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Predict Away Goals</a></span></li><li><span><a href="#Goal-Difference-Regression" data-toc-modified-id="Goal-Difference-Regression-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Goal Difference Regression</a></span></li><li><span><a href="#Attacking-Strength" data-toc-modified-id="Attacking-Strength-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Attacking Strength</a></span><ul class="toc-item"><li><span><a href="#Using-Home-Advantage" data-toc-modified-id="Using-Home-Advantage-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Using Home Advantage</a></span></li><li><span><a href="#Test-without-Home-Advantage" data-toc-modified-id="Test-without-Home-Advantage-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Test without Home Advantage</a></span></li></ul></li><li><span><a href="#Defensive-Strength" data-toc-modified-id="Defensive-Strength-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Defensive Strength</a></span><ul class="toc-item"><li><span><a href="#Using-Home-Advantage" data-toc-modified-id="Using-Home-Advantage-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Using Home Advantage</a></span></li><li><span><a href="#Without-home-Advantage" data-toc-modified-id="Without-home-Advantage-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Without home Advantage</a></span></li></ul></li><li><span><a href="#Single-line-predictions" data-toc-modified-id="Single-line-predictions-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Single line predictions</a></span></li><li><span><a href="#Predict-Result" data-toc-modified-id="Predict-Result-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Predict Result</a></span></li></ul></div>

# %% [markdown]
# # Read In

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import log_loss


from sklearn.preprocessing import LabelEncoder,StandardScaler, MinMaxScaler
from sklearn.model_selection import StratifiedKFold, cross_val_score, cross_val_predict
from sklearn import ensemble, metrics, model_selection as ms, preprocessing, tree
from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline
from sklearn import linear_model as lm
from sklearn import svm
from sklearn import neighbors
from sklearn import linear_model, tree, discriminant_analysis, naive_bayes, ensemble, gaussian_process

import statsmodels.api as sm
import statsmodels.formula.api as smf
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 70)
import datetime


from pathlib import Path
import os
from os import listdir
from os.path import isfile, join

from sklearn.feature_selection import RFECV

# %% [markdown]
# ## Import custom functions

# %%
import path

print(path.Path.getcwd())
print(path.Path('../predicting_results').isdir())
if path.Path('../predicting_results').isdir():
    with path.Path('..'):
        print(path.Path.getcwd())
        import _00_BettingFunctions
        print('Success!')
print(path.Path.getcwd())
# Out:
# C:\Users\Byron\Documents\Football Predictions\PremierLeaguePredictions\git-repo\predicting_results
# True
# C:\Users\Byron\Documents\Football Predictions\PremierLeaguePredictions\git-repo
# Success!
# C:\Users\Byron\Documents\Football Predictions\PremierLeaguePredictions\git-repo\predicting_results

# %%
from _00_BettingFunctions import (ema_no_reset, moving_average_no_reset, restructure_ema, create_model_base,
                              optimise_alpha_classifier,optimise_alpha,track_best_span,create_model_probs_df,returns,expected_returns,result_returns,
                              determine_bet,most_likely_result,prediction_correct,bet_index_cutoff,bet_profit,
                              full_gambling_calc,create_model_base_scaled,full_gambling_calc_cutoff)

# %% [markdown]
# ## Read in Files

# %% [markdown]
# ### Results and model data

# %%
results = pd.read_csv(r"C:\\Users\Byron\Documents\Football Predictions\PremierLeaguePredictions\data\ff_us_1419.csv").drop("Unnamed: 0",axis=1)
results.tail()
# Out:
#       season     gameweek            matchid  \
# 4351    2019  Gameweek 28  /matches/1059980/
# 4352    2019  Gameweek 28  /matches/1059975/
# 4353    2019  Gameweek 28  /matches/1059975/
# 4354    2019  Gameweek 28  /matches/1059979/
# 4355    2019  Gameweek 28  /matches/1059979/
#
#                                            fixture            matchdate  \
# 4351                          Watford vs Liverpool  2020-02-29 17:30:00
# 4352                  Everton vs Manchester United  2020-03-01 14:00:00
# 4353                  Everton vs Manchester United  2020-03-01 14:00:00
# 4354  Tottenham Hotspur vs Wolverhampton Wanderers  2020-03-01 14:00:00
# 4355  Tottenham Hotspur vs Wolverhampton Wanderers  2020-03-01 14:00:00
#
#                        f_Team  f_HmGame  f_Possession  \
# 4351                Liverpool         0          71.0
# 4352                  Everton         1          43.1
# 4353        Manchester United         0          56.9
# ...

# %% [markdown]
# ### Bookie Data

# %%
odds = pd.read_csv(r"C:\\Users\Byron\Documents\Football Predictions\PremierLeaguePredictions\data\bookie_odds.csv").drop("Unnamed: 0",axis=1)
odds_clean = odds[["season","fixture","FTR","bookie","BookieHomeOdds","BookieDrawOdds"
                  ,"BookieAwayOdds","BookieHomeProb","BookieDrawProb","BookieAwayProb"]].copy()
odds_clean.tail()
# Out:
#       season                             fixture FTR  bookie  BookieHomeOdds  \
# 2183    2018        Huddersfield Town vs Arsenal   A  Bet365            5.75
# 2184    2018                   Fulham vs Arsenal   A  Bet365            5.25
# 2185    2018  Wolverhampton Wanderers vs Arsenal   H  Bet365            2.90
# 2186    2018             Cardiff City vs Arsenal   A  Bet365            6.50
# 2187    2019         Sheffield United vs Arsenal   H  Bet365            3.90
#
#       BookieDrawOdds  BookieAwayOdds  BookieHomeProb  BookieDrawProb  \
# 2183            4.40            1.60        0.173913        0.227273
# 2184            4.33            1.66        0.190476        0.230947
# 2185            3.50            2.55        0.344828        0.285714
# 2186            4.33            1.57        0.153846        0.230947
# 2187            3.75            1.90        0.256410        0.266667
#
#       BookieAwayProb
# 2183        0.625000
# 2184        0.602410
# ...

# %%
merge_vars = ["season","matchid","gw_no","fixture","matchdate"]
team_vars = ["HomeTeam","AwayTeam"]
pred_cols = ["Model_Prob_"+col for col in ["A","D","H"]]
gamble_cols = merge_vars + team_vars + pred_cols
print(gamble_cols)
# Out:
# ['season', 'matchid', 'gw_no', 'fixture', 'matchdate', 'HomeTeam', 'AwayTeam', 'Model_Prob_A', 'Model_Prob_D', 'Model_Prob_H']

# %%
bookie_home_odds = "BookieHomeOdds"
bookie_draw_odds = "BookieDrawOdds"
bookie_away_odds = "BookieAwayOdds"
bookie_home_prob = "BookieHomeProb"
bookie_draw_prob = "BookieDrawProb"
bookie_away_prob = "BookieAwayProb"

model_home = "Model_Prob_H"
model_draw = "Model_Prob_D"
model_away = "Model_Prob_A"

stake = 5

# %% [markdown]
# ### Teamnames Lookup

# %%
TeamNames = pd.read_csv(r"C:\\Users\Byron\Documents\Football Predictions\PremierLeaguePredictions\data\PremTeamNamesLookup.csv")
TeamNames.tail(25)
# Out:
#    league      FootballData                Understat                  FFScout  \
# 5     EPL           Cardiff                  Cardiff             Cardiff City
# 6     EPL           Chelsea                  Chelsea                  Chelsea
# 7     EPL    Crystal Palace           Crystal Palace           Crystal Palace
# 8     EPL           Everton                  Everton                  Everton
# 9     EPL            Fulham                   Fulham                   Fulham
# 10    EPL      Huddersfield             Huddersfield        Huddersfield Town
# 11    EPL              Hull                     Hull                Hull City
# 12    EPL         Leicester                Leicester           Leicester City
# 13    EPL         Liverpool                Liverpool                Liverpool
# 14    EPL          Man City          Manchester City          Manchester City
# 15    EPL        Man United        Manchester United        Manchester United
# ...

# %% [markdown]
# ### Transfermarkt

# %%
transfermarkt = pd.read_csv(r"C:\\Users\Byron\Documents\Football Predictions\PremierLeaguePredictions\data\TransferMarkt.csv")
transfermarkt.tail()
# Out:
#      Season                  Club  Squad   Age  Foreigners  TotalMarket   \
# 115    2014          Swansea City     36  24.3          30         96.93
# 116    2014  West Bromwich Albion     34  25.5          22         90.54
# 117    2014        Crystal Palace     42  26.0          25         80.37
# 118    2014        Leicester City     37  25.9          18         50.27
# 119    2014            Burnley FC     30  25.5          13         33.08
#
#      AverageMarketValue
# 115                2.69
# 116                2.66
# 117                1.91
# 118                1.36
# 119                1.10

# %%
def lookupclean(lkup,newFile,newFileName,keepName,joinName):
    output = lkup[[keepName,joinName]].copy()
    output = pd.merge(output,newFile,left_on=joinName,right_on=newFileName)
    output = output.drop([joinName,newFileName],axis=1)
    return output

transfermarkt_clean = lookupclean(TeamNames,transfermarkt,"Club","FFScout","Transfermarkt")
transfermarkt_clean.head()
# Out:
#    FFScout  Season  Squad   Age  Foreigners  TotalMarket   AverageMarketValue
# 0  Arsenal    2018     42  23.9          28        533.97               12.71
# 1  Arsenal    2019     27  25.6          19        521.42               19.31
# 2  Arsenal    2017     45  23.8          27        570.51               12.68
# 3  Arsenal    2016     42  23.7          26        470.48               11.20
# 4  Arsenal    2015     41  23.7          29        367.74                8.97

# %%
AMVMean =(transfermarkt_clean.groupby("Season")[["AverageMarketValue"]].mean().reset_index().rename(columns={"AverageMarketValue":"AVMMean"}))
AMVMean

tm = pd.merge(transfermarkt_clean,AMVMean)
tm["AMVIndex"]=tm["AverageMarketValue"]/tm["AVMMean"]

tm.head()
# Out:
#                     FFScout  Season  Squad   Age  Foreigners  TotalMarket   \
# 0                   Arsenal    2018     42  23.9          28        533.97
# 1               Bournemouth    2018     37  24.7          16        155.52
# 2  Brighton and Hove Albion    2018     41  24.8          29        155.39
# 3                   Burnley    2018     33  27.1          14        167.18
# 4              Cardiff City    2018     35  26.3          32         68.40
#
#    AverageMarketValue  AVMMean  AMVIndex
# 0               12.71   9.4475  1.345329
# 1                4.20   9.4475  0.444562
# 2                3.79   9.4475  0.401164
# 3                5.07   9.4475  0.536650
# 4                1.95   9.4475  0.206404

# %% [markdown]
# ### XG Predictions file

# %%
xg_pred_cols = ["AttStr_Home","DefStr_Home","AttStr_Away","DefStr_Away","Pred_HG","Pred_AG"]

# %%
xg_pred = pd.read_csv(r"C:\\Users\Byron\Documents\Football Predictions\UnderstatPredictions\Datasets\xg_predictions.csv")
xg_pred = xg_pred[(xg_pred["league"]=="EPL") &
                 (xg_pred["AverageMethod"]=="EMA No reset")]

xg_pred["season"] = xg_pred["season"].apply(lambda x: x[:4])

xg_pred_clean = xg_pred[["season","fixture","season_gw","Team_Home","Team_Away","AttStr_Home",
                  "DefStr_Home","AttStr_Away","DefStr_Away","Pred_HG","Pred_AG"]].dropna()

xg_pred_clean = lookupclean(TeamNames,xg_pred_clean,"Team_Home","FFScout","Understat").rename(columns={"FFScout":"HomeTeam"})
xg_pred_clean = lookupclean(TeamNames,xg_pred_clean,"Team_Away","FFScout","Understat").rename(columns={"FFScout":"AwayTeam"})
xg_pred_clean["fixture"] = xg_pred_clean["HomeTeam"]+ " vs " + xg_pred_clean["AwayTeam"]
xg_pred_clean["season"] = xg_pred_clean["season"].apply(lambda x: int(x))
xg_pred_clean = xg_pred_clean.drop(columns=["HomeTeam","AwayTeam"])

xg_pred_clean.sort_values(by=["season","season_gw"])
# Out:
#       season                              fixture  season_gw  AttStr_Home  \
# 37      2014            Leicester City vs Arsenal          3     0.819551
# 450     2014                   Everton vs Chelsea          3     0.891405
# 594     2014   Newcastle United vs Crystal Palace          3     0.750911
# 805     2014             Aston Villa vs Hull City          3     0.637036
# 1037    2014       Tottenham Hotspur vs Liverpool          3     1.560331
# ...      ...                                  ...        ...          ...
# 1407    2019      Manchester City vs Norwich City         38     1.725867
# 1456    2019      Southampton vs Sheffield United         38     0.992274
# 1810    2019  Crystal Palace vs Tottenham Hotspur         38     0.717594
# 1892    2019                   Arsenal vs Watford         38     1.021431
# 2174    2019   Chelsea vs Wolverhampton Wanderers         38     1.242563
#
#       DefStr_Home  AttStr_Away  DefStr_Away   Pred_HG   Pred_AG
# ...

# %%
xg_pred.head()
# Out:
#      league season                             fixture  season_gw  \
# 7344    EPL   2014        Manchester United vs Swansea          1
# 7348    EPL   2014                Leicester vs Everton          1
# 7352    EPL   2014         Queens Park Rangers vs Hull          1
# 7356    EPL   2014                Stoke vs Aston Villa          1
# 7360    EPL   2014  West Bromwich Albion vs Sunderland          1
#
#                  Team_Home    Team_Away  homegoals  awaygoals Result  \
# 7344     Manchester United      Swansea        1.0        2.0      A
# 7348             Leicester      Everton        2.0        2.0      D
# 7352   Queens Park Rangers         Hull        0.0        1.0      A
# 7356                 Stoke  Aston Villa        0.0        1.0      A
# 7360  West Bromwich Albion   Sunderland        2.0        2.0      D
#
#      AverageMethod  xG_av_Home  xGA_av_Home  AttStr_Home  DefStr_Home  \
# 7344  EMA No reset         NaN          NaN          NaN          NaN
# ...

# %% [markdown]
# ## Create single line df
# We will use our results dataset to create a single line results dataset that contains the Result. This will be our target variable.

# %%
def home_teams(df,keep):
    outdf = df.copy()
    outdf = outdf.query("f_HmGame==1")
    outdf = outdf[keep]
    outdf=outdf.rename(columns={'f_Team': 'HomeTeam'})
    return outdf

def away_teams(df,keep):
    outdf = df.copy()
    outdf = outdf.query("f_HmGame==0")
    outdf = outdf[keep]
    outdf=outdf.rename(columns={'f_Team': 'AwayTeam'})
    return outdf

def fixture_scores(df,score_keep_vars):
    outdf = df.copy()
    outdf = outdf.query("f_HmGame==1")
    outdf = outdf[score_keep_vars]
    outdf=outdf.rename(columns={'f_Goals': 'HomeGoals',
                                'f_Goals Conceded': 'AwayGoals'})
    return outdf

def join_fixtures(home,away,scores,merge_vars):
    outdf= pd.merge(home,away,on=merge_vars)
    outdf = pd.merge(outdf,scores,on=merge_vars)
    return outdf
def final_outcome(fixtures,homegoals,awaygoals):
    outdf = fixtures.copy()
    outdf["Result"] = np.where(outdf[homegoals]>outdf[awaygoals],"H",
                              np.where(outdf[homegoals]<outdf[awaygoals],"A","D"))
    return outdf

# %%
keep_vars = ["season","matchid","gw_no","fixture","matchdate","f_Team"]
score_keep_vars = ["season","matchid","gw_no","fixture","matchdate","f_Goals","f_Goals Conceded"]
merge_vars = ["season","matchid","gw_no","fixture","matchdate"]
team_vars = ["HomeTeam","AwayTeam"]

# %%
hometeams = home_teams(results,keep_vars)
awayteams = away_teams(results,keep_vars)
scores = fixture_scores(results,score_keep_vars)
single_line = join_fixtures(hometeams,awayteams,scores,merge_vars)
single_line = final_outcome(single_line,"HomeGoals","AwayGoals")
single_line.tail()
# Out:
#       season            matchid  gw_no  \
# 2173    2019  /matches/1059977/     28
# 2174    2019  /matches/1059981/     28
# 2175    2019  /matches/1059980/     28
# 2176    2019  /matches/1059975/     28
# 2177    2019  /matches/1059979/     28
#
#                                            fixture            matchdate  \
# 2173                   Newcastle United vs Burnley  2020-02-29 15:00:00
# 2174                West Ham United vs Southampton  2020-02-29 15:00:00
# 2175                          Watford vs Liverpool  2020-02-29 17:30:00
# 2176                  Everton vs Manchester United  2020-03-01 14:00:00
# 2177  Tottenham Hotspur vs Wolverhampton Wanderers  2020-03-01 14:00:00
#
#                HomeTeam                 AwayTeam  HomeGoals  AwayGoals Result
# 2173   Newcastle United                  Burnley          0          0      D
# 2174    West Ham United              Southampton          3          1      H
# ...

# %% [markdown]
# ## Feature labelling

# %% [markdown]
# **List Features**

# %%
features = [i for i in results.columns if i.startswith("f_") and i !="f_Team"]
# def_features = [i for i in features if "Conceded" in i]
# att_features = [i for i in features if i not in def_features]
# calculated_features = ["f_netxg","f_xGRatio","f_ShotsRatio","f_ShOnTargetRatio"]
# print(att_features)
# print()
# print(def_features)
# print()
# print(calculated_features)

# %%
df_null = results[features].isnull().sum()/results[features].count()

# %%
##handling nulls
df_null = results[features].isnull().sum()/results[features].count()
df_null = df_null[df_null>0]
null_vars = df_null.index.tolist()
print(null_vars)

results = results.drop(null_vars,axis=1)
# Out:
# ['f_xA Expected Assists Conceded']

# %%
results[results['season']==2014].describe().loc["max"].sort_values()
# Out:
# f_xG Open Play Conceded                            0.00000
# f_xG Conceded                                      0.00000
# f_xA Expected Assists                              0.00000
# f_xG Expected Goals                                0.00000
# f_xG Open Play                                     0.00000
# f_HmGame                                           1.00000
# f_Goals From Penalties                             2.00000
# f_Points                                           3.00000
# f_US xG Conceded                                   5.35103
# f_US xG                                            5.35103
# f_Touches - Final Third log                        6.25575
# f_Goals                                            8.00000
# f_Goals Conceded                                   8.00000
# f_Big Chances Total                                8.00000
# f_Big Chances Conceded                             8.00000
# f_Shots On Target Conceded                        16.00000
# ...

# %%
#remove variables that are blank
incomplete_vars = ["f_xG Open Play Conceded","f_xG Open Play","f_xA Expected Assists",
                   "f_xG Open Play","f_xG Expected Goals"]

# %%
features = [i for i in results.columns if i.startswith("f_") and i !="f_Team" 
            and i not in incomplete_vars]
def_features = [i for i in features if "Conceded" in i]
att_features = [i for i in features if i not in def_features]
calculated_features = ["f_netxg","f_xGRatio","f_ShotsRatio","f_ShOnTargetRatio"]
print(att_features)
print()
print(def_features)
# Out:
# ['f_HmGame', 'f_Possession', 'f_Touches - Final Third', 'f_Touches - Penalty Area', 'f_Passes - Final Third - Successful', 'f_Chances Created', 'f_Goals', 'f_Goals From Penalties', 'f_Goal Attempts', 'f_Shots - Inside Box', 'f_Big Chances Total', 'f_Shots On Target', 'f_US xG', 'f_Points', 'f_Touches - Final Third log']
#
# ['f_Goal Attempts In Box Conceded', 'f_Shots Conceded', 'f_Shots On Target Conceded', 'f_Big Chances Conceded', 'f_Goals Conceded', 'f_xG Conceded', 'f_Touches - Final Third Conceded', 'f_Touches - Penalty Area Conceded', 'f_Passes - Final Third - Successful Conceded', 'f_US xG Conceded', 'f_Chances Conceded']

# %% [markdown]
# ### Split out seasons

# %%
training = results[results["season"].isin([2014,2015,2016,2017])]
test = results[results["season"]==2018]
holdout = results[results["season"]==2019]

# %% [markdown]
# ### Create target goals dataframe
# This contains target variables for a per team modelling dataset predicting goals scored or conceded

# %%
target_goals = results[['f_Team', 'matchid','f_HmGame','f_Goals', 'f_Goals Conceded',"f_US xG", "f_US xG Conceded"]].copy() 
target_goals.columns = ['f_Team', 'matchid','f_HmGameFut','t_Goals', 't_Goals Conceded',"t_US xG", "t_US xG Conceded"]
target_goals.loc[0:,"t_Goals_Scored_In"] = np.where(target_goals["t_Goals"]>0,1,0)
target_goals.loc[0:,"t_Goals_Conceded_In"] = np.where(target_goals["t_Goals Conceded"]>0,1,0)
target_goals.head()
# Out:
#               f_Team           matchid  f_HmGameFut  t_Goals  \
# 0       Swansea City  /matches/755307/            0        2
# 1  Manchester United  /matches/755307/            1        1
# 2            Everton  /matches/755305/            0        2
# 3     Leicester City  /matches/755305/            1        2
# 4          Hull City  /matches/755309/            0        1
#
#    t_Goals Conceded   t_US xG  t_US xG Conceded  t_Goals_Scored_In  \
# 0                 1  0.278076          1.166350                  1
# 1                 2  1.166350          0.278076                  1
# 2                 2  0.613273          1.278300                  1
# 3                 2  1.278300          0.613273                  1
# 4                 0  1.117570          1.900670                  1
#
#    t_Goals_Conceded_In
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    0

# %%
target_goals[target_goals["f_Team"]== "Everton"].nunique()
# Out:
# f_Team                   1
# matchid                218
# f_HmGameFut              2
# t_Goals                  7
# t_Goals Conceded         7
# t_US xG                218
# t_US xG Conceded       218
# t_Goals_Scored_In        2
# t_Goals_Conceded_In      2
# dtype: int64

# %% [markdown]
# ### Variable lists

# %%
kfold = StratifiedKFold(n_splits=5,shuffle=True, random_state=42)

# %%
classifier_vars = [i +"_Home" for i in features] + [i + "_Away" for i in features]
classifier_att_vars = [i +"_Home" for i in att_features] + [i + "_Away" for i in att_features]
classifier_def_vars = [i +"_Home" for i in def_features] + [i + "_Away" for i in def_features]
classifier_calc_vars = [i +"_Home" for i in calculated_features] + [i + "_Away" for i in calculated_features]
print(classifier_att_vars)
# Out:
# ['f_HmGame_Home', 'f_Possession_Home', 'f_Touches - Final Third_Home', 'f_Touches - Penalty Area_Home', 'f_Passes - Final Third - Successful_Home', 'f_Chances Created_Home', 'f_Goals_Home', 'f_Goals From Penalties_Home', 'f_Goal Attempts_Home', 'f_Shots - Inside Box_Home', 'f_Big Chances Total_Home', 'f_Shots On Target_Home', 'f_US xG_Home', 'f_Points_Home', 'f_Touches - Final Third log_Home', 'f_HmGame_Away', 'f_Possession_Away', 'f_Touches - Final Third_Away', 'f_Touches - Penalty Area_Away', 'f_Passes - Final Third - Successful_Away', 'f_Chances Created_Away', 'f_Goals_Away', 'f_Goals From Penalties_Away', 'f_Goal Attempts_Away', 'f_Shots - Inside Box_Away', 'f_Big Chances Total_Away', 'f_Shots On Target_Away', 'f_US xG_Away', 'f_Points_Away', 'f_Touches - Final Third log_Away']

# %%
test_all_vars = classifier_vars + classifier_calc_vars + ["f_AMVIndex_Home","f_AMVIndex_Away"] +xg_pred_cols
non_xg_vars = classifier_vars + classifier_calc_vars + ["f_AMVIndex_Home","f_AMVIndex_Away"]

# %%
log_reg_features = ['f_Touches - Final Third_Home', 'f_Touches - Final Third log_Home'
                    , 'f_xGRatio_Away', 'f_ShotsRatio_Away', 'f_ShOnTargetRatio_Away']
lr_features_xg = ['Pred_HG', 'f_ShotsRatio_Home', 'AttStr_Away', 'f_ShotsRatio_Away', 'f_xGRatio_Away']

home_goals_home_vars = ["f_Touches - Final Third_Home","f_Touches - Penalty Area_Home","f_US xG_Home",
                       "f_ShotsRatio_Home"]
home_goals_away_vars = ["f_Touches - Penalty Area Conceded_Away","f_US xG Conceded_Away","f_Goal Attempts In Box Conceded_Away"]
away_goals_home_vars = ["f_US xG Conceded_Home","f_Shots On Target Conceded_Home","f_xGRatio_Home"]
away_goals_away_vars = ["f_Chances Created_Away","f_Goal Attempts_Away","f_Touches - Penalty Area_Away",
                       "f_US xG_Away"]
manual_trial_features = home_goals_home_vars+home_goals_away_vars+away_goals_home_vars+away_goals_away_vars

calc_and_value = classifier_calc_vars + ["f_AMVIndex_Home","f_AMVIndex_Away"]

best_rf_vars = ['f_AMVIndex_Away', 'f_Shots On Target_Home', 'f_Touches - Final Third_Home', 
                'f_Passes - Final Third - Successful_Home', 'f_AMVIndex_Home', 'f_xGRatio_Away', 
                'f_Goal Attempts In Box Conceded_Away', 'f_Touches - Penalty Area_Away', 
                'f_netxg_Home', 'f_netxg_Away', 'f_US xG_Away', 'f_Touches - Final Third log_Home', 
                'f_Chances Created_Home', 'f_Shots - Inside Box_Home', 'f_xGRatio_Home']

rf_xg_vars = ['Pred_HG', 'Pred_AG', 'f_AMVIndex_Away', 'f_ShotsRatio_Home', 
              'f_Shots - Inside Box_Away', 'AttStr_Away', 'f_Big Chances Total_Away', 
              'f_AMVIndex_Home', 'f_netxg_Home', 'f_Touches - Final Third log_Home', 
              'f_ShotsRatio_Away', 'f_Touches - Final Third log_Away', 'f_Shots On Target_Away', 
              'f_xGRatio_Away', 'f_Goal Attempts_Home']

lr_features_xg2 = ['f_Touches - Final Third log_Away', 'f_netxg_Home', 'f_ShotsRatio_Away', 
                   'f_ShOnTargetRatio_Away', 'f_AMVIndex_Home', 'AttStr_Home', 'AttStr_Away', 
                   'Pred_HG', 'Pred_AG']

# %% [markdown]
# ### Scaling

# %%
standard_scaler = StandardScaler()
min_max_scaler = MinMaxScaler()

# %%
rf = ensemble.RandomForestClassifier(n_estimators = 50,random_state=42, max_depth=2)
lr = lm.LogisticRegression(solver='lbfgs', multi_class='auto', max_iter=1000)

# %% [markdown]
# # Predict HomeGoals

# %%
model_base = create_model_base_scaled(training,ema_no_reset,36,features,standard_scaler,
                                     target_goals,merge_vars,calculated_features,single_line)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["HomeTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Home"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["AwayTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Away"}).drop(["FFScout","Season"],axis=1)

model_base = pd.merge(model_base,xg_pred_clean, on =["season","fixture"])
model_base.head()
# Out:
#    season           matchid  gw_no                                   fixture  \
# 0    2014  /matches/755324/      3              Burnley vs Manchester United
# 1    2014  /matches/755400/     10      Manchester City vs Manchester United
# 2    2014  /matches/755580/     28     Newcastle United vs Manchester United
# 3    2014  /matches/755519/     22  Queens Park Rangers vs Manchester United
# 4    2014  /matches/755561/     26         Swansea City vs Manchester United
#
#              matchdate             HomeTeam           AwayTeam  HomeGoals  \
# 0  2014-08-30 12:45:00              Burnley  Manchester United          0
# 1  2014-11-02 13:30:00      Manchester City  Manchester United          1
# 2  2015-03-04 19:45:00     Newcastle United  Manchester United          0
# 3  2015-01-17 15:00:00  Queens Park Rangers  Manchester United          0
# 4  2015-02-21 15:00:00         Swansea City  Manchester United          2
#
#    AwayGoals Result  f_HmGame_Home  f_Possession_Home  \
# ...

# %%
hg_corr = model_base[test_all_vars+["HomeGoals","AwayGoals"]].corr()[["HomeGoals","AwayGoals"]]
#ag_corr = model_base[classifier_vars + classifier_calc_vars+["AwayGoals"]].corr()[["AwayGoals"]]
# corr_goals = pd.concat([hg_corr,ag_corr],axis = 1)
hg_corr.sort_values(by="AwayGoals",ascending =False)
# Out:
#                                                    HomeGoals  AwayGoals
# AwayGoals                                          -0.111741   1.000000
# Pred_AG                                            -0.265848   0.348230
# f_Touches - Penalty Area_Away                      -0.155892   0.307878
# f_Goal Attempts_Away                               -0.146145   0.306345
# f_Chances Created_Away                             -0.140986   0.302195
# f_Shots On Target_Away                             -0.158516   0.297564
# f_ShotsRatio_Away                                  -0.168444   0.295953
# f_Shots - Inside Box_Away                          -0.156629   0.295118
# f_xGRatio_Away                                     -0.189846   0.290453
# f_US xG_Away                                       -0.173761   0.290324
# f_netxg_Away                                       -0.192627   0.290224
# AttStr_Away                                        -0.174726   0.288472
# ...

# %% [markdown]
# ## Linear Regression to predict Home Goals
# Not Including Siimple XG predictions

# %%
model_base = create_model_base_scaled(training,ema_no_reset,36,features,standard_scaler,
                                     target_goals,merge_vars,calculated_features,single_line)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["HomeTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Home"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["AwayTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Away"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,xg_pred_clean, on =["season","fixture"])
y = model_base["HomeGoals"]
X = model_base[classifier_vars + classifier_calc_vars + ["f_AMVIndex_Home","f_AMVIndex_Away"]]

# %% [markdown]
# ### RFECV to identify variables

# %%
rfmod = lm.LinearRegression()
rfecv = RFECV(estimator=rfmod, step=1, cv=StratifiedKFold(n_splits=10, random_state=42), scoring='neg_mean_squared_error')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# Optimal number of features: 6

# %%
plt.figure(figsize=(6, 4))
plt.title('Recursive Feature Elimination with Cross-Validation', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of features selected', fontsize=14, labelpad=20)
plt.ylabel('Mean Squared Error', fontsize=14, labelpad=20)
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_*-1, color='#303F9F', linewidth=3)

plt.show()

# %% [markdown]
# **Let's look at which variables have come out as the best variables to use**

# %%
lnr_hg_vars = list(X.columns[rfecv.support_])
print(lnr_hg_vars)
# Out:
# ['f_Shots On Target_Home', 'f_Goal Attempts_Away', 'f_Shots On Target_Away', 'f_ShotsRatio_Home', 'f_ShotsRatio_Away', 'f_ShOnTargetRatio_Away']

# %% [markdown]
# ### Compare Mean squared error for linear regression

# %%
y = model_base["HomeGoals"]
X = X[X.columns[rfecv.support_]]
cross_val_score(rfmod,X,y,scoring="neg_mean_squared_error",cv =kfold).mean()
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# -1.5005130505263453

# %% [markdown]
# Log Loss for "Simple" Goals Prediction

# %%
metrics.mean_squared_error(model_base["HomeGoals"],model_base["Pred_HG"])
# Out:
# 1.518768240606013

# %% [markdown]
# ### Summary
# Linear regression for home goals doesn't outperform the simple formula for predictions

# %%
cv_scores = []
lowest_span = 2
for span in range(2, 38, 2):
    model_base = create_model_base_scaled(training,ema_no_reset,span,features,standard_scaler,
                                         target_goals,merge_vars,calculated_features,single_line)
    model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["HomeTeam","season"],
             right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Home"}).drop(["FFScout","Season"],axis=1)
    model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["AwayTeam","season"],
             right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Away"}).drop(["FFScout","Season"],axis=1)
    model_base = pd.merge(model_base,xg_pred_clean, on =["season","fixture"])
    error = optimise_alpha(model_base,lnr_gf_vars,"HomeGoals",lm.LinearRegression())
    cv_scores.append(error)
    if error == max(cv_scores):
        lowest_span = span

plt.style.use('ggplot')
plt.plot(list(range(2, 38, 2)), (pd.Series(cv_scores)*-1), label="linear regression") # Plot our result
plt.title("Optimising span for predicted Goals Scored")
plt.xlabel("Span of games")
plt.ylabel("Mean Squared Error")
plt.legend()
print("The lowest span occured at " +str(lowest_span))
print("The lowest error was " +str(max(cv_scores)))
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# ...

# %% [markdown]
# ## Statsmodels Regression

# %%
##We will clean up the naming conventions of our variables to remove spaces and dashes.

model_base = create_model_base_scaled(training,ema_no_reset,36,features,standard_scaler,
                                     target_goals,merge_vars,calculated_features,single_line)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["HomeTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Home"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["AwayTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Away"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,xg_pred_clean, on =["season","fixture"])

model_base.columns = model_base.columns.str.replace(' ', '_')
model_base.columns = model_base.columns.str.replace('-', '')

features_ns = [i.replace(' ', '_') for i in test_all_vars]
features_ns = [i.replace('-', '') for i in features_ns]

X = model_base[features_ns].copy()
y = model_base["HomeGoals"].copy()
y = y.apply(lambda x: float(x))

#print(features_ns)
formula = 'HomeGoals ~ ' + ' + '.join(x for x in features_ns)
#print(formula)
X1 = X.copy()
X1 = sm.add_constant(X1)

# model = smf.ols(
#     formula,
#     data=ema_target
# ).fit()

model = sm.OLS(y,X1).fit()

model.summary()
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              HomeGoals   R-squared:                       0.165
# Model:                            OLS   Adj. R-squared:                  0.126
# Method:                 Least Squares   F-statistic:                     4.188
# Date:                Mon, 15 Jun 2020   Prob (F-statistic):           1.74e-24
# Time:                        19:36:25   Log-Likelihood:                -2329.7
# No. Observations:                1464   AIC:                             4793.
# Df Residuals:                    1397   BIC:                             5148.
# Df Model:                          66
# Covariance Type:            nonrobust
# ...

# %%
round(model.pvalues.iloc[np.where(model.pvalues<0.1)],5).sort_values()
# Out:
# f_AMVIndex_Away                                    0.02153
# f_Passes__Final_Third__Successful_Conceded_Away    0.04394
# f_ShotsRatio_Home                                  0.04424
# f_Shots__Inside_Box_Away                           0.04535
# f_Touches__Final_Third_Conceded_Home               0.05264
# f_Touches__Penalty_Area_Conceded_Away              0.05672
# f_Touches__Penalty_Area_Away                       0.07216
# f_Touches__Final_Third_Conceded_Away               0.07571
# f_Goal_Attempts_Home                               0.08560
# f_xG_Conceded_Home                                 0.08716
# dtype: float64

# %%
stats_sig = list(model.pvalues.iloc[np.where(model.pvalues<0.05)].reset_index()["index"])
stats_sig
# Out:
# ['f_Shots__Inside_Box_Away',
#  'f_Passes__Final_Third__Successful_Conceded_Away',
#  'f_ShotsRatio_Home',
#  'f_AMVIndex_Away']

# %%
mod =  lm.LinearRegression()
y = model_base["HomeGoals"]
X = model_base[stats_sig]
cross_val_score(mod,X,y,scoring="neg_mean_squared_error",cv =kfold).mean()
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# -1.5055031261875198

# %% [markdown]
# ## Linear Regression to predict Home Goals with XG Cols
# Including Siimple XG predictions

# %%
model_base = create_model_base_scaled(training,ema_no_reset,36,features,standard_scaler,
                                     target_goals,merge_vars,calculated_features,single_line)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["HomeTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Home"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["AwayTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Away"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,xg_pred_clean, on =["season","fixture"])
y = model_base["HomeGoals"]
X = model_base[test_all_vars]

# %% [markdown]
# ### RFECV to identify variables

# %%
rfmod = lm.LinearRegression()
rfecv = RFECV(estimator=rfmod, step=1, cv=StratifiedKFold(n_splits=10, random_state=42), scoring='neg_mean_squared_error')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# Optimal number of features: 4

# %%
plt.figure(figsize=(6, 4))
plt.title('Recursive Feature Elimination with Cross-Validation', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of features selected', fontsize=14, labelpad=20)
plt.ylabel('Mean Squared Error', fontsize=14, labelpad=20)
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_*-1, color='#303F9F', linewidth=3)

plt.show()

# %% [markdown]
# **Let's look at which variables have come out as the best variables to use**

# %%
lnr_hg_vars = list(X.columns[rfecv.support_])
print(lnr_hg_vars)
# Out:
# ['f_xGRatio_Home', 'f_ShotsRatio_Home', 'f_ShOnTargetRatio_Home', 'f_xGRatio_Away']

# %% [markdown]
# ### Compare Mean squared error for linear regression

# %%
y = model_base["HomeGoals"]
X = X[X.columns[rfecv.support_]]
cross_val_score(rfmod,X,y,scoring="neg_mean_squared_error",cv =kfold).mean()
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# -1.5009138527322883

# %% [markdown]
# Log Loss for "Simple" Goals Prediction

# %%
metrics.mean_squared_error(model_base["HomeGoals"],model_base["Pred_HG"])
# Out:
# 1.518768240606013

# %% [markdown]
# ### Summary
# Linear regression for home goals doesn't outperform the simple formula for predictions

# %% [markdown]
# ## Predict Using XG Cols and Random Forest

# %%
model_base = create_model_base_scaled(training,ema_no_reset,36,features,standard_scaler,
                                     target_goals,merge_vars,calculated_features,single_line)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["HomeTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Home"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["AwayTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Away"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,xg_pred_clean, on =["season","fixture"])
y = model_base["HomeGoals"]
X = model_base[test_all_vars]

# %%
rfmod = rfmod = ensemble.RandomForestRegressor(n_estimators=50, random_state=42, max_depth = 2) #lm.LinearRegression()
rfecv = RFECV(estimator=rfmod, step=1, cv=StratifiedKFold(n_splits=10, random_state=42), scoring='neg_mean_squared_error')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# Optimal number of features: 2

# %%
plt.figure(figsize=(6, 4))
plt.title('Recursive Feature Elimination with Cross-Validation', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of features selected', fontsize=14, labelpad=20)
plt.ylabel('Mean Squared Error', fontsize=14, labelpad=20)
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_*-1, color='#303F9F', linewidth=3)

plt.show()

# %% [markdown]
# **Let's look at which variables have come out as the best variables to use**

# %%
lnr_hg_vars = list(X.columns[rfecv.support_])
print(lnr_hg_vars)
# Out:
# ['f_Shots On Target_Home', 'Pred_HG']

# %%
y = model_base["HomeGoals"]
X = X[X.columns[rfecv.support_]]
cross_val_score(rfmod,X,y,scoring="neg_mean_squared_error",cv =kfold).mean()
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# -1.493231131946079

# %%
metrics.mean_squared_error(model_base["HomeGoals"],model_base["Pred_HG"])
# Out:
# 1.518768240606013

# %% [markdown]
# ### Summary
# Very limited improvement on "Simple" Formula for predictions

# %% [markdown]
# # Predict Away Goals

# %%
model_base = create_model_base_scaled(training,ema_no_reset,36,features,standard_scaler,
                                     target_goals,merge_vars,calculated_features,single_line)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["HomeTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Home"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["AwayTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Away"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,xg_pred_clean, on =["season","fixture"])
y = model_base["AwayGoals"]
X = model_base[classifier_vars + classifier_calc_vars + ["f_AMVIndex_Home","f_AMVIndex_Away"]]

# %%
rfmod = lm.LinearRegression()
rfecv = RFECV(estimator=rfmod, step=1, cv=StratifiedKFold(n_splits=10, random_state=42), scoring='neg_mean_squared_error')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# Optimal number of features: 4

# %%
plt.figure(figsize=(6, 4))
plt.title('Recursive Feature Elimination with Cross-Validation', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of features selected', fontsize=14, labelpad=20)
plt.ylabel('Mean Squared Error', fontsize=14, labelpad=20)
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_*-1, color='#303F9F', linewidth=3)

plt.show()

# %% [markdown]
# **Let's look at which variables have come out as the best variables to use**

# %%
lnr_ag_vars = list(X.columns[rfecv.support_])
print(lnr_ag_vars)
# Out:
# ['f_Shots On Target_Away', 'f_xGRatio_Home', 'f_ShOnTargetRatio_Home', 'f_ShOnTargetRatio_Away']

# %%
y = model_base["AwayGoals"]
X = X[X.columns[rfecv.support_]]
cross_val_score(rfmod,X,y,scoring="neg_mean_squared_error",cv =kfold).mean()
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# -1.1581913239378605

# %%
metrics.mean_squared_error(model_base["AwayGoals"],model_base["Pred_AG"])
# Out:
# 1.1965010439739197

# %%
lnr = lm.LinearRegression()

model_base = create_model_base_scaled(training,ema_no_reset,36,features,standard_scaler,
                                     target_goals,merge_vars,calculated_features,single_line)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["HomeTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Home"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["AwayTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Away"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,xg_pred_clean, on =["season","fixture"])

y_hg = model_base["HomeGoals"]
X_hg= model_base[lnr_hg_vars]

y_ag = model_base["AwayGoals"]
X_ag = model_base[lnr_ag_vars]
lnr = lm.LinearRegression()
lr_hg = lnr.fit(X_hg,y_hg)
lnr = lm.LinearRegression()
lr_ag = lnr.fit(X_ag,y_ag)

# %%
model_base = create_model_base_scaled(results,ema_no_reset,36,features,standard_scaler,
                                     target_goals,merge_vars,calculated_features,single_line)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["HomeTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Home"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["AwayTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Away"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,xg_pred_clean, on =["season","fixture"])

model_base["lnr_HG_Pred"] = lr_hg.predict(model_base[lnr_hg_vars])
model_base["lnr_AG_Pred"] = lr_ag.predict(model_base[lnr_ag_vars])

# %%
test = model_base[model_base["season"]==2018].copy()
print(metrics.mean_squared_error(test["HomeGoals"],test["Pred_HG"]))
print(metrics.mean_squared_error(test["HomeGoals"],test["lnr_HG_Pred"]))
print(metrics.mean_squared_error(test["AwayGoals"],test["Pred_AG"]))
print(metrics.mean_squared_error(test["AwayGoals"],test["lnr_AG_Pred"]))
# Out:
# 1.3534113513379946
# 1.363310986842726
# 1.1840903636153546
# 1.2336344587973207

# %%
GD = test["HomeGoals"]-test["AwayGoals"]
xGGD = test["Pred_HG"]-test["Pred_AG"]
lnr_GD = test["lnr_HG_Pred"]- test["lnr_AG_Pred"]
print(metrics.mean_squared_error(GD,xGGD))
print(metrics.mean_squared_error(GD,lnr_GD))
# Out:
# 2.5842040607707184
# 2.6278424425533977

# %%
hg_corr = test.corr()[["HomeGoals","AwayGoals"]]

# %%
hg_corr.sort_values(by="HomeGoals",ascending = False)
# Out:
#                                                    HomeGoals  AwayGoals
# HomeGoals                                           1.000000  -0.181493
# Pred_HG                                             0.444032  -0.342292
# lnr_HG_Pred                                         0.443372  -0.392538
# f_Touches - Penalty Area_Home                       0.380771  -0.267932
# f_Shots - Inside Box_Home                           0.370497  -0.273647
# ...                                                      ...        ...
# f_Passes - Final Third - Successful Conceded_Home  -0.324673   0.238095
# f_Touches - Final Third Conceded_Home              -0.340953   0.246053
# Pred_AG                                            -0.356391   0.400495
# lnr_AG_Pred                                        -0.382489   0.373621
# season                                                   NaN        NaN
#
# [75 rows x 2 columns]

# %%
hg_corr.sort_values(by="AwayGoals",ascending = False).head()
# Out:
#                                       HomeGoals  AwayGoals
# AwayGoals                             -0.181493   1.000000
# Pred_AG                               -0.356391   0.400495
# lnr_AG_Pred                           -0.382489   0.373621
# f_Goal Attempts In Box Conceded_Home  -0.284865   0.297121
# f_Touches - Penalty Area_Away         -0.235143   0.288672

# %% [markdown]
# # Goal Difference Regression

# %%
model_base = create_model_base_scaled(training,ema_no_reset,36,features,standard_scaler,
                                     target_goals,merge_vars,calculated_features,single_line)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["HomeTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Home"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,tm[["FFScout","Season","AMVIndex"]],left_on=["AwayTeam","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex_Away"}).drop(["FFScout","Season"],axis=1)
model_base = pd.merge(model_base,xg_pred_clean, on =["season","fixture"])
model_base["GD"] = model_base["HomeGoals"]-model_base["AwayGoals"]
y = model_base["GD"]
X = model_base[non_xg_vars]

# %%
rfmod = lm.LinearRegression()
rfecv = RFECV(estimator=rfmod, step=1, cv=StratifiedKFold(n_splits=10, random_state=42), scoring='neg_mean_squared_error')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# Optimal number of features: 20

# %%
plt.figure(figsize=(6, 4))
plt.title('Recursive Feature Elimination with Cross-Validation', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of features selected', fontsize=14, labelpad=20)
plt.ylabel('Mean Squared Error', fontsize=14, labelpad=20)
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_*-1, color='#303F9F', linewidth=3)

plt.show()

# %% [markdown]
# **Let's look at which variables have come out as the best variables to use**

# %%
lnr_hg_vars = list(X.columns[rfecv.support_])
print(lnr_hg_vars)
# Out:
# ['f_Touches - Final Third_Home', 'f_Passes - Final Third - Successful_Home', 'f_Goal Attempts_Home', 'f_Shots On Target_Home', 'f_Shots Conceded_Home', 'f_Touches - Final Third Conceded_Home', 'f_Passes - Final Third - Successful Conceded_Home', 'f_Touches - Final Third log_Home', 'f_Touches - Final Third_Away', 'f_Passes - Final Third - Successful_Away', 'f_Goal Attempts_Away', 'f_Shots On Target_Away', 'f_Shots Conceded_Away', 'f_Touches - Penalty Area Conceded_Away', 'f_ShotsRatio_Home', 'f_ShOnTargetRatio_Home', 'f_ShotsRatio_Away', 'f_ShOnTargetRatio_Away', 'f_AMVIndex_Home', 'f_AMVIndex_Away']

# %%
y = model_base["GD"]
X = X[X.columns[rfecv.support_]]
cross_val_score(rfmod,X,y,scoring="neg_mean_squared_error",cv =kfold).mean()
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# -2.6044906783685087

# %% [markdown]
# # Attacking Strength

# %% [markdown]
# ## Using Home Advantage

# %%
features = [f for f in results.columns if f.startswith("f_") and f !="f_Team" 
            and f not in incomplete_vars]

ema_output = ema_no_reset(training, span=36,feature_cols=features)
ema_target = pd.merge(ema_output, target_goals, on = ['f_Team','matchid']).dropna()
ema_target = pd.merge(ema_target,tm[["FFScout","Season","AMVIndex"]],left_on=["f_Team","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex"}).drop(["FFScout","Season"],axis=1)

y = ema_target["t_Goals"]
X = ema_target[features + ["f_AMVIndex","f_HmGameFut"]].drop(columns=["f_HmGame"])
rfmod = lm.LinearRegression()
rfecv = RFECV(estimator=rfmod, step=1, cv=StratifiedKFold(n_splits=10, random_state=42), scoring='neg_mean_squared_error')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# Optimal number of features: 5

# %%
plt.figure(figsize=(6, 4))
plt.title('Recursive Feature Elimination with Cross-Validation', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of features selected', fontsize=14, labelpad=20)
plt.ylabel('Mean Squared Error', fontsize=14, labelpad=20)
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_*-1, color='#303F9F', linewidth=3)

plt.show()

# %% [markdown]
# **Let's look at which variables have come out as the best variables to use**

# %%
att_pred_vars = list(X.columns[rfecv.support_])
att_pred_vars
# Out:
# ['f_Shots On Target',
#  'f_US xG Conceded',
#  'f_Touches - Final Third log',
#  'f_AMVIndex',
#  'f_HmGameFut']

# %%
#ema_target_clean = ema_target[ema_target["t_Goals"]<6].copy()
y = ema_target["t_Goals"]
X = ema_target[att_pred_vars]
cross_val_score(rfmod,X,y,scoring="neg_mean_squared_error",cv =kfold).mean()
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# -1.367280075670593

# %%
lr = lm.LinearRegression()
clf_AttStr = lr.fit(X,y)

# %% [markdown]
# ## Test without Home Advantage

# %%
features = [i for i in results.columns if i.startswith("f_") and i !="f_Team" 
            and i not in incomplete_vars]

ema_output = ema_no_reset(training, span=36,feature_cols=features)
ema_target = pd.merge(ema_output, target_goals, on = ['f_Team','matchid']).dropna()
ema_target = pd.merge(ema_target,tm[["FFScout","Season","AMVIndex"]],left_on=["f_Team","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex"}).drop(["FFScout","Season"],axis=1)

y = ema_target["t_Goals"]
X = ema_target[features + ["f_AMVIndex"]].drop(columns=["f_HmGame"])
rfmod = lm.LinearRegression()
rfecv = RFECV(estimator=rfmod, step=1, cv=StratifiedKFold(n_splits=10, random_state=42), scoring='neg_mean_squared_error')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))

att_pred_vars2 = list(X.columns[rfecv.support_])
print(att_pred_vars2)

#ema_target_clean = ema_target[ema_target["t_Goals"]<6].copy()
y = ema_target["t_Goals"]
X = ema_target[att_pred_vars2]
print(cross_val_score(rfmod,X,y,scoring="neg_mean_squared_error",cv =kfold).mean())

lr = lm.LinearRegression()
clf_AttStr2 = lr.fit(X,y)
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# Optimal number of features: 7
# ['f_Big Chances Total', 'f_Shots On Target', 'f_Goals Conceded', 'f_US xG Conceded', 'f_Points', 'f_Touches - Final Third log', 'f_AMVIndex']
# -1.4040740181766425
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)

# %%
# Out:
#    season           matchid  gw_no                               fixture  \
# 0    2014  /matches/755324/      3          Burnley vs Manchester United
# 1    2014  /matches/755327/      3         Manchester City vs Stoke City
# 2    2014  /matches/755328/      3    Newcastle United vs Crystal Palace
# 3    2014  /matches/755329/      3     Queens Park Rangers vs Sunderland
# 4    2014  /matches/755330/      3  Swansea City vs West Bromwich Albion
#
#              matchdate             HomeTeam              AwayTeam  HomeGoals  \
# 0  2014-08-30 12:45:00              Burnley     Manchester United          0
# 1  2014-08-30 15:00:00      Manchester City            Stoke City          0
# 2  2014-08-30 15:00:00     Newcastle United        Crystal Palace          3
# 3  2014-08-30 15:00:00  Queens Park Rangers            Sunderland          1
# 4  2014-08-30 15:00:00         Swansea City  West Bromwich Albion          3
#
#    AwayGoals Result  f_HmGame_Home  f_xG Conceded_Home  \
# ...

# %% [markdown]
# # Defensive Strength

# %% [markdown]
# ## Using Home Advantage

# %%
ema_output = ema_no_reset(training, span=36,feature_cols=features)
ema_target = pd.merge(ema_output, target_goals, on = ['f_Team','matchid']).dropna()
ema_target = pd.merge(ema_target,tm[["FFScout","Season","AMVIndex"]],left_on=["f_Team","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex"}).drop(["FFScout","Season"],axis=1)

y = ema_target["t_Goals Conceded"]
X = ema_target[features + ["f_AMVIndex","f_HmGameFut"]].drop(columns=["f_HmGame"])
rfmod = lm.LinearRegression()
rfecv = RFECV(estimator=rfmod, step=1, cv=StratifiedKFold(n_splits=10, random_state=42), scoring='neg_mean_squared_error')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# Optimal number of features: 5

# %%
plt.figure(figsize=(6, 4))
plt.title('Recursive Feature Elimination with Cross-Validation', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of features selected', fontsize=14, labelpad=20)
plt.ylabel('Mean Squared Error', fontsize=14, labelpad=20)
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_*-1, color='#303F9F', linewidth=3)

plt.show()

# %% [markdown]
# **Let's look at which variables have come out as the best variables to use**

# %%
def_pred_vars = list(X.columns[rfecv.support_])
def_pred_vars
# Out:
# ['f_Big Chances Total',
#  'f_Big Chances Conceded',
#  'f_Touches - Final Third log',
#  'f_AMVIndex',
#  'f_HmGameFut']

# %%
#ema_target_clean = ema_target[ema_target["t_Goals"]<6].copy()
y = ema_target_clean["t_Goals Conceded"]
X = ema_target_clean[att_pred_vars]
cross_val_score(rfmod,X,y,scoring="neg_mean_squared_error",cv =kfold).mean()
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# -1.4637874166707294

# %%
lr = lm.LinearRegression()
clf_DefStr = lr.fit(X,y)

# %% [markdown]
# ## Without home Advantage

# %%
features = [i for i in results.columns if i.startswith("f_") and i !="f_Team" 
            and i not in incomplete_vars]

ema_output = ema_no_reset(training, span=36,feature_cols=features)
ema_target = pd.merge(ema_output, target_goals, on = ['f_Team','matchid']).dropna()
ema_target = pd.merge(ema_target,tm[["FFScout","Season","AMVIndex"]],left_on=["f_Team","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex"}).drop(["FFScout","Season"],axis=1)

y = ema_target["t_Goals Conceded"]
X = ema_target[features + ["f_AMVIndex"]].drop(columns=["f_HmGame"])
rfmod = lm.LinearRegression()
rfecv = RFECV(estimator=rfmod, step=1, cv=StratifiedKFold(n_splits=10, random_state=42), scoring='neg_mean_squared_error')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))

def_pred_vars2 = list(X.columns[rfecv.support_])
print(att_pred_vars2)

#ema_target_clean = ema_target[ema_target["t_Goals"]<6].copy()
y = ema_target["t_Goals Conceded"]
X = ema_target[def_pred_vars2]
print(cross_val_score(rfmod,X,y,scoring="neg_mean_squared_error",cv =kfold).mean())

lr = lm.LinearRegression()
clf_DefStr2 = lr.fit(X,y)
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# Optimal number of features: 5
# ['f_Big Chances Total', 'f_Shots On Target', 'f_Goals Conceded', 'f_US xG Conceded', 'f_Points', 'f_Touches - Final Third log', 'f_AMVIndex']
# -1.4952885095104163
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)

# %% [markdown]
# # Single line predictions

# %%
league_goals = single_line.groupby(["season","gw_no"])[["HomeGoals","AwayGoals"]].sum().reset_index()
league_goals["fixtures"] = single_line.groupby(["season","gw_no"])[["fixture"]].count().reset_index()["fixture"]
#league_goals[["TotalHG","TotalAG","TotalFix"]] = league_goals[["HomeGoals","AwayGoals","fixtures"]].cumsum()
#league_goals
season_av = league_goals.groupby(['season'])["HomeGoals","AwayGoals","fixtures"].transform(lambda row: row.rolling(window=36,min_periods=2).sum()).shift(1)
league_goals["SeasonHG"] = season_av["HomeGoals"]/season_av["fixtures"]
league_goals["SeasonAG"] = season_av["AwayGoals"]/season_av["fixtures"]
league_goals = league_goals[["season","gw_no","SeasonHG","SeasonAG"]].dropna()
league_goals.head()
# Out:
#    season  gw_no  SeasonHG  SeasonAG
# 2    2014      3     1.250  1.200000
# 3    2014      4     1.300  1.400000
# 4    2014      5     1.425  1.350000
# 5    2014      6     1.440  1.420000
# 6    2014      7     1.500  1.316667

# %%
features = [i for i in results.columns if i.startswith("f_") and i !="f_Team" 
            and i not in incomplete_vars]
ema_output = ema_no_reset(results, span=span,feature_cols=features)
ema_target = pd.merge(ema_output, target_goals, on = ['f_Team','matchid']).dropna()
ema_target = pd.merge(ema_target,tm[["FFScout","Season","AMVIndex"]],left_on=["f_Team","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex"}).drop(["FFScout","Season"],axis=1)

ema_target["f_clfAttStr"] = clf_AttStr.predict(ema_target[att_pred_vars])
ema_target["f_clfDefStr"]  = clf_DefStr.predict(ema_target[def_pred_vars])
ema_target["f_clfAttStr2"] = clf_AttStr2.predict(ema_target[att_pred_vars2])
ema_target["f_clfDefStr2"]  = clf_DefStr2.predict(ema_target[def_pred_vars2])

# %%
mean_str = ema_target.groupby(["season","gw_no"])["f_clfAttStr","f_clfDefStr",
                                                  "f_clfAttStr2","f_clfDefStr2"].agg("mean").add_suffix("_mean").reset_index()
ema_target = pd.merge(ema_target,mean_str, on =["season","gw_no"])
for i in ["f_clfAttStr","f_clfDefStr","f_clfAttStr2","f_clfDefStr2"]:
    ema_target[i+"_ind"] = ema_target[i]/ema_target[i+"_mean"]
ema_target.head()
# Out:
#             matchid             f_Team    gameweek  season  f_HmGame  \
# 0  /matches/755324/  Manchester United  Gameweek 3    2014  0.486111
# 1  /matches/755324/            Burnley  Gameweek 3    2014  0.486111
# 2  /matches/755327/         Stoke City  Gameweek 3    2014  0.486111
# 3  /matches/755327/    Manchester City  Gameweek 3    2014  0.513889
# 4  /matches/755328/     Crystal Palace  Gameweek 3    2014  0.513889
#
#                               fixture            matchdate  gw_no  \
# 0        Burnley vs Manchester United  2014-08-30 12:45:00      3
# 1        Burnley vs Manchester United  2014-08-30 12:45:00      3
# 2       Manchester City vs Stoke City  2014-08-30 15:00:00      3
# 3       Manchester City vs Stoke City  2014-08-30 15:00:00      3
# 4  Newcastle United vs Crystal Palace  2014-08-30 15:00:00      3
#
#    f_xG Conceded  f_Touches - Final Third log  f_Goal Attempts  \
# 0            0.0                     5.375139        11.944444
# ...

# %%
features = [f for f in ema_target if f.startswith("f_") and f !="f_Team"]
model_base = restructure_ema(ema_target,merge_vars,features)
model_base = pd.merge(single_line,model_base, on = merge_vars)
model_base = pd.merge(model_base,xg_pred_clean, on =["season","fixture"])
model_base = pd.merge(model_base,league_goals, on =["season","gw_no"])
model_base.head()
# Out:
#    season           matchid  gw_no                               fixture  \
# 0    2014  /matches/755324/      3          Burnley vs Manchester United
# 1    2014  /matches/755327/      3         Manchester City vs Stoke City
# 2    2014  /matches/755328/      3    Newcastle United vs Crystal Palace
# 3    2014  /matches/755329/      3     Queens Park Rangers vs Sunderland
# 4    2014  /matches/755330/      3  Swansea City vs West Bromwich Albion
#
#              matchdate             HomeTeam              AwayTeam  HomeGoals  \
# 0  2014-08-30 12:45:00              Burnley     Manchester United          0
# 1  2014-08-30 15:00:00      Manchester City            Stoke City          0
# 2  2014-08-30 15:00:00     Newcastle United        Crystal Palace          3
# 3  2014-08-30 15:00:00  Queens Park Rangers            Sunderland          1
# 4  2014-08-30 15:00:00         Swansea City  West Bromwich Albion          3
#
#    AwayGoals Result  f_HmGame_Home  f_xG Conceded_Home  \
# ...

# %%
def Predicted_HG(HAtt,ADef,LgHG):
    Pred_HG = HAtt*ADef*LgHG
    return Pred_HG

def Predicted_AG(HDef,AAtt,LgAG):
    Pred_AG = HDef*AAtt*LgAG
    return Pred_AG

model_base["clf_Pred_HG"] = model_base.apply(lambda row: Predicted_HG(
                                            row["f_clfAttStr2_ind_Home"],row["f_clfDefStr2_ind_Away"],row["SeasonHG"]), axis =1)
model_base["clf_Pred_AG"] = model_base.apply(lambda row: Predicted_AG(
                                            row["f_clfDefStr2_ind_Home"],row["f_clfAttStr2_ind_Away"],row["SeasonAG"]), axis =1)

model_base.head()
# Out:
#    season           matchid  gw_no                               fixture  \
# 0    2014  /matches/755324/      3          Burnley vs Manchester United
# 1    2014  /matches/755327/      3         Manchester City vs Stoke City
# 2    2014  /matches/755328/      3    Newcastle United vs Crystal Palace
# 3    2014  /matches/755329/      3     Queens Park Rangers vs Sunderland
# 4    2014  /matches/755330/      3  Swansea City vs West Bromwich Albion
#
#              matchdate             HomeTeam              AwayTeam  HomeGoals  \
# 0  2014-08-30 12:45:00              Burnley     Manchester United          0
# 1  2014-08-30 15:00:00      Manchester City            Stoke City          0
# 2  2014-08-30 15:00:00     Newcastle United        Crystal Palace          3
# 3  2014-08-30 15:00:00  Queens Park Rangers            Sunderland          1
# 4  2014-08-30 15:00:00         Swansea City  West Bromwich Albion          3
#
#    AwayGoals Result  f_HmGame_Home  f_xG Conceded_Home  \
# ...

# %%
clf_train = model_base[model_base["season"].isin([2014,2015,2016,2017])]
clf_test = model_base[model_base["season"].isin([2018])]

# %%
clf_test.corr()[["HomeGoals","AwayGoals"]].sort_values(by="HomeGoals",ascending =False).head(10)
# Out:
#                                HomeGoals  AwayGoals
# HomeGoals                       1.000000  -0.181493
# Pred_HG                         0.444032  -0.342292
# clf_Pred_HG                     0.442312  -0.353461
# f_Touches - Penalty Area_Home   0.380771  -0.267932
# f_clfAttStr_ind_Home            0.374174  -0.276267
# f_clfAttStr2_ind_Home           0.373494  -0.270381
# f_clfAttStr_Home                0.373357  -0.279413
# f_clfAttStr2_Home               0.372788  -0.273170
# f_Shots - Inside Box_Home       0.370497  -0.273647
# AttStr_Home                     0.366789  -0.269173

# %%
index_keep = ["f_clfDefStr2_Home","f_clfDefStr_Home","f_clfAttStr2_Home","f_clfAttStr_Home",
             "f_clfDefStr2_Away","f_clfDefStr_Away","f_clfAttStr2_Away","f_clfAttStr_Away",
              "f_clfDefStr2_ind_Home","f_clfDefStr_ind_Home","f_clfAttStr2_ind_Home","f_clfAttStr_ind_Home",
             "f_clfDefStr2_ind_Away","f_clfDefStr_ind_Away","f_clfAttStr2_ind_Away","f_clfAttStr_ind_Away",
             "AttStr_Home","AttStr_Away","DefStr_Home","DefStr_Away","Pred_HG","Pred_AG",
             "SeasonHG","SeasonAG","clf_Pred_HG","clf_Pred_AG"]
clf_test.corr()[["HomeGoals","AwayGoals"]].loc[index_keep].sort_values(by="AwayGoals",ascending =False)
# Out:
#                        HomeGoals  AwayGoals
# Pred_AG                -0.356391   0.400495
# clf_Pred_AG            -0.362047   0.384500
# f_clfDefStr2_Home      -0.356531   0.285672
# DefStr_Home            -0.270988   0.285590
# f_clfDefStr_Home       -0.303177   0.281842
# f_clfDefStr2_ind_Home  -0.359853   0.280989
# f_clfDefStr_ind_Home   -0.307167   0.279019
# AttStr_Away            -0.245253   0.274596
# f_clfAttStr2_ind_Away  -0.206525   0.265662
# f_clfAttStr_ind_Away   -0.207585   0.265323
# f_clfAttStr_Away       -0.208551   0.262974
# f_clfAttStr2_Away      -0.207056   0.262459
# SeasonHG               -0.071888   0.025717
# SeasonAG                0.039059  -0.056903
# DefStr_Away             0.263483  -0.237334
# f_clfDefStr_Away        0.252862  -0.262902
# AttStr_Home             0.366789  -0.269173
# f_clfDefStr_ind_Away    0.251423  -0.269490
# f_clfAttStr2_ind_Home   0.373494  -0.270381
# f_clfAttStr2_Home       0.372788  -0.273170
# ...

# %% [markdown]
# # Predict Result

# %%
X = clf_train[index_keep]
y = clf_train["Result"]
le = LabelEncoder()
y = le.fit_transform(y)

lr = lm.LogisticRegression(solver='lbfgs', multi_class='auto', max_iter=1000)
rfecv = RFECV(estimator=lr, step=1, cv=StratifiedKFold(n_splits=10, random_state=42), scoring='neg_log_loss')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
# Out:
# Optimal number of features: 4

# %%
plt.figure(figsize=(6, 4))
plt.title('Recursive Feature Elimination with Cross-Validation', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of features selected', fontsize=14, labelpad=20)
plt.ylabel('Mean Squared Error', fontsize=14, labelpad=20)
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_*-1, color='#303F9F', linewidth=3)

plt.show()

# %%
lr_features_xg =list(X.columns[rfecv.support_])
print(lr_features_xg)
rfecv.estimator_.coef_
# Out:
# ['f_clfAttStr2_ind_Home', 'SeasonAG', 'clf_Pred_HG', 'clf_Pred_AG']
# array([[-0.31026496, -1.27941813, -0.41866221,  0.85865096],
#        [ 0.35551414,  1.11784264, -0.35782461, -0.34750261],
#        [-0.04524917,  0.16157549,  0.77648682, -0.51114835]])

# %%
X = clf_train[lr_features_xg]
y = clf_train["Result"]
le = LabelEncoder()
y = le.fit_transform(y)

lr_logloss = cross_val_score(lr, X, y, scoring="neg_log_loss", cv=kfold).mean()
lr_accuracy = cross_val_score(lr, X, y, scoring="accuracy", cv=kfold).mean()

print(lr_logloss)
print(lr_accuracy)

clf_lr_pred = lr.fit(X,y)
# Out:
# -0.9702427371385276
# 0.5423211212578911

# %%
X = clf_test[lr_features_xg]
y = clf_test["Result"]
le = LabelEncoder()
y = le.fit_transform(y)

print("GSLR")
print(metrics.log_loss(y,clf_lr_pred.predict_proba(X)))
print(metrics.accuracy_score(y,clf_lr_pred.predict(X)))
# Out:
# GSLR
# 0.9080689022100296
# 0.5885558583106267

# %%
model_pre = model_base.copy()

# %%
gambling_output.tail()
# Out:
#       season            matchid  gw_no  \
# 2093    2019  /matches/1059977/     28
# 2094    2019  /matches/1059981/     28
# 2095    2019  /matches/1059980/     28
# 2096    2019  /matches/1059975/     28
# 2097    2019  /matches/1059979/     28
#
#                                            fixture            matchdate  \
# 2093                   Newcastle United vs Burnley  2020-02-29 15:00:00
# 2094                West Ham United vs Southampton  2020-02-29 15:00:00
# 2095                          Watford vs Liverpool  2020-02-29 17:30:00
# 2096                  Everton vs Manchester United  2020-03-01 14:00:00
# 2097  Tottenham Hotspur vs Wolverhampton Wanderers  2020-03-01 14:00:00
#
#                HomeTeam                 AwayTeam  Model_Prob_A  Model_Prob_D  \
# 2093   Newcastle United                  Burnley      0.292186      0.316769
# 2094    West Ham United              Southampton      0.301238      0.264899
# ...

# %%
model_base = create_model_probs_df(model_pre,[2014,2015,2016,2017,2018,2019],clf_lr_pred,lr_features_xg,
                                  list(le.classes_),gamble_cols)
odds_preds = pd.merge(model_base,odds_clean, on =["season","fixture"], how ="inner")
odds_preds = odds_preds.rename(columns={"FTR":"Result"})
gambling_df = odds_preds.copy()
gambling_output = full_gambling_calc_cutoff(gambling_df,stake,bookie_home_prob,bookie_draw_prob,bookie_away_prob,model_home,
                                            model_draw,model_away,1.1)

# %%
gambling_output.groupby(["season","bookie"]).agg(BookieAcc=("BookiePredCorrect","mean")
                                        ,ModelAcc=("ModelPredCorrect","mean")
                                        ,ModelReturns=("ModelPredProfit","sum")
                                        ,ValueAcc=("ValuePredCorrect","mean")
                                        ,ValueReturns=("ValuePredProfit","sum")
                                        ,ValueCutoffReturns=("ValueCutoffProfit","sum")
                                        #,ModelResultProb=("FinalResultProb","mean")
                                        ,Counts=("fixture","nunique")
                                        ,ValueCutoffCounts=("ValueRequirementMet","sum")).reset_index()
# Out:
#    season  bookie  BookieAcc  ModelAcc  ModelReturns  ValueAcc  ValueReturns  \
# 0    2014  Bet365   0.541667  0.536111          6.30  0.397222        238.80
# 1    2015  Bet365   0.476839  0.457766       -202.20  0.335150         75.00
# 2    2016  Bet365   0.612466  0.620596        244.55  0.341463          7.80
# 3    2017  Bet365   0.554348  0.551630        -59.60  0.312500        193.35
# 4    2018  Bet365   0.588556  0.588556         77.50  0.280654       -143.95
# 5    2019  Bet365   0.528090  0.513109       -150.55  0.265918       -109.65
#
#    ValueCutoffReturns  Counts  ValueCutoffCounts
# 0              143.30     360                199
# 1              -27.80     367                204
# 2               36.90     369                229
# 3              231.00     368                199
# 4               -7.85     367                230
# 5             -113.95     267                141

# %%
# Out:
# -109.64999999999999

# %%
for i in [2014,2015,2016,2017,2018,2019]:
    log_test = gambling_output[gambling_output["season"]==i].copy()
    y = log_test["Result"]
    le = LabelEncoder()
    y = le.fit_transform(y)
    model_logloss = metrics.log_loss(y,log_test[["Model_Prob_A","Model_Prob_D","Model_Prob_H"]])
    model_accuracy = log_test["ModelPredCorrect"].mean()
    bookie_logloss = metrics.log_loss(y,log_test[["BookieAwayProb","BookieDrawProb","BookieHomeProb"]])
    bookie_accuracy = log_test["BookiePredCorrect"].mean()
    print(str(i) + " Model log loss " + str(model_logloss) + " Accuracy: " + str(model_accuracy))
    print(str(i) + " Bookie log loss " + str(bookie_logloss) + " Accuracy: " + str(bookie_accuracy))
# Out:
# 2014 Model log loss 0.9608300475322358 Accuracy: 0.5361111111111111
# 2014 Bookie log loss 0.9715931068323761 Accuracy: 0.5416666666666666
# 2015 Model log loss 1.046076020665394 Accuracy: 0.45776566757493187
# 2015 Bookie log loss 1.0353743140413456 Accuracy: 0.4768392370572207
# 2016 Model log loss 0.9108933001940681 Accuracy: 0.6205962059620597
# 2016 Bookie log loss 0.9040003337489257 Accuracy: 0.6124661246612466
# 2017 Model log loss 0.9401556866463359 Accuracy: 0.5516304347826086
# 2017 Bookie log loss 0.9439825647174763 Accuracy: 0.5543478260869565
# 2018 Model log loss 0.9080689022100296 Accuracy: 0.5885558583106267
# 2018 Bookie log loss 0.8937161999254375 Accuracy: 0.5885558583106267
# 2019 Model log loss 1.0137622962884572 Accuracy: 0.5131086142322098
# 2019 Bookie log loss 0.9839600200826766 Accuracy: 0.5280898876404494

# %%
season_test = gambling_output[gambling_output["season"]==2018]
weekly_summary = season_test.groupby("gw_no")["ValuePredProfit"].sum().reset_index()
weekly_summary["ProfitCumu"] = weekly_summary["ValuePredProfit"].cumsum()
weekly_summary["MaxWin"] = season_test.groupby("gw_no")["ValuePredProfit"].max().reset_index()["ValuePredProfit"]
weekly_summary["ValueCorrect"] = season_test.groupby("gw_no")["ValuePredCorrect"].sum().reset_index()["ValuePredCorrect"]
weekly_summary
# Out:
#     gw_no  ValuePredProfit  ProfitCumu  MaxWin  ValueCorrect
# 0       1             1.15        1.15    6.85             4
# 1       3           -20.20      -19.05    8.00             3
# 2       4           -29.00      -48.05   16.00             1
# 3       5           -28.00      -76.05    7.50             2
# 4       6            -4.60      -80.65   16.65             3
# 5       7            -8.80      -89.45   13.00             3
# 6       8           -11.30     -100.75   13.00             3
# 7       9            -3.00     -103.75   14.00             3
# 8      10           -41.40     -145.15    3.60             1
# 9      11            -4.50     -149.65   14.50             3
# 10     12            25.40     -124.25   21.25             4
# 11     13            43.35      -80.90   35.00             4
# 12     14           -19.75     -100.65   14.00             2
# 13     15           -16.70     -117.35   20.00             2
# ...

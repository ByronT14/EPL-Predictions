# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Import-custom-functions" data-toc-modified-id="Import-custom-functions-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Import custom functions</a></span></li><li><span><a href="#Read-in-Files" data-toc-modified-id="Read-in-Files-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Read in Files</a></span><ul class="toc-item"><li><span><a href="#Results-and-model-data" data-toc-modified-id="Results-and-model-data-0.2.1"><span class="toc-item-num">0.2.1&nbsp;&nbsp;</span>Results and model data</a></span></li><li><span><a href="#Bookie-Data" data-toc-modified-id="Bookie-Data-0.2.2"><span class="toc-item-num">0.2.2&nbsp;&nbsp;</span>Bookie Data</a></span></li><li><span><a href="#Teamnames-Lookup" data-toc-modified-id="Teamnames-Lookup-0.2.3"><span class="toc-item-num">0.2.3&nbsp;&nbsp;</span>Teamnames Lookup</a></span></li><li><span><a href="#Transfermarkt" data-toc-modified-id="Transfermarkt-0.2.4"><span class="toc-item-num">0.2.4&nbsp;&nbsp;</span>Transfermarkt</a></span></li><li><span><a href="#XG-Predictions-file" data-toc-modified-id="XG-Predictions-file-0.2.5"><span class="toc-item-num">0.2.5&nbsp;&nbsp;</span>XG Predictions file</a></span></li><li><span><a href="#Create-Season-Order" data-toc-modified-id="Create-Season-Order-0.2.6"><span class="toc-item-num">0.2.6&nbsp;&nbsp;</span>Create Season Order</a></span></li></ul></li><li><span><a href="#Create-single-line-df" data-toc-modified-id="Create-single-line-df-0.3"><span class="toc-item-num">0.3&nbsp;&nbsp;</span>Create single line df</a></span></li><li><span><a href="#Feature-labelling" data-toc-modified-id="Feature-labelling-0.4"><span class="toc-item-num">0.4&nbsp;&nbsp;</span>Feature labelling</a></span><ul class="toc-item"><li><span><a href="#Split-out-seasons" data-toc-modified-id="Split-out-seasons-0.4.1"><span class="toc-item-num">0.4.1&nbsp;&nbsp;</span>Split out seasons</a></span></li><li><span><a href="#Create-target-goals-dataframe" data-toc-modified-id="Create-target-goals-dataframe-0.4.2"><span class="toc-item-num">0.4.2&nbsp;&nbsp;</span>Create target goals dataframe</a></span></li><li><span><a href="#Variable-lists" data-toc-modified-id="Variable-lists-0.4.3"><span class="toc-item-num">0.4.3&nbsp;&nbsp;</span>Variable lists</a></span></li><li><span><a href="#Scaling" data-toc-modified-id="Scaling-0.4.4"><span class="toc-item-num">0.4.4&nbsp;&nbsp;</span>Scaling</a></span></li></ul></li></ul></li><li><span><a href="#Creating-an-Attacking-Strength-Metric" data-toc-modified-id="Creating-an-Attacking-Strength-Metric-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Creating an Attacking Strength Metric</a></span></li><li><span><a href="#Plotting-xG-Attack-and-Defence" data-toc-modified-id="Plotting-xG-Attack-and-Defence-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Plotting xG Attack and Defence</a></span><ul class="toc-item"><li><span><a href="#Unscaled" data-toc-modified-id="Unscaled-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Unscaled</a></span></li><li><span><a href="#Scaled" data-toc-modified-id="Scaled-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Scaled</a></span></li><li><span><a href="#Compare-xG-indexes" data-toc-modified-id="Compare-xG-indexes-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Compare xG indexes</a></span></li></ul></li><li><span><a href="#Creating-modelled-attacking-strength" data-toc-modified-id="Creating-modelled-attacking-strength-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Creating modelled attacking strength</a></span><ul class="toc-item"><li><span><a href="#Predicting-Goals" data-toc-modified-id="Predicting-Goals-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Predicting Goals</a></span><ul class="toc-item"><li><span><a href="#RFECV-Linear-Regression" data-toc-modified-id="RFECV-Linear-Regression-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>RFECV Linear Regression</a></span></li><li><span><a href="#RFECV-Random-Forest" data-toc-modified-id="RFECV-Random-Forest-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>RFECV Random Forest</a></span></li><li><span><a href="#Manual-Selection-of-Variables" data-toc-modified-id="Manual-Selection-of-Variables-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Manual Selection of Variables</a></span></li><li><span><a href="#Statsmodels" data-toc-modified-id="Statsmodels-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Statsmodels</a></span></li></ul></li></ul></li><li><span><a href="#Creating-modelled-defensive-strength" data-toc-modified-id="Creating-modelled-defensive-strength-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Creating modelled defensive strength</a></span><ul class="toc-item"><li><span><a href="#Predicting-Goals-Conceded" data-toc-modified-id="Predicting-Goals-Conceded-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Predicting Goals Conceded</a></span><ul class="toc-item"><li><span><a href="#RFECV-Linear-Regression" data-toc-modified-id="RFECV-Linear-Regression-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>RFECV Linear Regression</a></span></li><li><span><a href="#RFECV-Random-Forest" data-toc-modified-id="RFECV-Random-Forest-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>RFECV Random Forest</a></span></li><li><span><a href="#Manual-Selection-of-Variables" data-toc-modified-id="Manual-Selection-of-Variables-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Manual Selection of Variables</a></span></li><li><span><a href="#Statsmodels" data-toc-modified-id="Statsmodels-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Statsmodels</a></span><ul class="toc-item"><li><span><a href="#Def-Manual-Stats-features" data-toc-modified-id="Def-Manual-Stats-features-4.1.4.1"><span class="toc-item-num">4.1.4.1&nbsp;&nbsp;</span>Def Manual Stats features</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Bring-Attack-and-Defense-strength-together" data-toc-modified-id="Bring-Attack-and-Defense-strength-together-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Bring Attack and Defense strength together</a></span><ul class="toc-item"><li><span><a href="#Att-Str" data-toc-modified-id="Att-Str-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Att Str</a></span></li><li><span><a href="#Def-Str" data-toc-modified-id="Def-Str-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Def Str</a></span></li><li><span><a href="#Predict" data-toc-modified-id="Predict-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Predict</a></span></li><li><span><a href="#Compare" data-toc-modified-id="Compare-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Compare</a></span></li></ul></li><li><span><a href="#Predict-Score" data-toc-modified-id="Predict-Score-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Predict Score</a></span></li><li><span><a href="#Single-Line-Predictions" data-toc-modified-id="Single-Line-Predictions-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Single Line Predictions</a></span></li><li><span><a href="#End-to-end" data-toc-modified-id="End-to-end-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>End to end</a></span></li><li><span><a href="#Test-on-2018" data-toc-modified-id="Test-on-2018-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Test on 2018</a></span></li></ul></div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import log_loss


from sklearn.preprocessing import LabelEncoder,StandardScaler, MinMaxScaler
from sklearn.model_selection import StratifiedKFold, KFold, cross_val_score, cross_val_predict
from sklearn import ensemble, metrics, model_selection as ms, preprocessing, tree
from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline
from sklearn import linear_model as lm
from sklearn import svm
from sklearn import neighbors
from sklearn import linear_model, tree, discriminant_analysis, naive_bayes, ensemble, gaussian_process

import statsmodels.api as sm
import statsmodels.formula.api as smf
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 70)
import datetime


from pathlib import Path
import os
from os import listdir
from os.path import isfile, join

from sklearn.feature_selection import RFECV

# %% [markdown]
# ## Import custom functions

# %%
from _00_BettingFunctions import (ema_no_reset, moving_average_no_reset, restructure_ema, create_model_base,
                              optimise_alpha_classifier,optimise_alpha,track_best_span,create_model_probs_df,returns,expected_returns,result_returns,
                              determine_bet,most_likely_result,prediction_correct,bet_index_cutoff,bet_profit,
                              full_gambling_calc,create_model_base_scaled,full_gambling_calc_cutoff)

# %% [markdown]
# ## Read in Files

# %% [markdown]
# ### Results and model data

# %%
results = pd.read_csv(r"C:\\Users\Byron\Documents\Football Predictions\PremierLeaguePredictions\data\ff_us_1419.csv").drop("Unnamed: 0",axis=1)
results.tail()
# Out:
#       season     gameweek            matchid  \
# 4351    2019  Gameweek 28  /matches/1059980/
# 4352    2019  Gameweek 28  /matches/1059975/
# 4353    2019  Gameweek 28  /matches/1059975/
# 4354    2019  Gameweek 28  /matches/1059979/
# 4355    2019  Gameweek 28  /matches/1059979/
#
#                                            fixture            matchdate  \
# 4351                          Watford vs Liverpool  2020-02-29 17:30:00
# 4352                  Everton vs Manchester United  2020-03-01 14:00:00
# 4353                  Everton vs Manchester United  2020-03-01 14:00:00
# 4354  Tottenham Hotspur vs Wolverhampton Wanderers  2020-03-01 14:00:00
# 4355  Tottenham Hotspur vs Wolverhampton Wanderers  2020-03-01 14:00:00
#
#                        f_Team  f_HmGame  f_Possession  \
# 4351                Liverpool         0          71.0
# 4352                  Everton         1          43.1
# 4353        Manchester United         0          56.9
# ...

# %% [markdown]
# ### Bookie Data

# %%
odds = pd.read_csv(r"C:\\Users\Byron\Documents\Football Predictions\PremierLeaguePredictions\data\bookie_odds.csv").drop("Unnamed: 0",axis=1)
odds_clean = odds[["season","fixture","FTR","bookie","BookieHomeOdds","BookieDrawOdds"
                  ,"BookieAwayOdds","BookieHomeProb","BookieDrawProb","BookieAwayProb"]].copy()
odds_clean.tail()
# Out:
#       season                             fixture FTR  bookie  BookieHomeOdds  \
# 2183    2018        Huddersfield Town vs Arsenal   A  Bet365            5.75
# 2184    2018                   Fulham vs Arsenal   A  Bet365            5.25
# 2185    2018  Wolverhampton Wanderers vs Arsenal   H  Bet365            2.90
# 2186    2018             Cardiff City vs Arsenal   A  Bet365            6.50
# 2187    2019         Sheffield United vs Arsenal   H  Bet365            3.90
#
#       BookieDrawOdds  BookieAwayOdds  BookieHomeProb  BookieDrawProb  \
# 2183            4.40            1.60        0.173913        0.227273
# 2184            4.33            1.66        0.190476        0.230947
# 2185            3.50            2.55        0.344828        0.285714
# 2186            4.33            1.57        0.153846        0.230947
# 2187            3.75            1.90        0.256410        0.266667
#
#       BookieAwayProb
# 2183        0.625000
# 2184        0.602410
# ...

# %%
merge_vars = ["season","matchid","gw_no","fixture","matchdate"]
team_vars = ["HomeTeam","AwayTeam"]
pred_cols = ["Model_Prob_"+col for col in ["A","D","H"]]
gamble_cols = merge_vars + team_vars + pred_cols
print(gamble_cols)
# Out:
# ['season', 'matchid', 'gw_no', 'fixture', 'matchdate', 'HomeTeam', 'AwayTeam', 'Model_Prob_A', 'Model_Prob_D', 'Model_Prob_H']

# %%
bookie_home_odds = "BookieHomeOdds"
bookie_draw_odds = "BookieDrawOdds"
bookie_away_odds = "BookieAwayOdds"
bookie_home_prob = "BookieHomeProb"
bookie_draw_prob = "BookieDrawProb"
bookie_away_prob = "BookieAwayProb"

model_home = "Model_Prob_H"
model_draw = "Model_Prob_D"
model_away = "Model_Prob_A"

stake = 5

# %% [markdown]
# ### Teamnames Lookup

# %%
TeamNames = pd.read_csv(r"C:\\Users\Byron\Documents\Football Predictions\PremierLeaguePredictions\data\PremTeamNamesLookup.csv")
TeamNames.tail(25)
# Out:
#    league      FootballData                Understat                  FFScout  \
# 5     EPL           Cardiff                  Cardiff             Cardiff City
# 6     EPL           Chelsea                  Chelsea                  Chelsea
# 7     EPL    Crystal Palace           Crystal Palace           Crystal Palace
# 8     EPL           Everton                  Everton                  Everton
# 9     EPL            Fulham                   Fulham                   Fulham
# 10    EPL      Huddersfield             Huddersfield        Huddersfield Town
# 11    EPL              Hull                     Hull                Hull City
# 12    EPL         Leicester                Leicester           Leicester City
# 13    EPL         Liverpool                Liverpool                Liverpool
# 14    EPL          Man City          Manchester City          Manchester City
# 15    EPL        Man United        Manchester United        Manchester United
# ...

# %% [markdown]
# ### Transfermarkt

# %%
transfermarkt = pd.read_csv(r"C:\\Users\Byron\Documents\Football Predictions\PremierLeaguePredictions\data\TransferMarkt.csv")
transfermarkt.tail()
# Out:
#      Season                  Club  Squad   Age  Foreigners  TotalMarket   \
# 115    2014          Swansea City     36  24.3          30         96.93
# 116    2014  West Bromwich Albion     34  25.5          22         90.54
# 117    2014        Crystal Palace     42  26.0          25         80.37
# 118    2014        Leicester City     37  25.9          18         50.27
# 119    2014            Burnley FC     30  25.5          13         33.08
#
#      AverageMarketValue
# 115                2.69
# 116                2.66
# 117                1.91
# 118                1.36
# 119                1.10

# %%
def lookupclean(lkup,newFile,newFileName,keepName,joinName):
    output = lkup[[keepName,joinName]].copy()
    output = pd.merge(output,newFile,left_on=joinName,right_on=newFileName)
    output = output.drop([joinName,newFileName],axis=1)
    return output

transfermarkt_clean = lookupclean(TeamNames,transfermarkt,"Club","FFScout","Transfermarkt")
transfermarkt_clean.head()
# Out:
#    FFScout  Season  Squad   Age  Foreigners  TotalMarket   AverageMarketValue
# 0  Arsenal    2018     42  23.9          28        533.97               12.71
# 1  Arsenal    2019     27  25.6          19        521.42               19.31
# 2  Arsenal    2017     45  23.8          27        570.51               12.68
# 3  Arsenal    2016     42  23.7          26        470.48               11.20
# 4  Arsenal    2015     41  23.7          29        367.74                8.97

# %%
AMVMean =(transfermarkt_clean.groupby("Season")[["AverageMarketValue"]].mean().reset_index().rename(columns={"AverageMarketValue":"AVMMean"}))
AMVMean

tm = pd.merge(transfermarkt_clean,AMVMean)
tm["AMVIndex"]=tm["AverageMarketValue"]/tm["AVMMean"]

tm.head()
# Out:
#                     FFScout  Season  Squad   Age  Foreigners  TotalMarket   \
# 0                   Arsenal    2018     42  23.9          28        533.97
# 1               Bournemouth    2018     37  24.7          16        155.52
# 2  Brighton and Hove Albion    2018     41  24.8          29        155.39
# 3                   Burnley    2018     33  27.1          14        167.18
# 4              Cardiff City    2018     35  26.3          32         68.40
#
#    AverageMarketValue  AVMMean  AMVIndex
# 0               12.71   9.4475  1.345329
# 1                4.20   9.4475  0.444562
# 2                3.79   9.4475  0.401164
# 3                5.07   9.4475  0.536650
# 4                1.95   9.4475  0.206404

# %% [markdown]
# ### XG Predictions file

# %%
xg_pred_cols = ["AttStr_Home","DefStr_Home","AttStr_Away","DefStr_Away","Pred_HG","Pred_AG"]

# %%
xg_pred = pd.read_csv(r"C:\\Users\Byron\Documents\Football Predictions\UnderstatPredictions\Datasets\xg_predictions.csv")
xg_pred = xg_pred[(xg_pred["league"]=="EPL") &
                 (xg_pred["AverageMethod"]=="EMA No reset")]

xg_pred["season"] = xg_pred["season"].apply(lambda x: x[:4])

xg_pred_clean = xg_pred[["season","fixture","season_gw","Team_Home","Team_Away","AttStr_Home",
                  "DefStr_Home","AttStr_Away","DefStr_Away","Pred_HG","Pred_AG"]].dropna()

xg_pred_clean = lookupclean(TeamNames,xg_pred_clean,"Team_Home","FFScout","Understat").rename(columns={"FFScout":"HomeTeam"})
xg_pred_clean = lookupclean(TeamNames,xg_pred_clean,"Team_Away","FFScout","Understat").rename(columns={"FFScout":"AwayTeam"})
xg_pred_clean["fixture"] = xg_pred_clean["HomeTeam"]+ " vs " + xg_pred_clean["AwayTeam"]
xg_pred_clean["season"] = xg_pred_clean["season"].apply(lambda x: int(x))
xg_pred_clean = xg_pred_clean.drop(columns=["HomeTeam","AwayTeam"])

xg_pred_clean.sort_values(by=["season","season_gw"])
# Out:
#       season                              fixture  season_gw  AttStr_Home  \
# 37      2014            Leicester City vs Arsenal          3     0.819551
# 450     2014                   Everton vs Chelsea          3     0.891405
# 594     2014   Newcastle United vs Crystal Palace          3     0.750911
# 805     2014             Aston Villa vs Hull City          3     0.637036
# 1037    2014       Tottenham Hotspur vs Liverpool          3     1.560331
# ...      ...                                  ...        ...          ...
# 1407    2019      Manchester City vs Norwich City         38     1.725867
# 1456    2019      Southampton vs Sheffield United         38     0.992274
# 1810    2019  Crystal Palace vs Tottenham Hotspur         38     0.717594
# 1892    2019                   Arsenal vs Watford         38     1.021431
# 2174    2019   Chelsea vs Wolverhampton Wanderers         38     1.242563
#
#       DefStr_Home  AttStr_Away  DefStr_Away   Pred_HG   Pred_AG
# ...

# %%
xg_pred.head()
# Out:
#      league season                             fixture  season_gw  \
# 7344    EPL   2014        Manchester United vs Swansea          1
# 7348    EPL   2014                Leicester vs Everton          1
# 7352    EPL   2014         Queens Park Rangers vs Hull          1
# 7356    EPL   2014                Stoke vs Aston Villa          1
# 7360    EPL   2014  West Bromwich Albion vs Sunderland          1
#
#                  Team_Home    Team_Away  homegoals  awaygoals Result  \
# 7344     Manchester United      Swansea        1.0        2.0      A
# 7348             Leicester      Everton        2.0        2.0      D
# 7352   Queens Park Rangers         Hull        0.0        1.0      A
# 7356                 Stoke  Aston Villa        0.0        1.0      A
# 7360  West Bromwich Albion   Sunderland        2.0        2.0      D
#
#      AverageMethod  xG_av_Home  xGA_av_Home  AttStr_Home  DefStr_Home  \
# 7344  EMA No reset         NaN          NaN          NaN          NaN
# ...

# %% [markdown]
# ### Create Season Order

# %%
season_list = [2014,2015,2016,2017,2018,2019]
season_gws = range(1,39)
final_order = pd.DataFrame()
x= 1
for i in season_list:
    for j in season_gws:
        gw_order=pd.DataFrame(data={"season":i,"gw_no":j,"gw_sq":x},index=[0])
        final_order = final_order.append(gw_order)
        x = x+1
        
results = pd.merge(results,final_order, on = ["season","gw_no"]).copy()
results.tail()
# Out:
#       season     gameweek            matchid  \
# 4351    2019  Gameweek 28  /matches/1059980/
# 4352    2019  Gameweek 28  /matches/1059975/
# 4353    2019  Gameweek 28  /matches/1059975/
# 4354    2019  Gameweek 28  /matches/1059979/
# 4355    2019  Gameweek 28  /matches/1059979/
#
#                                            fixture            matchdate  \
# 4351                          Watford vs Liverpool  2020-02-29 17:30:00
# 4352                  Everton vs Manchester United  2020-03-01 14:00:00
# 4353                  Everton vs Manchester United  2020-03-01 14:00:00
# 4354  Tottenham Hotspur vs Wolverhampton Wanderers  2020-03-01 14:00:00
# 4355  Tottenham Hotspur vs Wolverhampton Wanderers  2020-03-01 14:00:00
#
#                        f_Team  f_HmGame  f_Possession  \
# 4351                Liverpool         0          71.0
# 4352                  Everton         1          43.1
# 4353        Manchester United         0          56.9
# ...

# %% [markdown]
# ## Create single line df
# We will use our results dataset to create a single line results dataset that contains the Result. This will be our target variable.

# %%
def home_teams(df,keep):
    outdf = df.copy()
    outdf = outdf.query("f_HmGame==1")
    outdf = outdf[keep]
    outdf=outdf.rename(columns={'f_Team': 'HomeTeam'})
    return outdf

def away_teams(df,keep):
    outdf = df.copy()
    outdf = outdf.query("f_HmGame==0")
    outdf = outdf[keep]
    outdf=outdf.rename(columns={'f_Team': 'AwayTeam'})
    return outdf

def fixture_scores(df,score_keep_vars):
    outdf = df.copy()
    outdf = outdf.query("f_HmGame==1")
    outdf = outdf[score_keep_vars]
    outdf=outdf.rename(columns={'f_Goals': 'HomeGoals',
                                'f_Goals Conceded': 'AwayGoals'})
    return outdf

def join_fixtures(home,away,scores,merge_vars):
    outdf= pd.merge(home,away,on=merge_vars)
    outdf = pd.merge(outdf,scores,on=merge_vars)
    return outdf
def final_outcome(fixtures,homegoals,awaygoals):
    outdf = fixtures.copy()
    outdf["Result"] = np.where(outdf[homegoals]>outdf[awaygoals],"H",
                              np.where(outdf[homegoals]<outdf[awaygoals],"A","D"))
    return outdf

# %%
keep_vars = ["season","matchid","gw_no","fixture","matchdate","f_Team"]
score_keep_vars = ["season","matchid","gw_no","fixture","matchdate","f_Goals","f_Goals Conceded"]
merge_vars = ["season","matchid","gw_no","fixture","matchdate"]
team_vars = ["HomeTeam","AwayTeam"]

# %%
hometeams = home_teams(results,keep_vars)
awayteams = away_teams(results,keep_vars)
scores = fixture_scores(results,score_keep_vars)
single_line = join_fixtures(hometeams,awayteams,scores,merge_vars)
single_line = final_outcome(single_line,"HomeGoals","AwayGoals")
single_line.tail()
# Out:
#       season            matchid  gw_no  \
# 2173    2019  /matches/1059977/     28
# 2174    2019  /matches/1059981/     28
# 2175    2019  /matches/1059980/     28
# 2176    2019  /matches/1059975/     28
# 2177    2019  /matches/1059979/     28
#
#                                            fixture            matchdate  \
# 2173                   Newcastle United vs Burnley  2020-02-29 15:00:00
# 2174                West Ham United vs Southampton  2020-02-29 15:00:00
# 2175                          Watford vs Liverpool  2020-02-29 17:30:00
# 2176                  Everton vs Manchester United  2020-03-01 14:00:00
# 2177  Tottenham Hotspur vs Wolverhampton Wanderers  2020-03-01 14:00:00
#
#                HomeTeam                 AwayTeam  HomeGoals  AwayGoals Result
# 2173   Newcastle United                  Burnley          0          0      D
# 2174    West Ham United              Southampton          3          1      H
# ...

# %% [markdown]
# ## Feature labelling

# %% [markdown]
# **List Features**

# %%
features = [i for i in results.columns if i.startswith("f_") and i !="f_Team"]
# def_features = [i for i in features if "Conceded" in i]
# att_features = [i for i in features if i not in def_features]
# calculated_features = ["f_netxg","f_xGRatio","f_ShotsRatio","f_ShOnTargetRatio"]
# print(att_features)
# print()
# print(def_features)
# print()
# print(calculated_features)

# %%
df_null = results[features].isnull().sum()/results[features].count()

# %%
##handling nulls
df_null = results[features].isnull().sum()/results[features].count()
df_null = df_null[df_null>0]
null_vars = df_null.index.tolist()
print(null_vars)

results = results.drop(null_vars,axis=1)
# Out:
# ['f_xA Expected Assists Conceded']

# %%
results[results['season']==2014].describe().loc["max"].sort_values()
# Out:
# f_xG Conceded                                      0.00000
# f_xA Expected Assists                              0.00000
# f_xG Expected Goals                                0.00000
# f_xG Open Play                                     0.00000
# f_xG Open Play Conceded                            0.00000
# f_HmGame                                           1.00000
# f_Goals From Penalties                             2.00000
# f_Points                                           3.00000
# f_US xG Conceded                                   5.35103
# f_US xG                                            5.35103
# f_Touches - Final Third log                        6.25575
# f_Big Chances Conceded                             8.00000
# f_Goals Conceded                                   8.00000
# f_Goals                                            8.00000
# f_Big Chances Total                                8.00000
# f_Shots On Target                                 16.00000
# ...

# %%
#remove variables that are blank
incomplete_vars = ["f_xG Open Play Conceded","f_xG Open Play","f_xA Expected Assists",
                   "f_xG Open Play","f_xG Expected Goals"]

# %%
features = [i for i in results.columns if i.startswith("f_") and i !="f_Team" 
            and i not in incomplete_vars]
def_features = [i for i in features if "Conceded" in i]
att_features = [i for i in features if i not in def_features]
calculated_features = ["f_netxg","f_xGRatio","f_ShotsRatio","f_ShOnTargetRatio"]
print(att_features)
print()
print(def_features)
# Out:
# ['f_HmGame', 'f_Possession', 'f_Touches - Final Third', 'f_Touches - Penalty Area', 'f_Passes - Final Third - Successful', 'f_Chances Created', 'f_Goals', 'f_Goals From Penalties', 'f_Goal Attempts', 'f_Shots - Inside Box', 'f_Big Chances Total', 'f_Shots On Target', 'f_US xG', 'f_Points', 'f_Touches - Final Third log']
#
# ['f_Goal Attempts In Box Conceded', 'f_Shots Conceded', 'f_Shots On Target Conceded', 'f_Big Chances Conceded', 'f_Goals Conceded', 'f_xG Conceded', 'f_Touches - Final Third Conceded', 'f_Touches - Penalty Area Conceded', 'f_Passes - Final Third - Successful Conceded', 'f_US xG Conceded', 'f_Chances Conceded']

# %% [markdown]
# ### Split out seasons

# %%
training = results[results["season"].isin([2014,2015,2016,2017])]
test = results[results["season"]==2018]
holdout = results[results["season"]==2019]

# %% [markdown]
# ### Create target goals dataframe
# This contains target variables for a per team modelling dataset predicting goals scored or conceded

# %%
target_goals = results[['f_Team', 'matchid','f_HmGame','f_Goals', 'f_Goals Conceded',"f_US xG", "f_US xG Conceded"]].copy() 
target_goals.columns = ['f_Team', 'matchid','f_HmGameFut','t_Goals', 't_Goals Conceded',"t_US xG", "t_US xG Conceded"]
target_goals.loc[0:,"t_Goals_Scored_In"] = np.where(target_goals["t_Goals"]>0,1,0)
target_goals.loc[0:,"t_Goals_Conceded_In"] = np.where(target_goals["t_Goals Conceded"]>0,1,0)
target_goals.head()
# Out:
#               f_Team           matchid  f_HmGameFut  t_Goals  \
# 0       Swansea City  /matches/755307/            0        2
# 1  Manchester United  /matches/755307/            1        1
# 2            Everton  /matches/755305/            0        2
# 3     Leicester City  /matches/755305/            1        2
# 4          Hull City  /matches/755309/            0        1
#
#    t_Goals Conceded   t_US xG  t_US xG Conceded  t_Goals_Scored_In  \
# 0                 1  0.278076          1.166350                  1
# 1                 2  1.166350          0.278076                  1
# 2                 2  0.613273          1.278300                  1
# 3                 2  1.278300          0.613273                  1
# 4                 0  1.117570          1.900670                  1
#
#    t_Goals_Conceded_In
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    0

# %%
target_goals[target_goals["f_Team"]== "Everton"].nunique()
# Out:
# f_Team                   1
# matchid                218
# f_HmGameFut              2
# t_Goals                  7
# t_Goals Conceded         7
# t_US xG                218
# t_US xG Conceded       218
# t_Goals_Scored_In        2
# t_Goals_Conceded_In      2
# dtype: int64

# %% [markdown]
# ### Variable lists

# %%
kfold = StratifiedKFold(n_splits=5,shuffle=True, random_state=42)
cv = KFold(n_splits = 5, shuffle =True, random_state = 42)

# %%
classifier_vars = [i +"_Home" for i in features] + [i + "_Away" for i in features]
classifier_att_vars = [i +"_Home" for i in att_features] + [i + "_Away" for i in att_features]
classifier_def_vars = [i +"_Home" for i in def_features] + [i + "_Away" for i in def_features]
classifier_calc_vars = [i +"_Home" for i in calculated_features] + [i + "_Away" for i in calculated_features]
print(classifier_att_vars)
# Out:
# ['f_HmGame_Home', 'f_Possession_Home', 'f_Touches - Final Third_Home', 'f_Touches - Penalty Area_Home', 'f_Passes - Final Third - Successful_Home', 'f_Chances Created_Home', 'f_Goals_Home', 'f_Goals From Penalties_Home', 'f_Goal Attempts_Home', 'f_Shots - Inside Box_Home', 'f_Big Chances Total_Home', 'f_Shots On Target_Home', 'f_US xG_Home', 'f_Points_Home', 'f_Touches - Final Third log_Home', 'f_HmGame_Away', 'f_Possession_Away', 'f_Touches - Final Third_Away', 'f_Touches - Penalty Area_Away', 'f_Passes - Final Third - Successful_Away', 'f_Chances Created_Away', 'f_Goals_Away', 'f_Goals From Penalties_Away', 'f_Goal Attempts_Away', 'f_Shots - Inside Box_Away', 'f_Big Chances Total_Away', 'f_Shots On Target_Away', 'f_US xG_Away', 'f_Points_Away', 'f_Touches - Final Third log_Away']

# %%
test_all_vars = classifier_vars + classifier_calc_vars + ["f_AMVIndex_Home","f_AMVIndex_Away"] +xg_pred_cols
non_xg_vars = classifier_vars + classifier_calc_vars + ["f_AMVIndex_Home","f_AMVIndex_Away"]

# %% [markdown]
# ### Scaling

# %%
standard_scaler = StandardScaler()
min_max_scaler = MinMaxScaler()

# %%
rf = ensemble.RandomForestClassifier(n_estimators = 50,random_state=42, max_depth=2)
lr = lm.LogisticRegression(solver='lbfgs', multi_class='auto', max_iter=1000)

# %% [markdown]
# # Creating an Attacking Strength Metric
# I want to create an attacking strength metric for each team. I have a baseline Attacking strength metric, which is weighted average xG for divided by a league average xG. I will use this as a baseline for comparison.<br>
# <br>
# I have two options for target variables for an attacking strength metric. One is Goals Scored in a game, the other is xG in a game. <br>
# <br>
# Finally for attacking and defensive strength, I want to use only attacking or defensive metrics. I will keep ratios for both. I also want to exclude Home or Away impact - I want to be able to isolate that later.

# %% [markdown]
# # Plotting xG Attack and Defence

# %% [markdown]
# ## Unscaled

# %%
features = [f for f in results.columns if f.startswith("f_") and f !="f_Team" 
            and f not in incomplete_vars]

ema_output = ema_no_reset(training, span=36,feature_cols=features)

# %%
random_week = ema_output[(ema_output["season"]==2016) &
                        (ema_output["gw_no"]==19)].copy()#.set_index("f_Team")[['f_Possession', 'f_Points']]
random_week.head(1)
# Out:
#                matchid   f_Team     gameweek  season  f_HmGame  \
# 1880  /matches/855355/  Everton  Gameweek 19    2016  0.494122
#
#                    fixture            matchdate  gw_no  \
# 1880  Hull City vs Everton  2016-12-31 00:00:00     19
#
#       f_Touches - Final Third log  f_Passes - Final Third - Successful  \
# 1880                     5.074028                             74.69212
#
#       f_xG Conceded  f_Chances Conceded   f_Goals   f_US xG  \
# 1880       0.057828            9.768837  1.286316  1.254256
#
#       f_Goals From Penalties  f_Shots Conceded  f_Touches - Final Third  \
# 1880                0.096012         12.782161               167.087844
#
#       f_Chances Created  f_Big Chances Conceded  f_US xG Conceded  \
# 1880           9.465628                1.626526           1.35267
#
#       f_Shots On Target  f_Goal Attempts In Box Conceded  \
# 1880           4.270847                         7.677381
#
# ...

# %%
def scatter_text(x, y, text_column, data, title, xlabel, ylabel):
    """Scatter plot with country codes on the x y coordinates
       Based on this answer: https://stackoverflow.com/a/54789170/2641825"""
    # Create the scatter plot
    p1 = sns.scatterplot(x, y, data=data, size =8, legend=False)
    # Add text besides each point
    for line in range(0,data.shape[0]):
         p1.text(data[x].iloc[line]+0.01, data[y].iloc[line], 
                 data[text_column].iloc[line], horizontalalignment='left', 
                 size='small', color='black', weight='semibold')
    # Set title and axis labels
    p1.invert_yaxis()
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    return p1

plt.figure(figsize=(10,6))
scatter_text('f_US xG', 'f_US xG Conceded', 'f_Team',
             data = random_week, 
             title = 'xG Averages', 
             xlabel = 'xG Attack',
             ylabel = 'xG Conceded')

# %%
# ax = random_week.plot('f_Possession', 'f_Points', kind='scatter', s=50 )

# def annotate_df(row):  
#     ax.annotate(row.index, row.values,
#                 xytext=(1,1), 
#                 textcoords='offset points',
#                 size=18, 
#                 color='darkslategrey')

# _ = random_week.apply(annotate_df, axis=1)

# %% [markdown]
# ## Scaled

# %%
random_week = ema_output.copy()
random_week[features] = standard_scaler.fit_transform(random_week[features])
random_week = random_week[(random_week["season"]==2016) &
                        (random_week["gw_no"]==19)]#.set_index("f_Team")[['f_Possession', 'f_Points']]

random_week.head(1)
# Out:
#                matchid   f_Team     gameweek  season  f_HmGame  \
# 1880  /matches/855355/  Everton  Gameweek 19    2016 -0.166272
#
#                    fixture            matchdate  gw_no  \
# 1880  Hull City vs Everton  2016-12-31 00:00:00     19
#
#       f_Touches - Final Third log  f_Passes - Final Third - Successful  \
# 1880                     0.009802                            -0.050714
#
#       f_xG Conceded  f_Chances Conceded   f_Goals   f_US xG  \
# 1880      -0.372334            0.162589 -0.135047 -0.089093
#
#       f_Goals From Penalties  f_Shots Conceded  f_Touches - Final Third  \
# 1880                 0.07763           0.02797                -0.076238
#
#       f_Chances Created  f_Big Chances Conceded  f_US xG Conceded  \
# 1880          -0.037482                0.232567          0.310147
#
#       f_Shots On Target  f_Goal Attempts In Box Conceded  \
# 1880           0.128433                         0.200884
#
# ...

# %%
plt.figure(figsize=(10,6))
scatter_text('f_US xG', 'f_US xG Conceded', 'f_Team',
             data = random_week, 
             title = 'xG Averages', 
             xlabel = 'xG Attack',
             ylabel = 'xG Conceded')

# %% [markdown]
# This works quite nicely as we have almost 10 teams that are in each half above average and below average in attacking and defensive strength as per xG. <br>
# As the scaling is fitted over a 4 year period and we're taking a random gameweek, the scaled xG strengths may not always return exact averages for a specif season.

# %% [markdown]
# ## Compare xG indexes

# %%
#Comeback to this later

# %% [markdown]
# # Creating modelled attacking strength

# %% [markdown]
# ## Predicting Goals

# %% [markdown]
# ### RFECV Linear Regression

# %%
print(att_features)
print()
print(calculated_features)
# Out:
# ['f_HmGame', 'f_Possession', 'f_Touches - Final Third', 'f_Touches - Penalty Area', 'f_Passes - Final Third - Successful', 'f_Chances Created', 'f_Goals', 'f_Goals From Penalties', 'f_Goal Attempts', 'f_Shots - Inside Box', 'f_Big Chances Total', 'f_Shots On Target', 'f_US xG', 'f_Points', 'f_Touches - Final Third log']
#
# ['f_netxg', 'f_xGRatio', 'f_ShotsRatio', 'f_ShOnTargetRatio']

# %%
import random
random.seed(42)
test_weeks = random.sample(range(1,152),2)

# %%
def season_split(df,test_size,sample_var):
    sq = df[sample_var].unique().tolist()
    no_sq = int(test_size*float(len(sq)))
    random.seed(42)
    test_sq = random.sample(sq,no_sq)
    train = df[~df[sample_var].isin(test_sq)]
    test = df[df[sample_var].isin(test_sq)]
    return train, test

test_eg, train_eg = season_split(results,0.3,"gw_sq")

# %%
features = [f for f in results.columns if f.startswith("f_") and f !="f_Team" 
            and f not in incomplete_vars]

ema_output = ema_no_reset(training, span=36,feature_cols=features)
ema_target = pd.merge(ema_output, target_goals, on = ['f_Team','matchid']).dropna()
ema_target = pd.merge(ema_target,tm[["FFScout","Season","AMVIndex"]],left_on=["f_Team","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex"}).drop(["FFScout","Season"],axis=1)
ema_target = pd.merge(ema_target,final_order, on = ["season","gw_no"]).copy()

train, test = season_split(ema_target,0.2,"gw_sq")
#train, test = train_test_split(ema_target,test_size = 0.2,random_state=42)

y = train["t_Goals"]
X = train[att_features + calculated_features + ["f_AMVIndex"]].drop(columns=("f_HmGame"))
rfmod = lm.LinearRegression()
rfecv = RFECV(estimator=rfmod, step=1, cv=StratifiedKFold(n_splits=10, random_state=42), scoring='neg_mean_squared_error')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
print("Best MSE Score: {}".format((-1*rfecv.grid_scores_).min()))
print("Worst MSE Score:{}".format((-1*rfecv.grid_scores_).max()))
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# Optimal number of features: 11
# Best MSE Score: 1.404375477990158
# Worst MSE Score:1.4467710561244589

# %%
att_pred_vars1 = list(X.columns[rfecv.support_])
att_pred_vars1
# Out:
# ['f_Goals',
#  'f_Goal Attempts',
#  'f_Shots - Inside Box',
#  'f_Big Chances Total',
#  'f_US xG',
#  'f_Touches - Final Third log',
#  'f_netxg',
#  'f_xGRatio',
#  'f_ShotsRatio',
#  'f_ShOnTargetRatio',
#  'f_AMVIndex']

# %% [markdown]
# **xG features without ratios**

# %%
y = train["t_Goals"]
X = train[att_features + ["f_AMVIndex"]].drop(columns=["f_HmGame"])
rfmod = lm.LinearRegression()
rfecv = RFECV(estimator=rfmod, step=1, cv=StratifiedKFold(n_splits=10, random_state=42), scoring='neg_mean_squared_error')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
print("Best MSE Score: {}".format((-1*rfecv.grid_scores_).min()))
print("Worst MSE Score:{}".format((-1*rfecv.grid_scores_).max()))
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# Optimal number of features: 10
# Best MSE Score: 1.4011613997770707
# Worst MSE Score:1.4139418649022732

# %%
att_pred_vars2 = list(X.columns[rfecv.support_])
att_pred_vars2
# Out:
# ['f_Touches - Penalty Area',
#  'f_Goals',
#  'f_Goals From Penalties',
#  'f_Goal Attempts',
#  'f_Shots - Inside Box',
#  'f_Big Chances Total',
#  'f_Shots On Target',
#  'f_US xG',
#  'f_Touches - Final Third log',
#  'f_AMVIndex']

# %% [markdown]
# **Feature Summary** <br>
# Features made more sense with normal test train split

# %% [markdown]
# ### RFECV Random Forest

# %%
y = train["t_Goals"]
X = train[att_features + calculated_features + ["f_AMVIndex"]].drop(columns=["f_HmGame"])
rfmod = ensemble.RandomForestRegressor(n_estimators=50, random_state=42, max_depth = 2)
rfecv = RFECV(estimator=rfmod, step=1, cv=StratifiedKFold(n_splits=10, random_state=42), scoring='neg_mean_squared_error')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
print("Best MSE Score: {}".format((-1*rfecv.grid_scores_).min()))
print("Worst MSE Score:{}".format((-1*rfecv.grid_scores_).max()))
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# Optimal number of features: 19
# Best MSE Score: 1.4037271051284148
# Worst MSE Score:1.4240765623213503

# %%
print(pd.Series(rfecv.support_,index = X.columns)[lambda x: x==True])
X.drop(X.columns[np.where(rfecv.support_ == False)[0]], axis=1, inplace=True)

dset = pd.DataFrame()
dset['attr'] = X.columns
dset['importance'] = rfecv.estimator_.feature_importances_

dset = dset.sort_values(by='importance', ascending=False)


plt.figure(figsize=(8, 3))
plt.barh(y=dset['attr'], width=dset['importance'], color='#1976D2')
plt.title('RFECV - Feature Importances', fontsize=20, fontweight='bold', pad=20)
plt.xlabel('Importance', fontsize=14, labelpad=20)
plt.show()
# Out:
# f_Possession                           True
# f_Touches - Final Third                True
# f_Touches - Penalty Area               True
# f_Passes - Final Third - Successful    True
# f_Chances Created                      True
# f_Goals                                True
# f_Goals From Penalties                 True
# f_Goal Attempts                        True
# f_Shots - Inside Box                   True
# f_Big Chances Total                    True
# f_Shots On Target                      True
# f_US xG                                True
# f_Points                               True
# f_Touches - Final Third log            True
# f_netxg                                True
# f_xGRatio                              True
# f_ShotsRatio                           True
# f_ShOnTargetRatio                      True
# f_AMVIndex                             True
# dtype: bool

# %%
att_pred_vars3 = list(X.columns)
att_pred_vars3
# Out:
# ['f_Possession',
#  'f_Touches - Final Third',
#  'f_Touches - Penalty Area',
#  'f_Passes - Final Third - Successful',
#  'f_Chances Created',
#  'f_Goals',
#  'f_Goals From Penalties',
#  'f_Goal Attempts',
#  'f_Shots - Inside Box',
#  'f_Big Chances Total',
#  'f_Shots On Target',
#  'f_US xG',
#  'f_Points',
#  'f_Touches - Final Third log',
#  'f_netxg',
#  'f_xGRatio',
#  'f_ShotsRatio',
#  'f_ShOnTargetRatio',
#  'f_AMVIndex']

# %% [markdown]
# **Without Ratios**

# %%
y = train["t_Goals"]
X = train[att_features + ["f_AMVIndex"]].drop(columns=["f_HmGame"])
rfmod = ensemble.RandomForestRegressor(n_estimators=50, random_state=42, max_depth = 2)
rfecv = RFECV(estimator=rfmod, step=1, cv=StratifiedKFold(n_splits=10, random_state=42), scoring='neg_mean_squared_error')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
print("Best MSE Score: {}".format((-1*rfecv.grid_scores_).min()))
print("Worst MSE Score:{}".format((-1*rfecv.grid_scores_).max()))
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# Optimal number of features: 13
# Best MSE Score: 1.40294789299402
# Worst MSE Score:1.4240765623213503

# %%
print(pd.Series(rfecv.support_,index = X.columns)[lambda x: x==True])
X.drop(X.columns[np.where(rfecv.support_ == False)[0]], axis=1, inplace=True)

dset = pd.DataFrame()
dset['attr'] = X.columns
dset['importance'] = rfecv.estimator_.feature_importances_

dset = dset.sort_values(by='importance', ascending=False)


plt.figure(figsize=(8, 3))
plt.barh(y=dset['attr'], width=dset['importance'], color='#1976D2')
plt.title('RFECV - Feature Importances', fontsize=20, fontweight='bold', pad=20)
plt.xlabel('Importance', fontsize=14, labelpad=20)
plt.show()
# Out:
# f_Possession                   True
# f_Touches - Final Third        True
# f_Touches - Penalty Area       True
# f_Chances Created              True
# f_Goals                        True
# f_Goal Attempts                True
# f_Shots - Inside Box           True
# f_Big Chances Total            True
# f_Shots On Target              True
# f_US xG                        True
# f_Points                       True
# f_Touches - Final Third log    True
# f_AMVIndex                     True
# dtype: bool

# %% [markdown]
# ### Manual Selection of Variables

# %%
att_manual = ["f_US xG","f_AMVIndex","f_Touches - Penalty Area","f_Points"]
y = train["t_Goals"]
X = train[att_manual]
rfmod = lm.LinearRegression()
print(cross_val_score(rfmod,X,y,scoring = "neg_mean_squared_error",cv = kfold).mean())
print(cross_val_score(rfmod,X,y,scoring = "neg_mean_squared_error",cv = cv).mean())
# Out:
# -1.4023096005751816
# -1.4013206401958709
# C:\Users\Byron\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)

# %% [markdown]
# ### Statsmodels

# %%
# features_ns = [i.replace(' ', '_') for i in att_features]
# features_ns = [i.replace('-', '') for i in features_ns]

# ema_output = ema_no_reset(training, span=36,feature_cols=features)
# ema_target = pd.merge(ema_output, target_goals, on = ['f_Team','matchid']).dropna()
# ema_target = pd.merge(ema_target,tm[["FFScout","Season","AMVIndex"]],left_on=["f_Team","season"],
#          right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex"}).drop(["FFScout","Season"],axis=1)

# train, test = train_test_split(ema_target, test_size=0.2,random_state=42)

#X = train[att_features + ["f_AMVIndex"]].copy().drop(columns=["f_HmGame"])
X = train[att_features].drop(columns=("f_HmGame"))
X.columns = X.columns.str.replace(' ', '_')
X.columns = X.columns.str.replace('-', '')
y = train["t_Goals"].copy()
y = y.apply(lambda x: float(x))

formula = 't_Goals ~ ' + ' + '.join(x for x in X.columns)
#print(formula)
X1 = X.copy()
X1 = sm.add_constant(X1)

# model = smf.ols(
#     formula,
#     data=ema_target
# ).fit()

model = sm.OLS(y,X1).fit()

model.summary()
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                t_Goals   R-squared:                       0.103
# Model:                            OLS   Adj. R-squared:                  0.097
# Method:                 Least Squares   F-statistic:                     19.45
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):           5.08e-47
# Time:                        22:32:21   Log-Likelihood:                -3789.3
# No. Observations:                2394   AIC:                             7609.
# Df Residuals:                    2379   BIC:                             7695.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...

# %%
round(model.pvalues.iloc[np.where(model.pvalues<0.1)],5).sort_values()
# Out:
# f_Touches__Penalty_Area    0.00139
# dtype: float64

# %% [markdown]
# Penalty Area Touches is the only variable that is significant. There are too many correlated variables here for the model to pick out

# %%
X = train[att_features+calculated_features + ["f_AMVIndex"]].drop(columns=("f_HmGame"))
# X.columns = X.columns.str.replace(' ', '_')
# X.columns = X.columns.str.replace('-', '')
y = train["t_Goals"].copy()
y = y.apply(lambda x: float(x))

formula = 't_Goals ~ ' + ' + '.join(x for x in X.columns)
#print(formula)
X1 = X.copy()
X1 = sm.add_constant(X1)

model = sm.OLS(y,X1).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                t_Goals   R-squared:                       0.105
# Model:                            OLS   Adj. R-squared:                  0.098
# Method:                 Least Squares   F-statistic:                     14.64
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):           4.62e-45
# Time:                        22:32:22   Log-Likelihood:                -3786.5
# No. Observations:                2394   AIC:                             7613.
# Df Residuals:                    2374   BIC:                             7729.
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
print(round(model.pvalues.iloc[np.where(model.pvalues<0.1)],5).sort_values())
stats_sig = pd.DataFrame(model.pvalues.iloc[np.where(model.pvalues<0.1)]).index.values.tolist()
# Out:
# f_Touches - Penalty Area    0.00519
# f_AMVIndex                  0.02867
# dtype: float64

# %% [markdown]
# Now we have only 2 variables that are statistically significant and Penalty Area Touches. This looks sensible.
# <br>
# How does our manual selection of variables compare

# %%
X = train[att_manual]
X.columns = X.columns.str.replace(' ', '_')
X.columns = X.columns.str.replace('-', '')
y = train["t_Goals"].copy()
y = y.apply(lambda x: float(x))

formula = 't_Goals ~ ' + ' + '.join(x for x in X.columns)
#print(formula)
X1 = X.copy()
X1 = sm.add_constant(X1)

model = sm.OLS(y,X1).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                t_Goals   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.095
# Method:                 Least Squares   F-statistic:                     64.10
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):           1.51e-51
# Time:                        22:32:22   Log-Likelihood:                -3797.0
# No. Observations:                2394   AIC:                             7604.
# Df Residuals:                    2389   BIC:                             7633.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
y = train["t_Goals"]
X = train[att_manual]
rfmod = lm.LinearRegression()
print(cross_val_score(rfmod,X,y,scoring = "neg_mean_squared_error",cv = cv).mean())
y = train["t_Goals"]
X = train[stats_sig]
rfmod = lm.LinearRegression()
print(cross_val_score(rfmod,X,y,scoring = "neg_mean_squared_error",cv = cv).mean())
print("compare test set")
y = test["t_Goals"]
X = test[att_manual]
print(cross_val_score(rfmod,X,y,scoring = "neg_mean_squared_error",cv = cv).mean())
y = test["t_Goals"]
X = test[stats_sig]
rfmod = lm.LinearRegression()
print(cross_val_score(rfmod,X,y,scoring = "neg_mean_squared_error",cv = cv).mean())
# Out:
# -1.4013206401958709
# -1.400811813049615
# compare test set
# -1.4219940466295538
# -1.422297874938587

# %% [markdown]
# # Creating modelled defensive strength

# %% [markdown]
# ## Predicting Goals Conceded

# %% [markdown]
# ### RFECV Linear Regression

# %%
print(def_features)
print()
print(calculated_features)
train.columns
# Out:
# ['f_Goal Attempts In Box Conceded', 'f_Shots Conceded', 'f_Shots On Target Conceded', 'f_Big Chances Conceded', 'f_Goals Conceded', 'f_xG Conceded', 'f_Touches - Final Third Conceded', 'f_Touches - Penalty Area Conceded', 'f_Passes - Final Third - Successful Conceded', 'f_US xG Conceded', 'f_Chances Conceded']
#
# ['f_netxg', 'f_xGRatio', 'f_ShotsRatio', 'f_ShOnTargetRatio']
# Index(['matchid', 'f_Team', 'gameweek', 'season', 'f_HmGame', 'fixture',
#        'matchdate', 'gw_no', 'f_Touches - Final Third log',
#        'f_Passes - Final Third - Successful', 'f_xG Conceded',
#        'f_Chances Conceded', 'f_Goals', 'f_US xG', 'f_Goals From Penalties',
#        'f_Shots Conceded', 'f_Touches - Final Third', 'f_Chances Created',
#        'f_Big Chances Conceded', 'f_US xG Conceded', 'f_Shots On Target',
#        'f_Goal Attempts In Box Conceded', 'f_Touches - Final Third Conceded',
#        'f_Touches - Penalty Area', 'f_Touches - Penalty Area Conceded',
# ...

# %%
# features = [f for f in results.columns if f.startswith("f_") and f !="f_Team" 
#             and f not in incomplete_vars]

# ema_output = ema_no_reset(training, span=36,feature_cols=features)
# ema_target = pd.merge(ema_output, target_goals, on = ['f_Team','matchid']).dropna()
# ema_target = pd.merge(ema_target,tm[["FFScout","Season","AMVIndex"]],left_on=["f_Team","season"],
#          right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex"}).drop(["FFScout","Season"],axis=1)

# train, test = train_test_split(ema_target, test_size=0.2,random_state=42)

y = train["t_Goals Conceded"]
X = train[def_features + calculated_features + ["f_AMVIndex"]]
rfmod = lm.LinearRegression()
rfecv = RFECV(estimator=rfmod, step=1, cv=KFold(n_splits=10, random_state=42), scoring='neg_mean_squared_error')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
print("Best MSE Score: {}".format((-1*rfecv.grid_scores_).min()))
print("Worst MSE Score:{}".format((-1*rfecv.grid_scores_).max()))
# Out:
# Optimal number of features: 7
# Best MSE Score: 1.5016871189294805
# Worst MSE Score:1.525318708826945

# %%
cross_val_score(rfmod,X,y,scoring ="neg_mean_squared_error",cv=cv).mean()
# Out:
# -1.5087856940580036

# %%
def_pred_vars1 = list(X.columns[rfecv.support_])
def_pred_vars1
# Out:
# ['f_Big Chances Conceded',
#  'f_US xG Conceded',
#  'f_netxg',
#  'f_xGRatio',
#  'f_ShotsRatio',
#  'f_ShOnTargetRatio',
#  'f_AMVIndex']

# %% [markdown]
# **xG features without ratios**

# %%
y = train["t_Goals Conceded"]
X = train[def_features + ["f_AMVIndex"]]
rfmod = lm.LinearRegression()
rfecv = RFECV(estimator=rfmod, step=1, cv=KFold(n_splits=10, random_state=42), scoring='neg_mean_squared_error')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
print("Best MSE Score: {}".format((-1*rfecv.grid_scores_).min()))
print("Worst MSE Score:{}".format((-1*rfecv.grid_scores_).max()))
# Out:
# Optimal number of features: 2
# Best MSE Score: 1.4985510172099343
# Worst MSE Score:1.5145355663071738

# %%
def_pred_vars2 = list(X.columns[rfecv.support_])
def_pred_vars2
# Out:
# ['f_Big Chances Conceded', 'f_AMVIndex']

# %% [markdown]
# **Feature Summary** <br>
# Only 2 variables

# %% [markdown]
# ### RFECV Random Forest

# %%
y = train["t_Goals Conceded"]
X = train[def_features + calculated_features + ["f_AMVIndex"]]
rfmod = ensemble.RandomForestRegressor(n_estimators=50, random_state=42, max_depth = 2)
rfecv = RFECV(estimator=rfmod, step=1, cv=KFold(n_splits=10, random_state=42), scoring='neg_mean_squared_error')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
print("Best MSE Score: {}".format((-1*rfecv.grid_scores_).min()))
print("Worst MSE Score:{}".format((-1*rfecv.grid_scores_).max()))
# Out:
# Optimal number of features: 14
# Best MSE Score: 1.5013093525834411
# Worst MSE Score:1.5143471209748456

# %%
print(pd.Series(rfecv.support_,index = X.columns)[lambda x: x==True])
X.drop(X.columns[np.where(rfecv.support_ == False)[0]], axis=1, inplace=True)

dset = pd.DataFrame()
dset['attr'] = X.columns
dset['importance'] = rfecv.estimator_.feature_importances_

dset = dset.sort_values(by='importance', ascending=False)


plt.figure(figsize=(8, 3))
plt.barh(y=dset['attr'], width=dset['importance'], color='#1976D2')
plt.title('RFECV - Feature Importances', fontsize=20, fontweight='bold', pad=20)
plt.xlabel('Importance', fontsize=14, labelpad=20)
plt.show()
# Out:
# f_Goal Attempts In Box Conceded                 True
# f_Shots Conceded                                True
# f_Shots On Target Conceded                      True
# f_Big Chances Conceded                          True
# f_Goals Conceded                                True
# f_Touches - Penalty Area Conceded               True
# f_Passes - Final Third - Successful Conceded    True
# f_US xG Conceded                                True
# f_Chances Conceded                              True
# f_netxg                                         True
# f_xGRatio                                       True
# f_ShotsRatio                                    True
# f_ShOnTargetRatio                               True
# f_AMVIndex                                      True
# dtype: bool
# C:\Users\Byron\Anaconda3\lib\site-packages\pandas\core\frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
def_pred_vars3 = list(X.columns)
def_pred_vars3
# Out:
# ['f_Goal Attempts In Box Conceded',
#  'f_Shots Conceded',
#  'f_Shots On Target Conceded',
#  'f_Big Chances Conceded',
#  'f_Goals Conceded',
#  'f_Touches - Penalty Area Conceded',
#  'f_Passes - Final Third - Successful Conceded',
#  'f_US xG Conceded',
#  'f_Chances Conceded',
#  'f_netxg',
#  'f_xGRatio',
#  'f_ShotsRatio',
#  'f_ShOnTargetRatio',
#  'f_AMVIndex']

# %% [markdown]
# **Without Ratios**

# %%
y = train["t_Goals Conceded"]
X = train[def_features + ["f_AMVIndex"]]
rfmod = ensemble.RandomForestRegressor(n_estimators=50, random_state=42, max_depth = 2)
rfecv = RFECV(estimator=rfmod, step=1, cv=KFold(n_splits=10, random_state=42), scoring='neg_mean_squared_error')
rfecv.fit(X, y)
print('Optimal number of features: {}'.format(rfecv.n_features_))
print("Best MSE Score: {}".format((-1*rfecv.grid_scores_).min()))
print("Worst MSE Score:{}".format((-1*rfecv.grid_scores_).max()))
# Out:
# Optimal number of features: 1
# Best MSE Score: 1.5018616393580329
# Worst MSE Score:1.51379726326537

# %%
print(pd.Series(rfecv.support_,index = X.columns)[lambda x: x==True])
X.drop(X.columns[np.where(rfecv.support_ == False)[0]], axis=1, inplace=True)

dset = pd.DataFrame()
dset['attr'] = X.columns
dset['importance'] = rfecv.estimator_.feature_importances_

dset = dset.sort_values(by='importance', ascending=False)


plt.figure(figsize=(8, 3))
plt.barh(y=dset['attr'], width=dset['importance'], color='#1976D2')
plt.title('RFECV - Feature Importances', fontsize=20, fontweight='bold', pad=20)
plt.xlabel('Importance', fontsize=14, labelpad=20)
plt.show()
# Out:
# f_AMVIndex    True
# dtype: bool
# C:\Users\Byron\Anaconda3\lib\site-packages\pandas\core\frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# ### Manual Selection of Variables

# %%
def_manual = ["f_US xG Conceded","f_AMVIndex","f_Touches - Penalty Area Conceded","f_xGRatio"]
y = train["t_Goals Conceded"]
X = train[def_manual]
rfmod = lm.LinearRegression()
cross_val_score(rfmod,X,y,scoring = "neg_mean_squared_error",cv = cv).mean()
# Out:
# -1.5002517992417064

# %% [markdown]
# ### Statsmodels

# %%
X = train[def_features]
y = train["t_Goals Conceded"].copy()
y = y.apply(lambda x: float(x))

formula = 't_Goals Conceded ~ ' + ' + '.join(x for x in X.columns)
#print(formula)
X1 = X.copy()
X1 = sm.add_constant(X1)

# model = smf.ols(
#     formula,
#     data=ema_target
# ).fit()

model = sm.OLS(y,X1).fit()

model.summary()
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       t_Goals Conceded   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     6.519
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):           8.66e-11
# Time:                        22:33:00   Log-Likelihood:                -3885.4
# No. Observations:                2394   AIC:                             7795.
# Df Residuals:                    2382   BIC:                             7864.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...

# %%
round(model.pvalues.iloc[np.where(model.pvalues<0.1)],5).sort_values()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# Nothing is significant. There are too many correlated variables here for the model to pick out

# %%
X = train[def_features+calculated_features + ["f_AMVIndex"]]
y = train["t_Goals Conceded"].copy()
y = y.apply(lambda x: float(x))

formula = 't_Goals Conceded ~ ' + ' + '.join(x for x in X.columns)
#print(formula)
X1 = X.copy()
X1 = sm.add_constant(X1)

model = sm.OLS(y,X1).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       t_Goals Conceded   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     6.448
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):           1.99e-14
# Time:                        22:33:00   Log-Likelihood:                -3870.1
# No. Observations:                2394   AIC:                             7774.
# Df Residuals:                    2377   BIC:                             7872.
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# ...

# %%
print(round(model.pvalues.iloc[np.where(model.pvalues<0.1)],5).sort_values())
stats_sig_def = pd.DataFrame(model.pvalues.iloc[np.where(model.pvalues<0.1)]).index.values.tolist()
# Out:
# f_AMVIndex                0.00058
# f_Big Chances Conceded    0.06548
# f_ShOnTargetRatio         0.08547
# dtype: float64

# %% [markdown]
# Now we have only 3 variables that are stats sig.
# <br>
# How does our manual selection of variables compare

# %% [markdown]
# #### Def Manual Stats features

# %%
def_manual = ["f_US xG Conceded","f_AMVIndex","f_Touches - Penalty Area Conceded","f_xGRatio"]
#def_manual = ["f_AMVIndex","f_xGRatio"]

X = train[def_manual]
y = train["t_Goals Conceded"].copy()
y = y.apply(lambda x: float(x))

formula = 't_Goals Conceded ~ ' + ' + '.join(x for x in X.columns)
#print(formula)
X1 = X.copy()
X1 = sm.add_constant(X1)

model = sm.OLS(y,X1).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       t_Goals Conceded   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     22.40
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):           3.52e-18
# Time:                        22:33:00   Log-Likelihood:                -3876.8
# No. Observations:                2394   AIC:                             7764.
# Df Residuals:                    2389   BIC:                             7793.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Bring Attack and Defense strength together

# %% [markdown]
# ## Att Str

# %%
att_manual = ["f_US xG","f_AMVIndex","f_Touches - Penalty Area","f_Points"]
y = train["t_Goals"]
X = train[att_manual]
rfmod = lm.LinearRegression()

lmAttStr = rfmod.fit(X,y)
print(metrics.mean_squared_error(y,lmAttStr.predict(X)))
print(metrics.mean_squared_error(test["t_Goals"],lmAttStr.predict(test[att_manual])))
# Out:
# 1.3968841970923733
# 1.4069663013267037

# %%
glm = lm.Ridge()
scaled_glm = Pipeline([
    ('std', preprocessing.StandardScaler()),
    ('reg', lm.Ridge(max_iter =1000))
])
gsAttStr = ms.GridSearchCV(estimator=scaled_glm,
                 param_grid={'reg__alpha': np.logspace(-10, 10, 21)},
                 scoring= ['neg_mean_squared_error'],
                 refit = 'neg_mean_squared_error',
                 return_train_score=True,
                 cv=cv)
gsAttStr.fit(X, y)
gsAttStr.best_score_
# Out:
# -1.400938967424266

# %%
print(metrics.mean_squared_error(test["t_Goals"],gsAttStr.predict(test[att_manual])))
# Out:
# 1.4060444951357391

# %% [markdown]
# ## Def Str

# %%
def_manual = ["f_US xG Conceded","f_AMVIndex","f_Touches - Penalty Area Conceded","f_xGRatio"]
y = train["t_Goals Conceded"]
X = train[def_manual]
rfmod = lm.LinearRegression()

lmDefStr = rfmod.fit(X,y)
print(metrics.mean_squared_error(y,lmDefStr.predict(X)))
print(metrics.mean_squared_error(test["t_Goals Conceded"],lmDefStr.predict(test[att_manual])))
# Out:
# 1.4932022791983237
# 1.653602992384614

# %%
glm = lm.Ridge()
scaled_glm = Pipeline([
    ('std', preprocessing.StandardScaler()),
    ('reg', lm.Ridge(max_iter =1000))
])
gsDefStr = ms.GridSearchCV(estimator=scaled_glm,
                 param_grid={'reg__alpha': np.logspace(-10, 10, 21)},
                 scoring= ['neg_mean_squared_error'],
                 refit = 'neg_mean_squared_error',
                 return_train_score=True,
                 cv=cv)
gsDefStr.fit(X, y)
gsDefStr.best_score_
# Out:
# -1.4996949030497986

# %%
print(metrics.mean_squared_error(test["t_Goals Conceded"],gsDefStr.predict(test[def_manual])))
# Out:
# 1.4975275681654996

# %% [markdown]
# ## Predict

# %%
ema_output = ema_no_reset(training, span=36,feature_cols=features)
ema_target = pd.merge(ema_output, target_goals, on = ['f_Team','matchid']).dropna()
ema_target = pd.merge(ema_target,tm[["FFScout","Season","AMVIndex"]],left_on=["f_Team","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex"}).drop(["FFScout","Season"],axis=1)

# %%
ema_target["AttStr"] = gsAttStr.predict(ema_target[att_manual])
ema_target["DefStr"] = gsDefStr.predict(ema_target[def_manual])
ema_target.head()
# Out:
#             matchid             f_Team    gameweek  season  f_HmGame  \
# 0  /matches/755324/  Manchester United  Gameweek 3    2014  0.486111
# 1  /matches/755338/  Manchester United  Gameweek 4    2014  0.314991
# 2  /matches/755346/  Manchester United  Gameweek 5    2014  0.500771
# 3  /matches/755358/  Manchester United  Gameweek 6    2014  0.389188
# 4  /matches/755368/  Manchester United  Gameweek 7    2014  0.505638
#
#                                     fixture            matchdate  gw_no  \
# 0              Burnley vs Manchester United  2014-08-30 12:45:00      3
# 1  Manchester United vs Queens Park Rangers  2014-09-14 16:00:00      4
# 2       Leicester City vs Manchester United  2014-09-21 13:30:00      5
# 3      Manchester United vs West Ham United  2014-09-27 15:00:00      6
# 4              Manchester United vs Everton  2014-10-05 12:00:00      7
#
#    f_Touches - Final Third log  f_Passes - Final Third - Successful  \
# ...

# %% [markdown]
# ## Compare

# %%
random_week = ema_target[(ema_target["season"]==2016) &
                        (ema_target["gw_no"]==19)].copy()#.set_index("f_Team")[['f_Possession', 'f_Points']]

plt.figure(figsize=(10,6))
scatter_text('f_US xG', 'f_US xG Conceded', 'f_Team',
             data = random_week, 
             title = 'xG Averages', 
             xlabel = 'xG Attack',
             ylabel = 'xG Conceded')

# %%
plt.figure(figsize=(10,6))
scatter_text('AttStr', 'DefStr', 'f_Team',
             data = random_week, 
             title = 'Att Def Strength', 
             xlabel = 'Att Str',
             ylabel = 'Def Str')

# %%
ema_target.corr()[["t_Goals","t_Goals Conceded"]].sort_values(by="t_Goals")
# Out:
#                                                t_Goals  t_Goals Conceded
# DefStr                                       -0.282882          0.182298
# f_Touches - Penalty Area Conceded            -0.241489          0.150998
# f_Touches - Final Third Conceded             -0.238708          0.132988
# f_Shots Conceded                             -0.236310          0.138336
# f_Chances Conceded                           -0.233918          0.136138
# f_Passes - Final Third - Successful Conceded -0.233617          0.122562
# f_Goal Attempts In Box Conceded              -0.228294          0.151132
# f_US xG Conceded                             -0.207808          0.156542
# f_Shots On Target Conceded                   -0.200521          0.144649
# t_US xG Conceded                             -0.197696          0.636346
# f_Goals Conceded                             -0.168943          0.128997
# f_Big Chances Conceded                       -0.119662          0.122946
# ...

# %%
print(test["gw_sq"].unique())
# Out:
# [  4   9  10  11  23  25  26  29  31  38  46  53  57  58  59  60  62  65
#   73  74  92 100 107 111 112 117 132 142 148 149]

# %% [markdown]
# # Predict Score

# %%
def id_opponent(fixture,home):
    if home==1:
        opponent = fixture.split(" vs ")[1]
    else:
        opponent = fixture.split(" vs ")[0]
    return opponent

ema_output = ema_no_reset(training, span=36,feature_cols=features)
ema_target = pd.merge(ema_output, target_goals, on = ['f_Team','matchid']).dropna()
ema_target = pd.merge(ema_target,tm[["FFScout","Season","AMVIndex"]],left_on=["f_Team","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex"}).drop(["FFScout","Season"],axis=1)
ema_target = pd.merge(ema_target,final_order, on = ["season","gw_no"]).copy()
ema_target["opponent"] = ema_target.apply(lambda row: id_opponent(row["fixture"],row["f_HmGameFut"]),axis=1)
ema_target["AttStr"] = gsAttStr.predict(ema_target[att_manual])
ema_target["DefStr"] = gsDefStr.predict(ema_target[def_manual])

train, test = season_split(ema_target,0.2,"gw_sq")

ema_target.head()
# Out:
#             matchid             f_Team    gameweek  season  f_HmGame  \
# 0  /matches/755324/  Manchester United  Gameweek 3    2014  0.486111
# 1  /matches/755324/            Burnley  Gameweek 3    2014  0.486111
# 2  /matches/755327/         Stoke City  Gameweek 3    2014  0.486111
# 3  /matches/755327/    Manchester City  Gameweek 3    2014  0.513889
# 4  /matches/755328/     Crystal Palace  Gameweek 3    2014  0.513889
#
#                               fixture            matchdate  gw_no  \
# 0        Burnley vs Manchester United  2014-08-30 12:45:00      3
# 1        Burnley vs Manchester United  2014-08-30 12:45:00      3
# 2       Manchester City vs Stoke City  2014-08-30 15:00:00      3
# 3       Manchester City vs Stoke City  2014-08-30 15:00:00      3
# 4  Newcastle United vs Crystal Palace  2014-08-30 15:00:00      3
#
#    f_Touches - Final Third log  f_Passes - Final Third - Successful  \
# 0                     5.375139                           113.097222
# ...

# %%
print(test["gw_sq"].unique())
# Out:
# [  4   9  10  11  23  25  26  29  31  38  46  53  57  58  59  60  62  65
#   73  74  92 100 107 111 112 117 132 142 148 149]

# %%
team_df = ema_target[["matchid","fixture","f_Team","season","gw_no","f_HmGameFut","AttStr","DefStr",
                      "t_Goals","t_Goals Conceded","opponent","gw_sq"]].copy()
opp_df = ema_target[["fixture","f_Team","season","AttStr","DefStr"]].copy()
opp_df = opp_df.rename(columns = {"f_Team":"opponent","AttStr":"OppAttStr","DefStr":"OppDefStr"})
team_df.head()
# Out:
#             matchid                             fixture             f_Team  \
# 0  /matches/755324/        Burnley vs Manchester United  Manchester United
# 1  /matches/755324/        Burnley vs Manchester United            Burnley
# 2  /matches/755327/       Manchester City vs Stoke City         Stoke City
# 3  /matches/755327/       Manchester City vs Stoke City    Manchester City
# 4  /matches/755328/  Newcastle United vs Crystal Palace     Crystal Palace
#
#    season  gw_no  f_HmGameFut    AttStr    DefStr  t_Goals  t_Goals Conceded  \
# 0    2014      3            0  1.383602  0.846565        0                 0
# 1    2014      3            1  0.824035  1.725489        0                 0
# 2    2014      3            0  1.289389  1.339192        1                 0
# 3    2014      3            1  1.690177  0.874729        0                 1
# 4    2014      3            0  0.747633  1.675470        3                 3
#
#             opponent  gw_sq
# ...

# %%
vs_df = pd.merge(team_df,opp_df, on =["opponent","season","fixture"])

train, test = season_split(vs_df,0.2,"gw_sq")
train.head()
# Out:
#             matchid                             fixture             f_Team  \
# 0  /matches/755324/        Burnley vs Manchester United  Manchester United
# 1  /matches/755324/        Burnley vs Manchester United            Burnley
# 2  /matches/755327/       Manchester City vs Stoke City         Stoke City
# 3  /matches/755327/       Manchester City vs Stoke City    Manchester City
# 4  /matches/755328/  Newcastle United vs Crystal Palace     Crystal Palace
#
#    season  gw_no  f_HmGameFut    AttStr    DefStr  t_Goals  t_Goals Conceded  \
# 0    2014      3            0  1.383602  0.846565        0                 0
# 1    2014      3            1  0.824035  1.725489        0                 0
# 2    2014      3            0  1.289389  1.339192        1                 0
# 3    2014      3            1  1.690177  0.874729        0                 1
# 4    2014      3            0  0.747633  1.675470        3                 3
#
#             opponent  gw_sq  OppAttStr  OppDefStr
# ...

# %%
X = train[["f_HmGameFut","AttStr","OppDefStr"]]
y = train["t_Goals"]
glm = lm.LinearRegression()
cross_val_score(glm,X,y, scoring = "neg_mean_squared_error",cv = cv).mean()
# Out:
# -1.3236951171320777

# %%
glm = lm.LinearRegression()
glmPredGoals = glm.fit(X,y)

metrics.mean_squared_error(test["t_Goals"], glmPredGoals.predict(test[["f_HmGameFut","AttStr","OppDefStr"]]))
# Out:
# 1.322398639252368

# %%
glmPredGoals.coef_
# Out:
# array([0.36993227, 1.00232459, 0.97715441])

# %%
glm = lm.LinearRegression()
gsPredGoals = ms.GridSearchCV(estimator=glm,
                 param_grid={'fit_intercept': [True]},
                 scoring= ['neg_mean_squared_error'],
                 refit = 'neg_mean_squared_error',
                 return_train_score=True,
                 cv=cv)
gsPredGoals.fit(X,y)
gsPredGoals.best_score_
gsPredGoals.best_estimator_.coef_
# Out:
# array([0.36993227, 1.00232459, 0.97715441])

# %%
formula = 't_Goals ~ ' + ' + '.join(x for x in X.columns)
X1 = X.copy()
X1 = sm.add_constant(X1)
model = sm.OLS(y,X1).fit()
model.summary()
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                t_Goals   R-squared:                       0.150
# Model:                            OLS   Adj. R-squared:                  0.149
# Method:                 Least Squares   F-statistic:                     140.3
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):           1.05e-83
# Time:                        22:33:05   Log-Likelihood:                -3708.0
# No. Observations:                2382   AIC:                             7424.
# Df Residuals:                    2378   BIC:                             7447.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# # Single Line Predictions

# %%
ema_output = ema_no_reset(results, span=36,feature_cols=features)
ema_target = pd.merge(ema_output, target_goals, on = ['f_Team','matchid']).dropna()
ema_target = pd.merge(ema_target,tm[["FFScout","Season","AMVIndex"]],left_on=["f_Team","season"],
         right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex"}).drop(["FFScout","Season"],axis=1)
ema_target = pd.merge(ema_target,final_order, on = ["season","gw_no"]).copy()
ema_target["opponent"] = ema_target.apply(lambda row: id_opponent(row["fixture"],row["f_HmGameFut"]),axis=1)
ema_target["AttStr"] = gsAttStr.predict(ema_target[att_manual])
ema_target["DefStr"] = gsDefStr.predict(ema_target[def_manual])

team_df = ema_target[["matchid","fixture","f_Team","season","gw_no","f_HmGameFut","AttStr","DefStr",
                      "t_Goals","t_Goals Conceded","opponent","gw_sq"]].copy()
opp_df = ema_target[["fixture","f_Team","season","AttStr","DefStr"]].copy()
opp_df = opp_df.rename(columns = {"f_Team":"opponent","AttStr":"OppAttStr","DefStr":"OppDefStr"})
vs_df = pd.merge(team_df,opp_df, on =["opponent","season","fixture"])
vs_df["PredGoals"] = gsPredGoals.predict(vs_df[["f_HmGameFut","AttStr","OppDefStr"]])

HomeTeam = vs_df[vs_df["f_HmGameFut"]==1][["matchid","fixture","f_Team","season","gw_no","f_HmGameFut","AttStr","DefStr",
                      "t_Goals","t_Goals Conceded","opponent","gw_sq","OppAttStr","OppDefStr","PredGoals"]]
AwayTeam = vs_df[vs_df["f_HmGameFut"]==0][["season","gw_no","fixture","PredGoals"]].rename(columns={"PredGoals":"AwayGoals"})
SingleLinePred = pd.merge(HomeTeam,AwayTeam,on=["season","gw_no","fixture"])
SingleLinePred.head()
# Out:
#             matchid                               fixture  \
# 0  /matches/755324/          Burnley vs Manchester United
# 1  /matches/755327/         Manchester City vs Stoke City
# 2  /matches/755328/    Newcastle United vs Crystal Palace
# 3  /matches/755329/     Queens Park Rangers vs Sunderland
# 4  /matches/755330/  Swansea City vs West Bromwich Albion
#
#                 f_Team  season  gw_no  f_HmGameFut    AttStr    DefStr  \
# 0              Burnley    2014      3            1  0.824035  1.725489
# 1      Manchester City    2014      3            1  1.690177  0.874729
# 2     Newcastle United    2014      3            1  1.161538  1.417956
# 3  Queens Park Rangers    2014      3            1  1.365036  1.583181
# 4         Swansea City    2014      3            1  0.603206  1.475774
#
#    t_Goals  t_Goals Conceded              opponent  gw_sq  OppAttStr  \
# 0        0                 0     Manchester United      3   1.383602
# ...

# %%
season_2017 = SingleLinePred[SingleLinePred["season"].isin([2014,2015,2016,2017])]
y_true = season_2017["t_Goals"]
y_pred = season_2017["PredGoals"]
print(len(y_true))
print(len(y_pred))
print(metrics.mean_squared_error(y_true,y_pred))
print(metrics.mean_squared_error(season_2017["t_Goals Conceded"],season_2017["AwayGoals"]))
# Out:
# 1488
# 1488
# 1.4707506294112924
# 1.165733491904421

# %%
season_2018 = SingleLinePred[SingleLinePred["season"].isin([2018])]
y_true = season_2018["t_Goals"]
y_pred = season_2018["PredGoals"]
print(len(y_true))
print(len(y_pred))
print(metrics.mean_squared_error(y_true,y_pred))
print(metrics.mean_squared_error(season_2018["t_Goals Conceded"],season_2018["AwayGoals"]))
# Out:
# 374
# 374
# 1.3697678552884014
# 1.1760246453445649

# %% [markdown]
# # End to end

# %%
def create_teamstr_df(df,span):
    ema_output = ema_no_reset(df, span=span,feature_cols=features)
    ema_target = pd.merge(ema_output, target_goals, on = ['f_Team','matchid']).dropna()
    ema_target = pd.merge(ema_target,tm[["FFScout","Season","AMVIndex"]],left_on=["f_Team","season"],
             right_on=["FFScout","Season"]).rename(columns={"AMVIndex":"f_AMVIndex"}).drop(["FFScout","Season"],axis=1)
    ema_target = pd.merge(ema_target,final_order, on = ["season","gw_no"]).copy()
    ema_target["opponent"] = ema_target.apply(lambda row: id_opponent(row["fixture"],row["f_HmGameFut"]),axis=1)
    return ema_target

def fitStrModel(df,model, target, model_vars):
    y = df[target]
    X = df[model_vars]
    scaled_glm = Pipeline([
        ('std', preprocessing.StandardScaler()),
        ('reg', model)
    ])
    
    GSMod = ms.GridSearchCV(estimator=scaled_glm,
                 param_grid={'reg__alpha': np.logspace(-10, 10, 21)},
                 scoring= ['neg_mean_squared_error'],
                 refit = 'neg_mean_squared_error',
                 return_train_score=True,
                 cv=cv)
    GSMod.fit(X,y)
    print(GSMod.best_score_)
    return GSMod
    
def create_pred_goals_df(df):
    team_df = df[["matchid","fixture","f_Team","season","gw_no","f_HmGameFut","AttStr","DefStr",
                      "AttStrScaled","DefStrScaled","t_Goals","t_Goals Conceded","opponent","gw_sq"]].copy()
    opp_df = df[["fixture","f_Team","season","AttStr","DefStr","AttStrScaled","DefStrScaled"]].copy()
    opp_df = opp_df.rename(columns = {"f_Team":"opponent","AttStr":"OppAttStr","AttStrScaled":"OppAttStrScaled",
                                      "DefStr":"OppDefStr","DefStrScaled":"OppDefStrScaled"})
    vs_df = pd.merge(team_df,opp_df, on =["opponent","season","fixture"])
    return vs_df

def create_single_line_df(df):
    HomeTeam = df[df["f_HmGameFut"]==1][["matchid","fixture","f_Team","season","gw_no","f_HmGameFut","AttStr","DefStr",
                                               "t_Goals","t_Goals Conceded","opponent","gw_sq","OppAttStr"
                                               ,"OppDefStr","PredGoals"]].rename(columns = {"PredGoals":"PredHomeGoals"})
    AwayTeam = df[df["f_HmGameFut"]==0][["season","gw_no","fixture","PredGoals"]].rename(columns={"PredGoals":"PredAwayGoals"})
    SingleLinePred = pd.merge(HomeTeam,AwayTeam,on=["season","gw_no","fixture"])
    return SingleLinePred

def fitScoreModel(df,model,target,model_vars):
    X = df[model_vars]
    y = df[target]
    glm = lm.LinearRegression()
    gsPredGoals = ms.GridSearchCV(estimator=model,
                     param_grid={'fit_intercept': [True]},
                     scoring= ['neg_mean_squared_error'],
                     refit = 'neg_mean_squared_error',
                     return_train_score=True,
                     cv=cv)
    gsPredGoals.fit(X,y)
    print(gsPredGoals.best_score_)
    print(gsPredGoals.best_estimator_.coef_)
    return gsPredGoals

from scipy.stats import poisson,skellam

def simulate_match(home_goals_avg, away_goals_avg, max_goals=10):
    team_pred = [[poisson.pmf(i, team_avg) for i in range(0, max_goals+1)] for team_avg in [home_goals_avg, away_goals_avg]]
    score_matrix = (np.outer(np.array(team_pred[0]), np.array(team_pred[1])))
    HomeProb = np.sum(np.tril(score_matrix, -1))
    DrawProb = np.sum(np.diag(score_matrix))
    AwayProb = np.sum(np.triu(score_matrix,1))
    #[HomeProb,DrawProb,AwayProb]
    return pd.Series([HomeProb,DrawProb,AwayProb])

# %%
att_manual = ["f_US xG","f_AMVIndex","f_Touches - Penalty Area","f_Points"]
def_manual = ["f_US xG Conceded","f_AMVIndex","f_Touches - Penalty Area Conceded","f_xGRatio"]
score_vars = ["f_HmGameFut","AttStr","OppDefStr"]
score_vars_scaled = ["f_HmGameFut","AttStrScaled","OppDefStrScaled"]

ema_target = create_teamstr_df(training,36 )
train, test = season_split(ema_target,0.2,"gw_sq")

gsAttStr = fitStrModel(train,lm.Ridge(max_iter =1000),"t_Goals",att_manual)
gsDefStr = fitStrModel(train,lm.Ridge(max_iter =1000),"t_Goals Conceded",def_manual)

ema_target["AttStr"] = gsAttStr.predict(ema_target[att_manual])
ema_target["DefStr"] = gsDefStr.predict(ema_target[def_manual])

ScaledStrength = standard_scaler.fit_transform(ema_target[["AttStr","DefStr"]])

ema_target[["AttStrScaled","DefStrScaled"]] = pd.DataFrame(ScaledStrength)
ema_target["DefStrScaled"] = ema_target["DefStrScaled"]*-1

vs_df = create_pred_goals_df(ema_target)
train, test = season_split(vs_df,0.2,"gw_sq")

GSScoreModel = fitScoreModel(train,lm.LinearRegression(),"t_Goals",score_vars_scaled)
vs_df["PredGoals"] = GSScoreModel.predict(vs_df[score_vars_scaled])

single_line_predictions = create_single_line_df(vs_df)

ProbVars = ["PoissHomeProb","PoissDrawProb","PoissAwayProb"]
single_line_predictions[["PoissHomeProb",
                        "PoissDrawProb",
                        "PoissAwayProb"]] = single_line_predictions.apply(lambda row: simulate_match(row["PredHomeGoals"],
                                                                                                     row["PredAwayGoals"]),
                                                                          axis = 1)
single_line_predictions = final_outcome(single_line_predictions,"t_Goals","t_Goals Conceded")
single_line_predictions.head()
# Out:
# -1.400938967424266
# -1.4996949030497986
# -1.3237369767835487
# [ 0.36993227  0.37968858 -0.22592081]
#             matchid                               fixture  \
# 0  /matches/755324/          Burnley vs Manchester United
# 1  /matches/755327/         Manchester City vs Stoke City
# 2  /matches/755328/    Newcastle United vs Crystal Palace
# 3  /matches/755329/     Queens Park Rangers vs Sunderland
# 4  /matches/755330/  Swansea City vs West Bromwich Albion
#
#                 f_Team  season  gw_no  f_HmGameFut    AttStr    DefStr  \
# 0              Burnley    2014      3            1  0.824035  1.725489
# 1      Manchester City    2014      3            1  1.690177  0.874729
# 2     Newcastle United    2014      3            1  1.161538  1.417956
# 3  Queens Park Rangers    2014      3            1  1.365036  1.583181
# 4         Swansea City    2014      3            1  0.603206  1.475774
#
#    t_Goals  t_Goals Conceded              opponent  gw_sq  OppAttStr  \
# ...

# %%
le = LabelEncoder()
single_line_predictions["ResultCode"] = le.fit_transform(single_line_predictions["Result"])
train, test = season_split(single_line_predictions,0.2,"gw_sq")
print(metrics.log_loss(train["ResultCode"],train[["PoissAwayProb","PoissDrawProb","PoissHomeProb"]]))
print(metrics.log_loss(test["ResultCode"],test[["PoissAwayProb","PoissDrawProb","PoissHomeProb"]]))
# Out:
# 0.9703190548153796
# 0.9941945641590509

# %% [markdown]
# # Test on 2018

# %%
ema_target = create_teamstr_df(results,36 )
ema_target["AttStr"] = gsAttStr.predict(ema_target[att_manual])
ema_target["DefStr"] = gsDefStr.predict(ema_target[def_manual])
ScaledStrength = standard_scaler.transform(ema_target[["AttStr","DefStr"]])
ema_target[["AttStrScaled","DefStrScaled"]] = pd.DataFrame(ScaledStrength)
ema_target["DefStrScaled"] = ema_target["DefStrScaled"]*-1

vs_df = create_pred_goals_df(ema_target)
vs_df["PredGoals"] = GSScoreModel.predict(vs_df[score_vars_scaled])

single_line_predictions = create_single_line_df(vs_df)

ProbVars = ["PoissHomeProb","PoissDrawProb","PoissAwayProb"]
single_line_predictions[ProbVars] = single_line_predictions.apply(lambda row: simulate_match(row["PredHomeGoals"],
                                                                                             row["PredAwayGoals"]),
                                                                  axis = 1)

single_line_predictions = final_outcome(single_line_predictions,"t_Goals","t_Goals Conceded")
single_line_predictions.head()
# Out:
#             matchid                               fixture  \
# 0  /matches/755324/          Burnley vs Manchester United
# 1  /matches/755327/         Manchester City vs Stoke City
# 2  /matches/755328/    Newcastle United vs Crystal Palace
# 3  /matches/755329/     Queens Park Rangers vs Sunderland
# 4  /matches/755330/  Swansea City vs West Bromwich Albion
#
#                 f_Team  season  gw_no  f_HmGameFut    AttStr    DefStr  \
# 0              Burnley    2014      3            1  0.824035  1.725489
# 1      Manchester City    2014      3            1  1.690177  0.874729
# 2     Newcastle United    2014      3            1  1.161538  1.417956
# 3  Queens Park Rangers    2014      3            1  1.365036  1.583181
# 4         Swansea City    2014      3            1  0.603206  1.475774
#
#    t_Goals  t_Goals Conceded              opponent  gw_sq  OppAttStr  \
# 0        0                 0     Manchester United      3   1.383602
# ...

# %%
le = LabelEncoder()
single_line_predictions["ResultCode"] = le.fit_transform(single_line_predictions["Result"])
season_2018 = single_line_predictions[single_line_predictions["season"]==2018]
print(metrics.log_loss(season_2018["ResultCode"],season_2018[["PoissAwayProb","PoissDrawProb","PoissHomeProb"]]))
# Out:
# 0.8900250899729067

# %%
ScaledStrength = standard_scaler.transform(ema_target[["AttStr","DefStr"]])

# %%
train, test = season_split(single_line_predictions,0.2,"gw_sq")
print(metrics.mean_squared_error(train["t_Goals"],train["PredHomeGoals"]))
print(metrics.mean_squared_error(train["t_Goals Conceded"],train["PredAwayGoals"]))

print(metrics.mean_squared_error(test["t_Goals"],test["PredHomeGoals"]))
print(metrics.mean_squared_error(test["t_Goals Conceded"],test["PredAwayGoals"]))
# Out:
# 1.4595816450372698
# 1.1748294219668236
# 1.5155393849313628
# 1.129257893573373

# %%
train, test = season_split(vs_df,0.2,"gw_sq")
fitScoreModel(train,lm.LinearRegression(),"t_Goals",score_vars)
fitScoreModel(train,lm.LinearRegression(),"t_Goals",score_vars_scaled)
# Out:
# -1.3237369767835487
# [0.36993227 1.00232459 0.97715441]
# -1.3237369767835487
# [ 0.36993227  0.37968858 -0.22592081]
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#        error_score='raise-deprecating',
#        estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'fit_intercept': [True]}, pre_dispatch='2*n_jobs',
#        refit='neg_mean_squared_error', return_train_score=True,
#        scoring=['neg_mean_squared_error'], verbose=0)

# %%
X = train[score_vars_scaled]
y = train["t_Goals"]
formula = 't_Goals ~ ' + ' + '.join(x for x in X.columns)
X1 = X.copy()
X1 = sm.add_constant(X1)
model = sm.OLS(y,X1).fit()
model.summary()
# Out:
# C:\Users\Byron\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                t_Goals   R-squared:                       0.150
# Model:                            OLS   Adj. R-squared:                  0.149
# Method:                 Least Squares   F-statistic:                     140.3
# Date:                Sat, 20 Jun 2020   Prob (F-statistic):           1.05e-83
# Time:                        19:27:27   Log-Likelihood:                -3708.0
# No. Observations:                2382   AIC:                             7424.
# Df Residuals:                    2378   BIC:                             7447.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...

# %%
poisson_model = smf.glm(formula='t_Goals ~ ' + ' + '.join(x for x in X.columns), data=train, 
                        family=sm.families.Poisson()).fit()
poisson_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                t_Goals   No. Observations:                 2382
# Model:                            GLM   Df Residuals:                     2378
# Model Family:                 Poisson   Df Model:                            3
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -3427.0
# Date:                Sat, 20 Jun 2020   Deviance:                       2668.6
# Time:                        19:36:05   Pearson chi2:                 2.35e+03
# No. Iterations:                     5
# Covariance Type:            nonrobust
# ...
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
poisson_model.predict(pd.DataFrame(data={'f_Team': 'Arsenal', 'opponent': 'Southampton',
                                       'f_HmGame':1},index=[1]))

# %%
plt.figure(figsize=(10,6))
scatter_text('AttStr', 'DefStr', 'f_Team',
             data = ema_target[(ema_target["season"]==2016) &
                               (ema_target["gw_no"]==20)
                              ], 
             title = 'xG Averages', 
             xlabel = 'AttStr',
             ylabel = 'DefStr')

# %%
plt.figure(figsize=(10,6))
scatter_text('AttStrScaled', 'DefStrScaled', 'f_Team',
             data = ema_target[(ema_target["season"]==2016) &
                               (ema_target["gw_no"]==20)
                              ], 
             title = 'xG Averages', 
             xlabel = 'AttStrScaled',
             ylabel = 'DefStrScaled')
